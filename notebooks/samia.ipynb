# %% [markdown]
# # PROJECT 02 : SHARK ATTACKS
# -----

# %% [markdown]
# ### BRIEF : data analysis of global shark attacks for a business idea
# You will initially examine the Shark Attack dataset, understanding its structure and formulating a hypothesis or several hypotheses about the data.
#  We hypothesize that shark attacks are more common in certain locations and peak during specific months.
# We define a Business Case, such as
#
# * “As a company that sells medical products, I want to identify destinations with high shark attack rates.”
# * “As a company providing supply transportation services, I want to know when and where shark attacks peak to plan the safe transport of medical supplies to hospitals.”
#
#  Throughout the project, we will use Python and the pandas library to apply at least five data cleaning techniques to handle missing values, duplicates, and formatting inconsistencies. After cleaning, we will perform basic exploratory data analysis to validate our hypotheses and extract insights.
#
# #### 📝 BUSINESS IDEA — 3 Bullet Points
#
# * Problem to Solve: Coastal hospitals and emergency response teams are not always prepared with the right medical supplies during periods of high shark-attack frequency. This business solves the problem by predicting when and where attacks are most likely, so medical supplies can be stocked in advance.
#
# * Business Concept: Use historical shark attack data to create global heatmaps and seasonal risk forecasts. Then provide pharmaceutical products (painkillers, antibiotics, blood bags, emergency kits) and transportation support to hospitals and ambulances near high-risk beaches.
#
# * Data Used to Profit: The business will analyze Country, Date/Month, Gender, Age, Fatality, and Type of Injury to identify high-risk locations, peak attack months, and most common injury types. This allows optimized supply production, targeted sales, and efficient delivery to the areas that need it most.

# %% [markdown]
# ## 🌀COLUMNS TO CLEAN :
# -----
#
# **- COUNTRY (global comparison between countries to invest in more)** @Blanca
#
#     * we just take the country column and make sure every country name is accurately named
#     * We are gonna check the column of COUNTRY and make sure every country name is correct
#     * We remove NULL COUNTRY data rows that dont have any country
#     * We need to make sure that the name of COUNTRY  is capitalized and written the same way for example :
#         United States of Amercia == USA == US
#         it has to have the same name and consistent!
#
# **- DATE ( MONTH + YEAR )** @Blanca
#
#     * split the date into day - month columns and only use month column
#     * interpret months which have shark attacks happen the most
#
# **- GENDER ( F or M )** @Cecilia
#
#     * We check unique values and make it so it is only two values F or M and deleted all rows that have other values
#     * we noticed mostly M get attacked
#     * percentages Male to Female victims
#     * We remove NULL DATE data rows that dont have a date or that the date doesnt include a month and a year
#     * We are gonna check the column of DATE and seperate it into three columns DAY + MONTH + YEAR
#     * We verify that the new YEAR column matches with the old YEAR column and keep the ones that match
#         * NEW YEAR COLUMN is the one split from the DATE column
#         * OLD YEAR COLUMN is the one already existing in the original sheet
#     * Once we finish comparing the new YEAR column vs old YEAR column and we find them not matching on some data rows. we remove the none matching ones so we keep clean data of accurate years
#     * We remove the DAY and OLD YEAR columns
#     * We are gonna keep the MONTH and matching YEAR
#
# **- AGE (victims age ranges)** @Samia
#
#     * majority of victims survive
#     * we split the age groups into three categories (minors under 18 / adults 18-40 and 40+)
#     * keep in mind complications depending on age when getting treated
#     * percentages of victims based on age ranges
#     * we split the age groups into three categories (minors under 18 / adults 18-40 and elders 40+)
#     * note that there are complications depending on age
#
# **- FATALITY ( Y or N )** @Cecilia
#     * depends on the column 'Type' of injury and if it includes death or high severity
#     * mostly survived
#     * for the pharamaceutical logistics & transportation of injured people to the hospital
#     * assumption we have a percentage of survivals highest and we use it to sell for the
#     * We check unique values and make sure it is only two values Y or N and deleted all rows that have other values
#     * assumption we have a high percentage of survivals and we use it to sell the idea to profit from selling products to hospitals
#
# **- INJURY TYPE** @Samia
#
#     * clean the type of injury by severity
#     * seperate the injury type into different severity
#     * seperate the injury type into different body parts
#     * treatment depends on type of injury and thus the supplies as well
#
# -------

# %% [markdown]
# ### IMPORT UTILS and INIT from SRC

# %%
import sys, os
sys.path.append(os.path.abspath(".."))
from src import utils
from src import init

# %% [markdown]
# -----
# ### GENERAL

# %%
import pandas as pd

# Load the CSV
url = 'https://drive.google.com/uc?export=download&id=1ZRuzHohahE54BC7hKcA289tyuL9cp7-h'
df = pd.read_csv(url)
df.head(3)
# Out:
#           Date    Year          Type    Country                   State  \
# 0  25 Aug 2023  2023.0    Unprovoked  AUSTRALIA         New South Wales
# 1  21 Aug-2023  2023.0  Questionable    BAHAMAS  New Providence   Isoad
# 2  07-Jun-2023  2023.0    Unprovoked    BAHAMAS                Freeport
#
#                             Location      Activity         Name Sex    Age  \
# 0  Lighthouse Beach, Port Macquarie        Surfing    Toby Begg   M     44
# 1             Saunders Beach, Nassau           NaN         male   M  20/30
# 2                     Shark Junction  Scuba diving  Heidi Ernst   F     73
#
#                                               Injury  Fatal Y/N     Time  \
# 0                     Severe injuries to lower limbs        NaN    10h00
# 1  Body found with shark bites. Possible drowning...        NaN  Morning
# 2                               Calf severely bitten        NaN    13h00
#
#                 Species                            Source
# 0  White shark, 3.8-4.2m  B. Myatt, & M. Michaelson, GSAF
# 1                    NaN           The Tribune, 8/21/2023
# 2  Caribbean rreef shark                J. Marchand, GSAF

# %%
# Option 1: Display the entire DataFrame (all rows and columns)
pd.set_option('display.max_rows', None)      # Show all rows
pd.set_option('display.max_columns', None)   # Show all columns

#the full table
#print(df)

# %%
df.info()
# change type of each serie
# year into int or split it from Date
# Age into int
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 561 entries, 0 to 560
# Data columns (total 15 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       561 non-null    object
#  1   Year       560 non-null    float64
#  2   Type       557 non-null    object
#  3   Country    556 non-null    object
#  4   State      508 non-null    object
#  5   Location   503 non-null    object
#  6   Activity   433 non-null    object
#  7   Name       502 non-null    object
#  8   Sex        480 non-null    object
#  9   Age        238 non-null    object
#  10  Injury     553 non-null    object
#  11  Fatal Y/N  0 non-null      float64
#  12  Time       157 non-null    object
#  13  Species    526 non-null    object
#  14  Source     556 non-null    object
# dtypes: float64(2), object(13)
# memory usage: 65.9+ KB

# %%
print("\nData Frame SHAPE", df.shape)

print("\nData Columns")
df.columns
# Out:
# Data Frame SHAPE (561, 15)
#
# Data Columns
# Index(['Date', 'Year', 'Type', 'Country', 'State', 'Location', 'Activity',
#        'Name', 'Sex', 'Age', 'Injury', 'Fatal Y/N', 'Time', 'Species ',
#        'Source'],
#       dtype='object')

# %% [markdown]
# -----
# ### 'Country' CLEANING

# %%
df.columns
# Out:
# Index(['Date', 'Year', 'Type', 'Country', 'State', 'Location', 'Activity',
#        'Name', 'Sex', 'Age', 'Injury', '
# 537                     AUSTRALIA
# 538                           USA
# 539                     AUSTRALIA
# 540                ATLANTIC OCEAN
# 541                     AUSTRALIA
# 542                           USA
# 543                           USA
# 544                     AUSTRALIA
# 545                           USA
# 546                         SPAIN
# 547                     AUSTRALIA
# 548                       ENGLAND
# 549                       JAMAICA
# 550                         SPAIN
# 551                        NORWAY
# 552                       ANTIGUA
# 553                           USA
# 554                           USA
# 555                        FRANCE
# 556                       ICELAND
# 557                        ROATAN
# 558                        GUINEA
# 559                     AUSTRALIA
# 560                           USA
# Name: Country, dtype: object

# %%
df['Country'].nunique()
df['Country'].unique()
# Out:
# c:\Users\sboub\anaconda3\Lib\site-packages\IPython\core\displayhook.py:281: UserWarning:
#
# Output cache limit (currently 1000 entries) hit.
# Flushing oldest 200 entries.
# array(['AUSTRALIA', 'BAHAMAS', 'SEYCHELLES', 'ARGENTINA', 'COSTA RICA',
#        'BRAZIL', 'EGYPT', 'FRENCH POLYNESIA', 'USA', 'COLOMBIA',
#        'SOUTH AFRICA', 'SPAIN', 'COMOROS', 'MEXICO', 'CAPE VERDE',
#        'CAYMAN ISLANDS', 'ITALY', nan, 'JAMAICA', 'TRINIDAD & TOBAGO',
#        'CANADA', 'CROATIA', 'SAUDI ARABIA', 'ANTIGUA',
#        'UNITED ARAB EMIRATES (UAE)', 'GUAM', 'NEVIS', 'JAPAN',
#        'NEW ZEALAND', 'BRITISH VIRGIN ISLANDS', 'SENEGAL', 'BELIZE',
#        'Seychelles', 'LIBERIA', 'HONDURAS', 'SRI LANKA', 'INDONESIA',
#        'NEW CALEDONIA', 'MADAGASCAR', 'MALAYSIA', 'TONGA', 'BERMUDA',
#        'MONTENEGRO', 'SOMALIA', 'GREECE', 'MOZAMBIQUE',
#        'PAPUA NEW GUINEA', 'TANZANIA', 'PANAMA', 'PHILIPPINES',
#        'ATLANTIC OCEAN', 'JOHNSTON ISLAND', 'MARSHALL ISLANDS',
#        'CARIBBEAN SEA', 'TURKEY', 'CUBA', 'GUATEMALA',
#        'NORTH ATLANTIC OCEAN', 'NORTH PACIFIC OCEAN', 'PACIFIC OCEAN',
#        'INDIAN OCEAN', 'UNITED KINGDOM', 'ISRAEL', 'ITALY / CROATIA',
#        'INDIA', 'HAITI', 'ENGLAND', 'YEMEN ', 'CRETE', 'FRANCE', 'SYRIA',
#        'AZORES', 'Fiji', 'GUYANA', 'CHINA', 'NORWAY', 'ICELAND', 'ROATAN',
#        'GUINEA'], dtype=object)

# %%
import pandas as pd

# Assume df is already loaded
# COUNTRY CLEANING
df = df.dropna(subset=["Country"])
df["Country"] = df["Country"].str.strip().str.title()

country_replacements = {
    "United States Of America": "USA",
    "Usa": "USA",
    "Us": "USA",
    "U.s.": "USA",
    "United Kingdom": "UK",
    "England": "UK",
    "Uk": "UK",
    "Brasil": "Brazil",
    "México": "Mexico",
    "United Arab Emirates (Uae)": "UAE",
    "Turkey": "Türkiye"
}

df["Country"] = df["Country"].replace(country_replacements)
df = df[df["Country"] != "Italy / Croatia"]

# Show stats about the Country column
print(df["Country"].describe())

# Save 'Country' CLEANED to CSV
df.to_csv("../data/interim/1_interim_country.csv", index=False)
print("STEP 1 : 'Country' Data cleaned and CSV saved successfully!")
# Out:
# count     555
# unique     75
# top       USA
# freq      191
# Name: Country, dtype: object
# STEP 1 : 'Country' Data cleaned and CSV saved successfully!

# %%
# Load the CSV to df_country
url = "../data/interim/1_interim_country.csv"
df_country = pd.read_csv(url)
df_country['Country'].unique()
# Out:
# array(['Australia', 'Bahamas', 'Seychelles', 'Argentina', 'Costa Rica',
#        'Brazil', 'Egypt', 'French Polynesia', 'USA', 'Colombia',
#        'South Africa', 'Spain', 'Comoros', 'Mexico', 'Cape Verde',
#        'Cayman Islands', 'Italy', 'Jamaica', 'Trinidad & Tobago',
#        'Canada', 'Croatia', 'Saudi Arabia', 'Antigua', 'UAE', 'Guam',
#        'Nevis', 'Japan', 'New Zealand', 'British Virgin Islands',
#        'Senegal', 'Belize', 'Liberia', 'Honduras', 'Sri Lanka',
#        'Indonesia', 'New Caledonia', 'Madagascar', 'Malaysia', 'Tonga',
#        'Bermuda', 'Montenegro', 'Somalia', 'Greece', 'Mozambique',
#        'Papua New Guinea', 'Tanzania', 'Panama', 'Philippines',
#        'Atlantic Ocean', 'Johnston Island', 'Marshall Islands',
#        'Caribbean Sea', 'Türkiye', 'Cuba', 'Guatemala',
#        'North Atlantic Ocean', 'North Pacific Ocean', 'Pacific Ocean',
#        'Indian Ocean', 'UK', 'Israel', 'India', 'Haiti', 'Yemen', 'Crete',
#        'France', 'Syria', 'Azores', 'Fiji', 'Guyana', 'China', 'Norway',
#        'Iceland', 'Roatan', 'Guinea'], dtype=object)

# %%
# verify the changes
df['Country'].unique()
# Out:
# array(['Australia', 'Bahamas', 'Seychelles', 'Argentina', 'Costa Rica',
#        'Brazil', 'Egypt', 'French Polynesia', 'USA', 'Colombia',
#        'South Africa', 'Spain', 'Comoros', 'Mexico', 'Cape Verde',
#        'Cayman Islands', 'Italy', 'Jamaica', 'Trinidad & Tobago',
#        'Canada', 'Croatia', 'Saudi Arabia', 'Antigua', 'UAE', 'Guam',
#        'Nevis', 'Japan', 'New Zealand', 'British Virgin Islands',
#        'Senegal', 'Belize', 'Liberia', 'Honduras', 'Sri Lanka',
#        'Indonesia', 'New Caledonia', 'Madagascar', 'Malaysia', 'Tonga',
#        'Bermuda', 'Montenegro', 'Somalia', 'Greece', 'Mozambique',
#        'Papua New Guinea', 'Tanzania', 'Panama', 'Philippines',
#        'Atlantic Ocean', 'Johnston Island', 'Marshall Islands',
#        'Caribbean Sea', 'Türkiye', 'Cuba', 'Guatemala',
#        'North Atlantic Ocean', 'North Pacific Ocean', 'Pacific Ocean',
#        'Indian Ocean', 'UK', 'Israel', 'India', 'Haiti', 'Yemen', 'Crete',
#        'France', 'Syria', 'Azores', 'Fiji', 'Guyana', 'China', 'Norway',
#        'Iceland', 'Roatan', 'Guinea'], dtype=object)

# %%
top_countries = df['Country'].value_counts().head(100)
print(top_countries)
# PIE CHART FOR COUNTRIES WITH HIGHEST SHARK ATTACKS

# USA , Australia, South Africa got the highest frequency of shark attacks
# Out:
# Country
# USA                       191
# Australia                 120
# South Africa               64
# Italy                      14
# New Zealand                12
# Mexico                     11
# Spain                      10
# Brazil                      9
# Bahamas                     8
# Croatia                     8
# Japan                       6
# Greece                      5
# Mozambique                  4
# Egypt                       4
# Cuba                        4
# Philippines                 4
# French Polynesia            3
# Jamaica                     3
# Bermuda                     3
# Costa Rica                  3
# UK                          3
# Papua New Guinea            2
# Atlantic Ocean              2
# Indian Ocean                2
# Sri Lanka                   2
# Senegal                     2
# Türkiye                     2
# France                      2
# Marshall Islands            2
# Seychelles                  2
# Cape Verde                  2
# Antigua                     2
# Cayman Islands              2
# North Pacific Ocean         1
# Roatan                      1
# Iceland                     1
# Norway                      1
# Guatemala                   1
# China                       1
# North Atlantic Ocean        1
# Crete                       1
# Caribbean Sea               1
# Pacific Ocean               1
# Fiji                        1
# Azores                      1
# Israel                      1
# Syria                       1
# India                       1
# Haiti                       1
# Yemen                       1
# Guyana                      1
# Malaysia                    1
# Johnston Island             1
# British Virgin Islands      1
# Argentina                   1
# Colombia                    1
# Comoros                     1
# Trinidad & Tobago           1
# Canada                      1
# Saudi Arabia                1
# UAE                         1
# Guam                        1
# Nevis                       1
# Belize                      1
# Panama                      1
# Liberia                     1
# Honduras                    1
# Indonesia                   1
# New Caledonia               1
# Madagascar                  1
# Tonga                       1
# Montenegro                  1
# Somalia                     1
# Tanzania                    1
# Guinea                      1
# Name: count, dtype: int64

# %%
df.columns
# Out:
# Index(['Date', 'Year', 'Type', 'Country', 'State', 'Location', 'Activity',
#        'Name', 'Sex', 'Age', 'Injury', 'Fatal Y/N', 'Time', 'Species ',
#        'Source'],
#       dtype='object')

# %%
# we could try analyse which state in the USA has the most shark attacks?

# %%
df.head(5)
# Out:
#           Date    Year          Type     Country                   State  \
# 0  25 Aug 2023  2023.0    Unprovoked   Australia         New South Wales
# 1  21 Aug-2023  2023.0  Questionable     Bahamas  New Providence   Isoad
# 2  07-Jun-2023  2023.0    Unprovoked     Bahamas                Freeport
# 3  02-Mar-2023  2023.0    Unprovoked  Seychelles          Praslin Island
# 4  18-Feb-2023  2023.0  Questionable   Argentina               Patagonia
#
#                             Location      Activity          Name Sex    Age  \
# 0  Lighthouse Beach, Port Macquarie        Surfing     Toby Begg   M     44
# 1             Saunders Beach, Nassau           NaN          male   M  20/30
# 2                     Shark Junction  Scuba diving   Heidi Ernst   F     73
# 3                                NaN    Snorkeling      Arthur …   M      6
# 4                    Chubut Province           NaN  Diego Barría   M     32
#
#                                               Injury  Fatal Y/N       Time  \
# 0                     Severe injuries to lower limbs        NaN      10h00
# 1  Body found with shark bites. Possible drowning...        NaN    Morning
# 2                               Calf severely bitten        NaN      13h00
# 3                                   Left foot bitten        NaN  Afternoon
# 4                              Death by misadventure        NaN        NaN
#
#                 Species                            Source
# 0  White shark, 3.8-4.2m  B. Myatt, & M. Michaelson, GSAF
# 1                    NaN           The Tribune, 8/21/2023
# 2  Caribbean rreef shark                J. Marchand, GSAF
# 3            Lemon shark              Midlibre, 3/18/2023
# 4                    NaN              El Pais,  2/27/2023

# %%
# dropping the activity

# %% [markdown]
# -----
# ### 'Sex' CLEANING

# %%
# Load the updated CSV
url = "../data/interim/1_interim_country.csv"
df = pd.read_csv(url)
df.columns
# Out:
# Index(['Date', 'Year', 'Type', 'Country', 'State', 'Location', 'Activity',
#        'Name', 'Sex', 'Age', 'Injury', 'Fatal Y/N', 'Time', 'Species ',
#        'Source'],
#       dtype='object')

# %%
df['Sex']
# Out:
# 0        M
# 1        M
# 2        F
# 3        M
# 4        M
# 5        F
# 6        M
# 7        M
# 8        M
# 9      NaN
# 10       F
# 11     NaN
# 12       F
# 13       F
# 14     NaN
# 15       M
# 16       F
# 17       M
# 18       M
# 19       M
# 20       M
# 21       M
# 22       F
# 23       M
# 24       F
# 25     NaN
# 26       M
# 27       F
# 28       F
# 29       M
# 30       M
# 31       M
# 32       M
# 33       M
# 34       M
# 35     NaN
# 36       M
# 37       M
# 38       M
# 39       M
# 40       M
# 41     NaN
# 42       M
# 43       M
# 44       F
# 45       M
# 46       M
# 47       M
# 48       M
# 49       F
# 50       M
# 51       M
# 52       F
# 53       M
# 54       M
# 55       F
# 56       M
# 57     NaN
# 58       M
# 59     NaN
# 60       M
# 61       M
# 62       M
# 63       F
# 64       M
# 65       F
# 66       M
# 67       M
# 68       M
# 69       M
# 70       M
# 71       M
# 72       M
# 73       M
# 74       M
# 75       M
# 76       F
# 77       F
# 78     NaN
# 79       M
# 80       M
# 81       M
# 82       M
# 83     NaN
# 84       M
# 85       M
# 86       M
# 87       M
# 88       M
# 89       F
# 90       F
# 91       M
# 92       M
# 93       F
# 94       M
# 95       M
# 96       M
# 97       M
# 98       F
# 99       M
# 100      M
# 101      M
# 102      M
# 103      M
# 104      M
# 105    NaN
# 106      M
# 107      F
# 108      M
# 109      M
# 110      M
# 111      M
# 112      M
# 113      M
# 114      M
# 115      M
# 116      M
# 117      M
# 118      M
# 119      F
# 120      F
# 121    NaN
# 122      F
# 123      M
# 124      M
# 125      M
# 126      M
# 127      M
# 128      M
# 129      M
# 130      M
# 131      M
# 132    NaN
# 133      F
# 134      M
# 135      M
# 136      M
# 137      M
# 138      M
# 139      M
# 140    NaN
# 141      M
# 142      M
# 143      M
# 144    NaN
# 145      M
# 146      M
# 147      M
# 148      F
# 149      M
# 150      F
# 151    NaN
# 152      M
# 153      M
# 154      M
# 155      F
# 156      M
# 157      M
# 158      M
# 159      M
# 160      M
# 161      F
# 162      M
# 163      F
# 164      M
# 165      M
# 166    NaN
# 167      M
# 168      M
# 169      M
# 170      M
# 171      M
# 172      M
# 173      F
# 174      M
# 175      F
# 176      M
# 177      M
# 178    NaN
# 179      M
# 180      M
# 181      F
# 182      M
# 183    NaN
# 184      M
# 185      F
# 186      M
# 187      M
# 188      F
# 189      M
# 190      M
# 191      M
# 192      M
# 193      M
# 194      M
# 195      M
# 196      M
# 197      M
# 198      F
# 199      M
# 200      M
# 201      M
# 202      M
# 203      M
# 204      M
# 205    NaN
# 206      M
# 207      M
# 208      M
# 209      M
# 210      M
# 211      M
# 212      M
# 213      M
# 214      M
# 215      M
# 216      M
# 217      F
# 218      M
# 219      M
# 220      F
# 221      M
# 222      M
# 223      M
# 224      M
# 225      M
# 226    NaN
# 227      M
# 228      M
# 229      M
# 230      M
# 231      M
# 232      M
# 233      M
# 234      F
# 235      F
# 236      M
# 237      M
# 238    NaN
# 239      M
# 240      M
# 241      F
# 242      M
# 243      M
# 244      M
# 245      M
# 246      M
# 247      M
# 248      M
# 249      F
# 250      M
# 251      M
# 252      M
# 253    NaN
# 254      M
# 255      M
# 256      M
# 257      M
# 258      M
# 259    NaN
# 260      M
# 261      M
# 262      M
# 263      M
# 264    NaN
# 265      M
# 266    NaN
# 267      M
# 268    NaN
# 269      M
# 270      M
# 271      M
# 272      F
# 273    NaN
# 274      M
# 275      M
# 276      M
# 277      M
# 278      M
# 279      M
# 280    NaN
# 281    NaN
# 282      M
# 283    NaN
# 284      M
# 285      M
# 286    NaN
# 287    NaN
# 288      M
# 289      F
# 290      M
# 291      M
# 292      M
# 293      M
# 294    NaN
# 295      M
# 296      M
# 297      M
# 298      M
# 299      M
# 300      M
# 301      F
# 302    NaN
# 303      M
# 304      M
# 305      M
# 306      M
# 307      M
# 308      M
# 309    NaN
# 310    NaN
# 311      M
# 312    NaN
# 313      F
# 314      M
# 315      M
# 316      M
# 317      F
# 318    NaN
# 319      M
# 320      M
# 321      M
# 322      M
# 323      M
# 324      F
# 325    NaN
# 326      M
# 327      M
# 328      M
# 329    NaN
# 330      M
# 331    NaN
# 332      M
# 333      M
# 334    NaN
# 335      F
# 336      M
# 337      M
# 338      M
# 339      M
# 340      M
# 341      M
# 342    NaN
# 343      M
# 344      M
# 345      M
# 346    NaN
# 347      M
# 348      M
# 349    NaN
# 350      F
# 351      M
# 352      M
# 353      M
# 354      M
# 355      M
# 356      M
# 357      M
# 358    NaN
# 359      M
# 360    NaN
# 361      M
# 362      F
# 363      M
# 364      M
# 365      M
# 366    NaN
# 367      M
# 368    NaN
# 369      M
# 370      M
# 371      M
# 372    NaN
# 373      M
# 374      M
# 375      F
# 376      M
# 377      M
# 378    NaN
# 379      M
# 380      M
# 381      M
# 382      M
# 383      M
# 384      M
# 385      M
# 386      M
# 387    NaN
# 388    NaN
# 389    NaN
# 390      M
# 391      M
# 392      M
# 393      M
# 394      M
# 395      M
# 396      M
# 397      M
# 398    NaN
# 399      M
# 400      M
# 401    NaN
# 402      F
# 403      F
# 404      M
# 405      M
# 406      M
# 407    NaN
# 408      M
# 409      M
# 410      M
# 411      M
# 412      M
# 413      M
# 414      M
# 415      M
# 416    NaN
# 417      M
# 418      M
# 419      M
# 420      M
# 421      M
# 422      M
# 423    NaN
# 424      M
# 425      F
# 426      M
# 427      M
# 428      M
# 429    NaN
# 430      M
# 431      M
# 432    NaN
# 433      M
# 434      M
# 435      M
# 436      M
# 437      M
# 438      M
# 439      M
# 440      M
# 441    NaN
# 442      M
# 443      F
# 444      M
# 445      M
# 446      M
# 447      M
# 448      M
# 449      F
# 450    NaN
# 451      M
# 452      M
# 453      M
# 454      M
# 455      M
# 456      M
# 457      F
# 458    NaN
# 459    NaN
# 460      M
# 461      M
# 462      M
# 463      M
# 464      M
# 465      M
# 466      M
# 467      M
# 468      M
# 469      M
# 470    NaN
# 471      M
# 472      M
# 473      M
# 474      M
# 475      M
# 476      M
# 477      M
# 478      M
# 479      M
# 480      M
# 481      M
# 482      F
# 483      M
# 484      M
# 485      M
# 486      M
# 487      M
# 488    NaN
# 489      M
# 490    NaN
# 491      M
# 492    NaN
# 493      M
# 494    NaN
# 495      M
# 496      M
# 497    NaN
# 498      M
# 499    NaN
# 500      F
# 501      M
# 502      M
# 503      M
# 504      M
# 505      M
# 506      M
# 507      M
# 508      M
# 509      M
# 510      M
# 511      M
# 512      M
# 513      M
# 514    NaN
# 515      M
# 516      M
# 517      M
# 518      M
# 519      M
# 520      M
# 521      M
# 522      M
# 523      M
# 524      M
# 525      M
# 526      M
# 527    NaN
# 528      M
# 529      M
# 530      M
# 531      M
# 532      M
# 533      M
# 534      F
# 535      M
# 536      M
# 537      M
# 538      M
# 539      M
# 540    NaN
# 541      M
# 542    NaN
# 543    NaN
# 544      M
# 545      M
# 546    NaN
# 547      M
# 548      M
# 549      M
# 550    NaN
# 551      M
# 552      M
# 553      F
# 554      M
# Name: Sex, dtype: object

# %%
# NaN , F, M
df['Sex'].value_counts(dropna=False)
# Out:
# Sex
# M      411
# NaN     80
# F       64
# Name: count, dtype: int64

# %%
df['Sex'] = df['Sex'].replace({
    'm' : 'M', 
    'f' : 'F', 
    'Male' : 'M', 
    'Female' : 'F'})

df['Sex'] = df['Sex'].str.upper()

# %%
df.dropna (subset = ['Sex'], inplace= True)
df['Sex'].value_counts(dropna=False)
# Out:
# Sex
# M    411
# F     64
# Name: count, dtype: int64

# %%
df.columns
# Out:
# Index(['Date', 'Year', 'Type', 'Country', 'State', 'Location', 'Activity',
#        'Name', 'Sex', 'Age', 'Injury', 'Fatal Y/N', 'Time', 'Species ',
#        'Source'],
#       dtype='object')

# %%
df.shape
# Out:
# (475, 15)

# %%
df['Sex'].describe()
# Male is the highest in frequency with shark attacks
# Out:
# count     475
# unique      2
# top         M
# freq      411
# Name: Sex, dtype: object

# %%
# Save 'Sex' CLEANED to CSV
df.to_csv("../data/interim/2_interim_sex.csv", index=False)
print("STEP 2 : 'Sex' Data cleaned successfully!")
# Out:
# STEP 2 : 'Sex' Data cleaned successfully!

# %%
 df.head()
# Out:
#           Date    Year          Type     Country                   State  \
# 0  25 Aug 2023  2023.0    Unprovoked   Australia         New South Wales
# 1  21 Aug-2023  2023.0  Questionable     Bahamas  New Providence   Isoad
# 2  07-Jun-2023  2023.0    Unprovoked     Bahamas                Freeport
# 3  02-Mar-2023  2023.0    Unprovoked  Seychelles          Praslin Island
# 4  18-Feb-2023  2023.0  Questionable   Argentina               Patagonia
#
#                             Location      Activity          Name Sex    Age  \
# 0  Lighthouse Beach, Port Macquarie        Surfing     Toby Begg   M     44
# 1             Saunders Beach, Nassau           NaN          male   M  20/30
# 2                     Shark Junction  Scuba diving   Heidi Ernst   F     73
# 3                                NaN    Snorkeling      Arthur …   M      6
# 4                    Chubut Province           NaN  Diego Barría   M     32
#
#                                               Injury  Fatal Y/N       Time  \
# 0                     Severe injuries to lower limbs        NaN      10h00
# 1  Body found with shark bites. Possible drowning...        NaN    Morning
# 2                               Calf severely bitten        NaN      13h00
# 3                                   Left foot bitten        NaN  Afternoon
# 4                              Death by misadventure        NaN        NaN
#
#                 Species                            Source
# 0  White shark, 3.8-4.2m  B. Myatt, & M. Michaelson, GSAF
# 1                    NaN           The Tribune, 8/21/2023
# 2  Caribbean rreef shark                J. Marchand, GSAF
# 3            Lemon shark              Midlibre, 3/18/2023
# 4                    NaN              El Pais,  2/27/2023

# %% [markdown]
# -----
# ### 'Age' CLEANING

# %%
# Load the updated CSV
url = "../data/interim/2_interim_sex.csv"
df = pd.read_csv(url)
df.columns
# Out:
# Index(['Date', 'Year', 'Type', 'Country', 'State', 'Location', 'Activity',
#        'Name', 'Sex', 'Age', 'Injury', 'Fatal Y/N', 'Time', 'Species ',
#        'Source'],
#       dtype='object')

# %%
df['Age'].info()
#238 non-null object
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 475 entries, 0 to 474
# Series name: Age
# Non-Null Count  Dtype
# --------------  -----
# 233 non-null    object
# dtypes: object(1)
# memory usage: 3.8+ KB

# %%
df['Age'].unique()
# Out:
# array(['44', '20/30', '73', '6', '32', '50', '11', '26', nan, '35', '62',
#        '34', '31', '33', '25', '10', '8', '18', '68', '20', '19', '27',
#        '60', 'Teen', '65', '9', '40', '39', '43', '23', '38', '63', '47',
#        '48', '42', '24', '12', '16', '14', '7', '49', '17', '52', '53',
#        '45', '36', '54', '51', '22', '28', '56', '8 or 10', '75',
#        '23 & 20', '37', '29', '21', '15', '30', '16 to 18', '67', '77',
#        'mid-20s', 'Ca. 33', '? & 19', '46', '37, 67, 35, 27,  ? & 27',
#        '21, 34,24 & 35', '34 & 19', '13', '5', '1'], dtype=object)

# %%
df['Age'].nunique()
# Out:
# 71

# %%
import pandas as pd
import numpy as np
import re

# DATA .csv
df = pd.read_csv(url)
# def Function : clean_age(value=age)
def clean_age(value):
    if pd.isna(value):
        return np.nan
    
    value = str(value).strip().lower()

    # Remove useless text
    value = value.replace("years", "").replace("year", "").replace("ca.", "").replace("about", "").strip()

    # Words meaning no age
    if value in ["n/a", "na", "none", "?", "", "unknown"]:
        return np.nan

    # Teen keyword (approx.)
    if "teen" in value:
        return 15

    # mid-20s → 25
    if "mid" in value and "20" in value:
        return 25

    # Extract numbers
    nums = re.findall(r"\d+", value)

    # Single number
    if len(nums) == 1:
        return int(nums[0])
    
    # Multiple numbers -> average them (20/30, 23 & 20, 16 to 18)
    if len(nums) >= 2:
        nums = [int(n) for n in nums]
        return sum(nums) / len(nums)

    return np.nan

# Apply cleaner
df['Age_clean'] = df['Age'].apply(clean_age)

# Convert to numeric
df['Age_clean'] = pd.to_numeric(df['Age_clean'], errors='coerce')

# Fill missing with median
median_age = df['Age_clean'].median()
df['Age_clean'].fillna(median_age, inplace=True)

# Convert to integer (no floats)
df['Age_clean'] = df['Age_clean'].round().astype(int)


# Show result
print(df[['Age', 'Age_clean']].head(10))
print("\nMedian age used:", int(median_age))

# Copy Age_clean into Age
df['Age'] = df['Age_clean']

# Drop Age_clean column
df = df.drop(columns=['Age_clean'])
# Out:
#      Age  Age_clean
# 0     44         44
# 1  20/30         25
# 2     73         73
# 3      6          6
# 4     32         32
# 5     50         50
# 6     11         11
# 7     26         26
# 8    NaN         26
# 9    NaN         26
#
# Median age used: 26
# C:\Users\sboub\AppData\Local\Temp\ipykernel_5660\3124323.py:51: FutureWarning:
#
# A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.

# %%
# Check result
print("\nFrequency of each",df["Age"].value_counts())
# Out:
# Frequency of each Age
# 26    247
# 17     15
# 20      9
# 43      8
# 22      7
# 24      7
# 21      7
# 32      7
# 25      7
# 19      7
# 18      7
# 11      6
# 23      6
# 31      6
# 27      6
# 9       5
# 40      5
# 36      5
# 10      5
# 28      5
# 35      5
# 14      5
# 39      4
# 49      4
# 44      4
# 45      4
# 52      4
# 12      4
# 53      3
# 37      3
# 7       3
# 29      3
# 30      3
# 47      3
# 42      3
# 15      3
# 50      3
# 33      3
# 34      3
# 68      2
# 8       2
# 13      2
# 51      2
# 63      2
# 16      2
# 38      2
# 62      2
# 48      2
# 6       2
# 65      1
# 67      1
# 5       1
# 46      1
# 77      1
# 75      1
# 73      1
# 56      1
# 54      1
# 60      1
# 1       1
# Name: count, dtype: int64

# %%
df['Age'].describe().round().astype(int)
# Out:
# count    475
# mean      28
# std       11
# min        1
# 25%       26
# 50%       26
# 75%       26
# max       77
# Name: Age, dtype: int64

# %%
percentiles = df['Age'].describe(percentiles=[0.25, 0.5, 0.75])

print("Age Percentile Statistics:")
print(f"Min:   {int(percentiles['min'])}")
print(f"25%:   {int(percentiles['25%'])}")
print(f"50% (Median): {int(percentiles['50%'])}")
print(f"75%:   {int(percentiles['75%'])}")
print(f"Max:   {int(percentiles['max'])}")

# the majority were people up to 26 years old
# Out:
# Age Percentile Statistics:
# Min:   1
# 25%:   26
# 50% (Median): 26
# 75%:   26
# Max:   77

# %%
# Save 'Age' CLEANED to CSV
df.to_csv("../data/interim/3_interim_age.csv", index=False)
print("STEP 3 : 'Age' Data cleaned successfully!")
# Out:
# STEP 3 : 'Age' Data cleaned successfully!

# %%
df.head(5)
# Out:
#           Date    Year          Type     Country                   State  \
# 0  25 Aug 2023  2023.0    Unprovoked   Australia         New South Wales
# 1  21 Aug-2023  2023.0  Questionable     Bahamas  New Providence   Isoad
# 2  07-Jun-2023  2023.0    Unprovoked     Bahamas                Freeport
# 3  02-Mar-2023  2023.0    Unprovoked  Seychelles          Praslin Island
# 4  18-Feb-2023  2023.0  Questionable   Argentina               Patagonia
#
#                             Location      Activity          Name Sex  Age  \
# 0  Lighthouse Beach, Port Macquarie        Surfing     Toby Begg   M   44
# 1             Saunders Beach, Nassau           NaN          male   M   25
# 2                     Shark Junction  Scuba diving   Heidi Ernst   F   73
# 3                                NaN    Snorkeling      Arthur …   M    6
# 4                    Chubut Province           NaN  Diego Barría   M   32
#
#                                               Injury  Fatal Y/N       Time  \
# 0                     Severe injuries to lower limbs        NaN      10h00
# 1  Body found with shark bites. Possible drowning...        NaN    Morning
# 2                               Calf severely bitten        NaN      13h00
# 3                                   Left foot bitten        NaN  Afternoon
# 4                              Death by misadventure        NaN        NaN
#
#                 Species                            Source
# 0  White shark, 3.8-4.2m  B. Myatt, & M. Michaelson, GSAF
# 1                    NaN           The Tribune, 8/21/2023
# 2  Caribbean rreef shark                J. Marchand, GSAF
# 3            Lemon shark              Midlibre, 3/18/2023
# 4                    NaN              El Pais,  2/27/2023

# %% [markdown]
# -----
# ### 'Type' Injury & 'Fatal Y/N'
# **Fatality depends on Type of injury and severity**

# %%
# Load the updated CSV
url = "../data/interim/3_interim_age.csv"
df = pd.read_csv(url)
df.columns
# Out:
# Index(['Date', 'Year', 'Type', 'Country', 'State', 'Location', 'Activity',
#        'Name', 'Sex', 'Age', 'Injury', 'Fatal Y/N', 'Time', 'Species ',
#        'Source'],
#       dtype='object')

# %%
df['Fatal Y/N'].unique()
# EMPTY
# Out:
# array([nan])

# %%
import pandas as pd
import numpy as np

def classify_injury(injury, fatal):
    if pd.isna(injury):
        injury = ""
    injury = injury.lower()
    fatal = str(fatal).strip().upper()

    # HOAX / FALSE
    if "hoax" in injury or "false" in injury:
        return "Hoax / False report"

    # NOT A SHARK
    if any(x in injury for x in ["not a shark", "stingray", "barracuda", "propeller", "fish"]):
        return "Not a shark"

    # NO INJURY
    if "no injury" in injury or "no injuries" in injury:
        return "No injury"

    # PROVOKED
    if "provoked" in injury:
        return "Provoked incident"

    # MISSING
    if any(x in injury for x in ["missing", "disappeared", "body not recovered"]):
        return "Missing / Unknown"

    # FATAL CASES
    if fatal == "Y":
        # drowned then bitten after death
        if "post-mortem" in injury or ("drown" in injury and "post" in injury):
            return "Fatal | Drowned, shark scavenged"
        if "unconfirmed" in injury or "probable" in injury:
            return "Fatal | Unconfirmed shark involvement"
        return "Fatal | Shark confirmed"

    # NON-FATAL CASES
    if fatal == "N":
        if any(x in injury for x in ["bitten", "lacerat", "puncture", "wound", "abrasion"]):
            return "Non-fatal | Confirmed shark bite"
        # Text but no bite
        return "Non-fatal | Other"

    # Unknown
    return "Other/Unknown"

# Apply to dataframe
df["Type"] = df.apply(lambda row: classify_injury(row["Injury"], row["Fatal Y/N"]), axis=1)


# Check RESULTS--------------------------------------------------------------------------------------------------------------

# Count number of records in each injury type
counts = df["Type"].value_counts()

# Calculate percentages
percentages = (counts / len(df)) * 100

# Create summary DataFrame
summary = pd.DataFrame({
    "Cases": counts,
    "Percentage": percentages.round(2)
})


# Save TYPE of INJURY CLEANED file
df.to_csv("../data/interim/4_interim_type_injury.csv", index=False)

# Print Injury type
print("Injury Type:")
for category in counts.index:
    print(f"{category}: {counts[category]} cases  ({percentages[category]:.2f}%)")
# Out:
# Injury Type:
# Other/Unknown: 338 cases  (71.16%)
# No injury: 74 cases  (15.58%)
# Missing / Unknown: 34 cases  (7.16%)
# Not a shark: 22 cases  (4.63%)
# Provoked incident: 4 cases  (0.84%)
# Hoax / False report: 3 cases  (0.63%)

# %%
# Save 'Type' CLEANED file
# Save cleaned and updated DataFrame to a new CSV
# we save the data after changes
df.to_csv("../data/interim/4_interim_type_injury.csv", index=False)
print("STEP 4 : 'Type' Data cleaned successfully!")
# Out:
# STEP 4 : 'Type' Data cleaned successfully!

# %%
df.head(5)
# Out:
#           Date    Year           Type     Country                   State  \
# 0  25 Aug 2023  2023.0  Other/Unknown   Australia         New South Wales
# 1  21 Aug-2023  2023.0  Other/Unknown     Bahamas  New Providence   Isoad
# 2  07-Jun-2023  2023.0  Other/Unknown     Bahamas                Freeport
# 3  02-Mar-2023  2023.0  Other/Unknown  Seychelles          Praslin Island
# 4  18-Feb-2023  2023.0  Other/Unknown   Argentina               Patagonia
#
#                             Location      Activity          Name Sex  Age  \
# 0  Lighthouse Beach, Port Macquarie        Surfing     Toby Begg   M   44
# 1             Saunders Beach, Nassau           NaN          male   M   25
# 2                     Shark Junction  Scuba diving   Heidi Ernst   F   73
# 3                                NaN    Snorkeling      Arthur …   M    6
# 4                    Chubut Province           NaN  Diego Barría   M   32
#
#                                               Injury  Fatal Y/N       Time  \
# 0                     Severe injuries to lower limbs        NaN      10h00
# 1  Body found with shark bites. Possible drowning...        NaN    Morning
# 2                               Calf severely bitten        NaN      13h00
# 3                                   Left foot bitten        NaN  Afternoon
# 4                              Death by misadventure        NaN        NaN
#
#                 Species                            Source
# 0  White shark, 3.8-4.2m  B. Myatt, & M. Michaelson, GSAF
# 1                    NaN           The Tribune, 8/21/2023
# 2  Caribbean rreef shark                J. Marchand, GSAF
# 3            Lemon shark              Midlibre, 3/18/2023
# 4                    NaN              El Pais,  2/27/2023

# %% [markdown]
# -----
# #### CLASSIFY INJURY SEVERITY

# %%
# Load the updated CSV
url = "../data/interim/4_interim_type_injury.csv"
df = pd.read_csv(url)
df.columns
# Out:
# Index(['Date', 'Year', 'Type', 'Country', 'State', 'Location', 'Activity',
#        'Name', 'Sex', 'Age', 'Injury', 'Fatal Y/N', 'Time', 'Species ',
#        'Source'],
#       dtype='object')

# %%
df['Type'].describe().round()
# Out:
# count               475
# unique                6
# top       Other/Unknown
# freq                338
# Name: Type, dtype: object

# %%
import re

# Function to classify injury severity
def classify_severity(val):
    if pd.isna(val):
        val = ""
    val = val.lower()
    
    if re.search(r'fatal|death|died|deceased', val):
        return "Death"
    if re.search(r'amputation|severed|severely bitten', val):
        return "Severe injury"
    if re.search(r'bitten|bite|laceration|cuts|fracture', val):
        return "Minor injury"
    if re.search(r'no injury|not injured|unharmed', val):
        return "No injury"
    if re.search(r'possible drowning|unknown', val):
        return "Uncertain"
    
    return "Unknown"

# Apply to create Injury Severity column
df["Injury Severity"] = df["Injury"].apply(classify_severity)

# %%
# Save 'Injury Severity' CLEANED to CSV
df.to_csv("../data/interim/5_interim_injury_severity.csv", index=False)
print("STEP 5 : 'Injury Severity' Data cleaned successfully!")
# Out:
# STEP 5 : 'Injury Severity' Data cleaned successfully!

# %% [markdown]
# -----
# #### FATALITY

# %%
# Load the updated CSV
url = "../data/interim/5_interim_injury_severity.csv"
df = pd.read_csv(url)
df.columns
# Out:
# Index(['Date', 'Year', 'Type', 'Country', 'State', 'Location', 'Activity',
#        'Name', 'Sex', 'Age', 'Injury', 'Fatal Y/N', 'Time', 'Species ',
#        'Source', 'Injury Severity'],
#       dtype='object')

# %%
# Now derive Fatal Y/N based on Injury Severity
def derive_fatal(severity):
    if severity == "Death":
        return "Y"
    elif severity in ["Severe injury", "Injury", "No injury", "Uncertain", "Other/Unknown"]:
        return "N"
    return "N"

df["Fatal Y/N"] = df["Injury Severity"].apply(derive_fatal)


# Save INJURY SEVERITY CLEANED file
df.to_csv("../data/interim/5_interim_injury_severity.csv", index=False)



# Check the first rows
print(df[["Injury", "Injury Severity", "Fatal Y/N"]].head(10))
# Out:
#                                               Injury Injury Severity Fatal Y/N
# 0                     Severe injuries to lower limbs         Unknown         N
# 1  Body found with shark bites. Possible drowning...           Death         Y
# 2                               Calf severely bitten   Severe injury         N
# 3                                   Left foot bitten    Minor injury         N
# 4                              Death by misadventure           Death         Y
# 5                Right forearm and left hand injured         Unknown         N
# 6                           Minor cuts to left thigh    Minor injury         N
# 7                                        Disappeared         Unknown         N
# 8           Laceration to arm caused by metal object    Minor injury         N
# 9                                                NaN         Unknown         N

# %%
# Save INJURY SEVERITY CLEANED file
df.to_csv("../data/interim/6_interim.fatality.csv", index=False)

df['Fatal Y/N'].describe()
# majority survive shark attacks !
# Out:
# count     475
# unique      2
# top         N
# freq      378
# Name: Fatal Y/N, dtype: object

# %%
df.head(5)
# Out:
#           Date    Year           Type     Country                   State  \
# 0  25 Aug 2023  2023.0  Other/Unknown   Australia         New South Wales
# 1  21 Aug-2023  2023.0  Other/Unknown     Bahamas  New Providence   Isoad
# 2  07-Jun-2023  2023.0  Other/Unknown     Bahamas                Freeport
# 3  02-Mar-2023  2023.0  Other/Unknown  Seychelles          Praslin Island
# 4  18-Feb-2023  2023.0  Other/Unknown   Argentina               Patagonia
#
#                             Location      Activity          Name Sex  Age  \
# 0  Lighthouse Beach, Port Macquarie        Surfing     Toby Begg   M   44
# 1             Saunders Beach, Nassau           NaN          male   M   25
# 2                     Shark Junction  Scuba diving   Heidi Ernst   F   73
# 3                                NaN    Snorkeling      Arthur …   M    6
# 4                    Chubut Province           NaN  Diego Barría   M   32
#
#                                               Injury Fatal Y/N       Time  \
# 0                     Severe injuries to lower limbs         N      10h00
# 1  Body found with shark bites. Possible drowning...         Y    Morning
# 2                               Calf severely bitten         N      13h00
# 3                                   Left foot bitten         N  Afternoon
# 4                              Death by misadventure         Y        NaN
#
#                 Species                            Source Injury Severity
# 0  White shark, 3.8-4.2m  B. Myatt, & M. Michaelson, GSAF         Unknown
# 1                    NaN           The Tribune, 8/21/2023           Death
# 2  Caribbean rreef shark                J. Marchand, GSAF   Severe injury
# 3            Lemon shark              Midlibre, 3/18/2023    Minor injury
# 4                    NaN              El Pais,  2/27/2023           Death

# %% [markdown]
# ----------
# ### 'Date' CLEANING & seperate DD-MM-YYYY columns

# %%
# Load the updated CSV
url = "../data/interim/6_interim.fatality.csv"
df = pd.read_csv(url)
df.columns
# Out:
# Index(['Date', 'Year', 'Type', 'Country', 'State', 'Location', 'Activity',
#        'Name', 'Sex', 'Age', 'Injury', 'Fatal Y/N', 'Time', 'Species ',
#        'Source', 'Injury Severity'],
#       dtype='object')

# %%
import pandas as pd
import re

# DataFrame with the 'Date' column
df = pd.read_csv(url)

# Function to parse dates-------------------------------------------------------------------------------------------------------------------
def parse_date(date_str):
    date_str = str(date_str).strip()
    
    # Remove 'Reported ' prefix
    date_str = re.sub(r'^Reported\s+', '', date_str, flags=re.IGNORECASE)
    
    # Patterns to match
    patterns = [
        r'(?P<DD>\d{1,2})[- ](?P<MM>[A-Za-z]+)[- ](?P<YYYY>\d{4})',  # DD MMM YYYY
        r'(?P<MM>[A-Za-z]+)[- ](?P<YYYY>\d{4})',                      # MMM-YYYY
        r'(?P<YYYY>\d{4})',                                           # YYYY only
    ]
    
    for pat in patterns:
        match = re.match(pat, date_str)
        if match:
            return match.groupdict()
    
    return {'DD': None, 'MM': None, 'YYYY': None}
#--------------------------------------------------------------------------------------------------------------------------------------------
# Call Function to the column
parsed_dates = df['Date'].apply(parse_date).apply(pd.Series)

# Merge back to original DataFrame
df = pd.concat([df, parsed_dates], axis=1)

# drop the column 'Date' and add the new columns DD MM YYYY
df = df.drop(columns=['Date'])

#
df = df[df["MM"] != "Early"]
df = df[df["MM"] != "Circa"]
df = df[df["MM"] != "Late"]
df = df[df["MM"] != "Before"]

df.head()
# Out:
#      Year           Type     Country                   State  \
# 0  2023.0  Other/Unknown   Australia         New South Wales
# 1  2023.0  Other/Unknown     Bahamas  New Providence   Isoad
# 2  2023.0  Other/Unknown     Bahamas                Freeport
# 3  2023.0  Other/Unknown  Seychelles          Praslin Island
# 4  2023.0  Other/Unknown   Argentina               Patagonia
#
#                             Location      Activity          Name Sex  Age  \
# 0  Lighthouse Beach, Port Macquarie        Surfing     Toby Begg   M   44
# 1             Saunders Beach, Nassau           NaN          male   M   25
# 2                     Shark Junction  Scuba diving   Heidi Ernst   F   73
# 3                                NaN    Snorkeling      Arthur …   M    6
# 4                    Chubut Province           NaN  Diego Barría   M   32
#
#                                               Injury Fatal Y/N       Time  \
# 0                     Severe injuries to lower limbs         N      10h00
# 1  Body found with shark bites. Possible drowning...         Y    Morning
# 2                               Calf severely bitten         N      13h00
# 3                                   Left foot bitten         N  Afternoon
# 4                              Death by misadventure         Y        NaN
#
#                 Species                            Source Injury Severity  DD  \
# 0  White shark, 3.8-4.2m  B. Myatt, & M. Michaelson, GSAF         Unknown  25
# 1                    NaN           The Tribune, 8/21/2023           Death  21
# 2  Caribbean rreef shark                J. Marchand, GSAF   Severe injury  07
# 3            Lemon shark              Midlibre, 3/18/2023    Minor injury  02
# 4                    NaN              El Pais,  2/27/2023           Death  18
#
#     MM  YYYY
# 0  Aug  2023
# 1  Aug  2023
# 2  Jun  2023
# 3  Mar  2023
# 4  Feb  2023

# %%
import pandas as pd
import numpy as np
import re
# Clean the MM from 'NaN' and 'None'
df = df[df["MM"].notna() & (df["MM"] != "")]

# Replace full month names with abbreviations
df["MM"] = df["MM"].replace({
    "November": "Nov",
    "April": "Apr"
})

df['MM'].unique()
# Out:
# array(['Aug', 'Jun', 'Mar', 'Feb', 'Nov', 'Oct', 'Sep', 'Jul', 'Apr',
#        'May', 'Jan', 'Dec'], dtype=object)

# %%
import pandas as pd
import numpy as np
import re

# DATA .csv
df = pd.read_csv(url)
# Function to parse dates-------------------------------------------------------------------------------------------------------------------
def parse_date(date_str):
    date_str = str(date_str).strip()
    
    # Remove 'Reported ' prefix
    date_str = re.sub(r'^Reported\s+', '', date_str, flags=re.IGNORECASE)
    
    # Patterns to match
    patterns = [
        r'(?P<DD>\d{1,2})[- ](?P<MM>[A-Za-z]+)[- ](?P<YYYY>\d{4})',  # DD MMM YYYY
        r'(?P<MM>[A-Za-z]+)[- ](?P<YYYY>\d{4})',                      # MMM-YYYY
        r'(?P<YYYY>\d{4})',                                           # YYYY only
    ]
    
    for pat in patterns:
        match = re.match(pat, date_str)
        if match:
            return match.groupdict()
    
    return {'DD': None, 'MM': None, 'YYYY': None}
#--------------------------------------------------------------------------------------------------------------------------------------------
# Call Function to the column
parsed_dates = df['Date'].apply(parse_date).apply(pd.Series)

# Merge back to original DataFrame
df = pd.concat([df, parsed_dates], axis=1)

# drop the column 'Date' and add the new columns DD MM YYYY
df = df.drop(columns=['Date'])

#
df = df[df["MM"] != "Early"]
df = df[df["MM"] != "Circa"]
df = df[df["MM"] != "Late"]
df = df[df["MM"] != "Before"]

# %%
# Mapping month names to integers
month_map = {
    'Jan': 1, 'January': 1,
    'Feb': 2, 'February': 2,
    'Mar': 3, 'March': 3,
    'Apr': 4, 'April': 4,
    'May': 5,
    'Jun': 6, 'June': 6,
    'Jul': 7, 'July': 7,
    'Aug': 8, 'August': 8,
    'Sep': 9, 'Sept': 9, 'September': 9,
    'Oct': 10, 'October': 10,
    'Nov': 11, 'November': 11,
    'Dec': 12, 'December': 12
}

# Map MM column to integers; non-months become NaN
df['MM_clean'] = df['MM'].map(month_map)

# Drop non-month values
df_months_only = df.dropna(subset=['MM_clean']).copy()

# Convert to int
df_months_only['MM_clean'] = df_months_only['MM_clean'].astype(int)

# Compute percentages
mm_percent = df_months_only['MM_clean'].value_counts(normalize=True) * 100


# Compute counts from the cleaned DataFrame
mm_counts = df_months_only['MM_clean'].value_counts()

# Display results
print("Counts of months (MM_clean):")
print(mm_counts.sort_index())  # months in chronological order

mm_percent = df_months_only['MM_clean'].value_counts(normalize=True) * 100

# Round to 2 decimal places and add % sign
mm_percent_formatted = mm_percent.sort_index().map(lambda x: f"{x:.2f}%")

# Display
print("\nPercentage of each month (MM_clean):")
print(mm_percent_formatted)
# Out:
# Counts of months (MM_clean):
# MM_clean
# 1     46
# 2     23
# 3     29
# 4     45
# 5     24
# 6     38
# 7     51
# 8     62
# 9     30
# 10    27
# 11    28
# 12    29
# Name: count, dtype: int64
#
# Percentage of each month (MM_clean):
# MM_clean
# 1     10.65%
# 2      5.32%
# 3      6.71%
# 4     10.42%
# 5      5.56%
# 6      8.80%
# 7     11.81%
# 8     14.35%
# 9      6.94%
# 10     6.25%
# 11     6.48%
# 12     6.71%
# Name: proportion, dtype: object

# %%
# frequency of shark attack in every month
df['MM'].value_counts()
# Out:
# MM
# Aug         62
# Jul         51
# Jan         46
# Apr         44
# Jun         38
# Sep         30
# Mar         29
# Dec         29
# Nov         27
# Oct         27
# May         24
# Feb         23
# November     1
# April        1
# Name: count, dtype: int64

# %%
# Calculate percentage of shark attacks per month
percentages = df['MM'].value_counts(normalize=True) * 100

# Sort from high to low
percentages_sorted = percentages.sort_values(ascending=False)

# Format as 00.00%
percentages_formatted = percentages_sorted.map("{:.2f}%".format)

print(percentages_formatted)
# Out:
# MM
# Aug         14.35%
# Jul         11.81%
# Jan         10.65%
# Apr         10.19%
# Jun          8.80%
# Sep          6.94%
# Mar          6.71%
# Dec          6.71%
# Nov          6.25%
# Oct          6.25%
# May          5.56%
# Feb          5.32%
# November     0.23%
# April        0.23%
# Name: proportion, dtype: object

# %%
# Drop MM_clean column
df = df.drop(columns=['MM_clean'])

# Drop Year column
df = df.drop(columns=['Year'])

# %%
# Save 'Date' CLEANED to CSV
df.to_csv("../data/interim/7_interim_date.csv", index=False)
print("STEP 7 : 'Date' cleaned successfully!")
# Out:
# STEP 7 : 'Date' cleaned successfully!

# %%
# Save DATE CLEANED file
# check for changes
df.head()
# Out:
#             Type     Country                   State  \
# 0  Other/Unknown   Australia         New South Wales
# 1  Other/Unknown     Bahamas  New Providence   Isoad
# 2  Other/Unknown     Bahamas                Freeport
# 3  Other/Unknown  Seychelles          Praslin Island
# 4  Other/Unknown   Argentina               Patagonia
#
#                             Location      Activity          Name Sex  Age  \
# 0  Lighthouse Beach, Port Macquarie        Surfing     Toby Begg   M   44
# 1             Saunders Beach, Nassau           NaN          male   M   25
# 2                     Shark Junction  Scuba diving   Heidi Ernst   F   73
# 3                                NaN    Snorkeling      Arthur …   M    6
# 4                    Chubut Province           NaN  Diego Barría   M   32
#
#                                               Injury Fatal Y/N       Time  \
# 0                     Severe injuries to lower limbs         N      10h00
# 1  Body found with shark bites. Possible drowning...         Y    Morning
# 2                               Calf severely bitten         N      13h00
# 3                                   Left foot bitten         N  Afternoon
# 4                              Death by misadventure         Y        NaN
#
#                 Species                            Source Injury Severity  DD  \
# 0  White shark, 3.8-4.2m  B. Myatt, & M. Michaelson, GSAF         Unknown  25
# 1                    NaN           The Tribune, 8/21/2023           Death  21
# 2  Caribbean rreef shark                J. Marchand, GSAF   Severe injury  07
# 3            Lemon shark              Midlibre, 3/18/2023    Minor injury  02
# 4                    NaN              El Pais,  2/27/2023           Death  18
#
#     MM  YYYY
# 0  Aug  2023
# 1  Aug  2023
# 2  Jun  2023
# 3  Mar  2023
# 4  Feb  2023

# %% [markdown]
# ----
# ### FINAL CHANGES

# %%
df.head(5)
# Out:
#             Type     Country                   State  \
# 0  Other/Unknown   Australia         New South Wales
# 1  Other/Unknown     Bahamas  New Providence   Isoad
# 2  Other/Unknown     Bahamas                Freeport
# 3  Other/Unknown  Seychelles          Praslin Island
# 4  Other/Unknown   Argentina               Patagonia
#
#                             Location      Activity          Name Sex  Age  \
# 0  Lighthouse Beach, Port Macquarie        Surfing     Toby Begg   M   44
# 1             Saunders Beach, Nassau           NaN          male   M   25
# 2                     Shark Junction  Scuba diving   Heidi Ernst   F   73
# 3                                NaN    Snorkeling      Arthur …   M    6
# 4                    Chubut Province           NaN  Diego Barría   M   32
#
#                                               Injury Fatal Y/N       Time  \
# 0                     Severe injuries to lower limbs         N      10h00
# 1  Body found with shark bites. Possible drowning...         Y    Morning
# 2                               Calf severely bitten         N      13h00
# 3                                   Left foot bitten         N  Afternoon
# 4                              Death by misadventure         Y        NaN
#
#                 Species                            Source Injury Severity  DD  \
# 0  White shark, 3.8-4.2m  B. Myatt, & M. Michaelson, GSAF         Unknown  25
# 1                    NaN           The Tribune, 8/21/2023           Death  21
# 2  Caribbean rreef shark                J. Marchand, GSAF   Severe injury  07
# 3            Lemon shark              Midlibre, 3/18/2023    Minor injury  02
# 4                    NaN              El Pais,  2/27/2023           Death  18
#
#     MM  YYYY
# 0  Aug  2023
# 1  Aug  2023
# 2  Jun  2023
# 3  Mar  2023
# 4  Feb  2023

# %%
# Drop columns we don't need:
df = df.drop(columns=['Activity'])
df = df.drop(columns=['Type'])
df = df.drop(columns=['Species '])
df = df.drop(columns=['Source'])
df = df.drop(columns=['Time'])
df = df.drop(columns=['Name'])
df = df.drop(columns=['State'])
df = df.drop(columns=['DD'])

df = df[df['MM'].notna() & (df['MM'] != "")]
df.head()
# Out:
#       Country                           Location Sex  Age  \
# 0   Australia  Lighthouse Beach, Port Macquarie    M   44
# 1     Bahamas             Saunders Beach, Nassau   M   25
# 2     Bahamas                     Shark Junction   F   73
# 3  Seychelles                                NaN   M    6
# 4   Argentina                    Chubut Province   M   32
#
#                                               Injury Fatal Y/N  \
# 0                     Severe injuries to lower limbs         N
# 1  Body found with shark bites. Possible drowning...         Y
# 2                               Calf severely bitten         N
# 3                                   Left foot bitten         N
# 4                              Death by misadventure         Y
#
#   Injury Severity   MM  YYYY
# 0         Unknown  Aug  2023
# 1           Death  Aug  2023
# 2   Severe injury  Jun  2023
# 3    Minor injury  Mar  2023
# 4           Death  Feb  2023

# %%
# Save INTERIM DATAFRAM CLEANED to CSV
df.to_csv("../data/interim/8_interim_clean.csv", index=False)
print("STEP 8 : All Data cleaned successfully!")
df.head()
# Out:
# STEP 8 : All Data cleaned successfully!
#       Country                           Location Sex  Age  \
# 0   Australia  Lighthouse Beach, Port Macquarie    M   44
# 1     Bahamas             Saunders Beach, Nassau   M   25
# 2     Bahamas                     Shark Junction   F   73
# 3  Seychelles                                NaN   M    6
# 4   Argentina                    Chubut Province   M   32
#
#                                               Injury Fatal Y/N  \
# 0                     Severe injuries to lower limbs         N
# 1  Body found with shark bites. Possible drowning...         Y
# 2                               Calf severely bitten         N
# 3                                   Left foot bitten         N
# 4                              Death by misadventure         Y
#
#   Injury Severity   MM  YYYY
# 0         Unknown  Aug  2023
# 1           Death  Aug  2023
# 2   Severe injury  Jun  2023
# 3    Minor injury  Mar  2023
# 4           Death  Feb  2023

# %% [markdown]
# ----
# ### CHARTS & INSIGHTS

# %%
df.columns
# Out:
# Index(['Country', 'Location', 'Sex', 'Age', 'Injury', 'Fatal Y/N',
#        'Injury Severity', 'MM', 'YYYY'],
#       dtype='object')

# %%
import plotly.io as pio
import plotly.express as px

# Use VS Code renderer for inline display
pio.renderers.default = 'vscode'  # or 'iframe'

# Prepare data
top_5 = df['Country'].value_counts().nlargest(5).reset_index()
top_5.columns = ['Country', 'Count']

# Create pie chart
fig = px.pie(
    top_5,
    names='Country',
    values='Count',
    title='Countries with High frequncy of shark attacks',
    color_discrete_sequence=px.colors.qualitative.Pastel
)

fig.show()

# %%
import pandas as pd
import plotly.express as px
import plotly.io as pio

# Ensure inline display in VS Code
pio.renderers.default = 'vscode'  # or 'iframe'

# Check column names for typos/spaces
print(df.columns)  # Optional: just to see actual column names

# Use the correct column names for Age and Sex
age_col = [col for col in df.columns if 'age' in col.lower()][0]  # picks the first column containing 'age'
sex_col = [col for col in df.columns if 'sex' in col.lower()][0]   # picks the first column containing 'sex'

# Ensure 'Age' is numeric
df[age_col] = pd.to_numeric(df[age_col], errors='coerce')

# Drop rows where Age is NaN
df = df.dropna(subset=[age_col])

# Group by Sex and calculate average Age
sex_age = df.groupby(sex_col)[age_col].mean().reset_index()

# Create the bar chart
fig = px.bar(
    sex_age,
    x=sex_col,
    y=age_col,
    color=sex_col,
    title='Average Age by Sex',
    text=sex_age[age_col].round(1),
    color_discrete_sequence=px.colors.qualitative.Pastel
)

# Customize layout
fig.update_traces(textposition='outside')
fig.update_layout(
    xaxis_title='Sex',
    yaxis_title='Average Age',
    template='plotly_white'
)

fig.show()
# Out:
# Index(['Country', 'Location', 'Sex', 'Age', 'Injury', 'Fatal Y/N',
#        'Injury Severity', 'MM', 'YYYY'],
#       dtype='object')

# %%
print(df.columns)
df.head(560)


# Clean Location data
# add extra data
## nearest_hospital_to_beach_location
## most_needed_product_for_injury_severity
# Out:
# Index(['Country', 'Location', 'Sex', 'Age', 'Injury', 'Fatal Y/N',
#        'Injury Severity', 'MM', 'YYYY'],
#       dtype='object')
#                     Country  \
# 0                 Australia
# 1                   Bahamas
# 2                   Bahamas
# 3                Seychelles
# 4                 Argentina
# 5                Costa Rica
# 6                    Brazil
# 7                 Australia
# 8                     Egypt
# 9                 Australia
# 10         French Polynesia
# 11                Australia
# 12                  Bahamas
# 13                      USA
# 14                 Colombia
# 15                   Brazil
# 16             South Africa
# 17                      USA
# 18             South Africa
# 19                    Spain
# 20                      USA
# 21                      USA
# 22                      USA
# 23                      USA
# 24                      USA
# 25                      USA
# 26             South Africa
# 27                Australia
# 28                Australia
# 29                      USA
# 30                   Mexico
# 31                      USA
# 32                Australia
# 33               Cape Verde
# 34                      USA
# 35                      USA
# 36           Cayman Islands
# 37                Australia
# 38                      USA
# 39                      USA
# 40                      USA
# 41                    Spain
# 42                Australia
# 43                      USA
# 44                      USA
# 45         French Polynesia
# 46                      USA
# 47                    Italy
# 48                   Brazil
# 49                Australia
# 50                      USA
# 51                      USA
# 52                  Bahamas
# 53                      USA
# 54                Australia
# 55                Australia
# 56           Cayman Islands
# 57                      USA
# 58                    Spain
# 59                  Jamaica
# 60                      USA
# 61                Australia
# 62                Australia
# 63                Australia
# 64                Australia
# 65                      USA
# 66                      USA
# 67        Trinidad & Tobago
# 68                   Canada
# 69                Australia
# 70                      USA
# 71             Saudi Arabia
# 72                  Antigua
# 73             South Africa
# 74                      USA
# 75                Australia
# 76                      USA
# 77                   Brazil
# 78                      UAE
# 79                    Egypt
# 80                Australia
# 81                Australia
# 82                  Bahamas
# 83                      USA
# 84                     Guam
# 85             South Africa
# 86                      USA
# 87                    Nevis
# 88                    Spain
# 89                      USA
# 90                      USA
# 91                      USA
# 92             South Africa
# 93                   Brazil
# 94                   Brazil
# 95                      USA
# 96                      USA
# 97                      USA
# 98                      USA
# 99                      USA
# 100            South Africa
# 101                  Mexico
# 102               Australia
# 104             New Zealand
# 105  British Virgin Islands
# 106               Australia
# 107                  Mexico
# 108                     USA
# 109                     USA
# 110                     USA
# 111               Australia
# 112              Costa Rica
# 113               Australia
# 114                     USA
# 116            South Africa
# 117               Australia
# 118                  Brazil
# 119                  Belize
# 120                   Spain
# 20                 Hilton Head Island, Beaufort County   M   10
# 21                 Hilton Head Island, Beaufort County   F    8
# 22                                  Wrightsville Beach   M   26
# 23                         Sunset Beach, Orange County   F   18
# 24                                                 NaN   F   26
# 25                                   Georgetown County   M   26
# 26                                        Protea Banks   M   68
# 27                                                 NaN   M   35
# 28                                           Merimbula   M   20
# 29                    New Smyrna Beach, Volusia County   M   19
# 30                                    Guadalupe Island   M   26
# 31                      Folly Beach, Charleston County   M   27
# 32                                          Kingscliff   M   26
# 33                                                 NaN   M   60
# 34           Corners Beach, Jupiter, Palm Beach County   M   26
# 35                        Fort Myers Beach, Lee County   M   15
# 36                                   Stingray City Bar   M   65
# 37                                         Nettley Bay   M   26
# 38           Paradise Beach, Melbourne, Brevard County   F    9
# 39                                           Waikiki,    M   32
# 40                        Cocoa Beach, Brevard  County   M   26
# 41                            Poniente Beach, Benidorm   M   10
# 42                                    Tyrendarra Beach   M   40
# 43                       Edisto Beach, Colleton County   F   35
# 44                     Huntington Beach, Orange County   M   39
# 45                                                 NaN   M   26
# 46                    Jacksonville Beach, Duval County   F   26
# 47                                                 NaN   M   43
# 48                            Praia del Chifre, Olinda   M   23
# 49                             Wategos Beach, Byon Bay   F   26
# 50                                                 NaN   M   38
# 51              Manresa State Beach, Santa Cruz County   M   26
# 52                                         Tiger Beach   M   63
# 53                  Bethel Shoals, Indian River County   M   26
# 54                                  Off Dawesville Cut   M   38
# 55                                         Lennox Head   F   10
# 56                                                 NaN   M   26
# 57                                    Catalina Channel   F   47
# 58               Sant Marti d’Empuries Beach, L’Escala   M   48
# 59                                          Port Royal   M   20
# 60              Tourmaline Surf Park, San Diego County   M   42
# 61                                               Perth   M   24
# 62                                      Terrigal Beach   M   47
# 63                                      Bullcock Beach   M   62
# 64                                          Mooloolaba   M   20
# 65                                          Hobe Sound   M   26
# 66                        Ocean Isle, Brunswick County   M   12
# 67                    Off Radix Village, Mayoro County   M   24
# 68                                   Tofino, Vancouver   F   23
# 69                 Ship's Graveyard off Point Lonsdale   F   42
# 70                          Myrtle Beach, Horry County   M   16
# 71                                            Off Duba   M   42
# 72                                    Fort James Beach   M   26
# 73                        Between Sodwana & Cape Vidal   M   26
# 74                                       Hatillo Beach   M   27
# 75                                      Fantome Island   M   48
# 76              Wrightsville Beach, New Hanover County   M   12
# 77                                       Praia do Pina   M   14
# 78                                        Khor Fakkan    M   43
# 79                                     Sharm-el-Sheikh   F   26
# 80                                       Cudgen Creek    F    7
# 81                                    Native Dog Beach   M   26
# 82               Off Jaws Beach, New Providence Island   M   43
# 83                       Bethune Beach, Volusia County   F   26
# 84                                         Achang Reef   M   31
# 85                                 North Beach, Durban   M   26
# 86                     Huntington Beach, Orange County   M   49
# 87                                        Castle Beach   M   26
# 88                                       Sant Salvador   F   11
# 89                 Shell Beach, San Luis Obispo County   M   26
# 90                     Melbourne Beach, Brevard County   M   14
# 91                                                Kona   M   49
# 92                                          Umtentweni   M   24
# 93                                Praia do Olho d'Aqua   M   17
# 94                                        Olho d'Água    M   17
# 170                                     Ha'ena, Kaua'i   M   26
# 171                 Bald Head Island, Brunswick County   M    9
# 172                      Emerald Isle, Carteret County   M   15
# 173                                             Neiafu   M   26
# 174                            Carmel, Monterey County   M   26
# 175                   New Smyrna Beach, Volusia County   M   12
# 178                   Hinchinbrook Channel, Queensland   M   44
# 179         Sunset Cliffs, San Diego, San Diego County   F   25
# 180                                 Barren Joey Island   M   32
# 181                      Twin Arches, Hana Ranch, Maui   M   26
# 182                                   St. Lucie County   M   26
# 183                                    Wai'anae, O'ahu   M   26
# 184                                Wreck of the U-352    M   45
# 185                 Clifton Beach, southwest of Hobart   M   19
# 186                                             Bimini   M   32
# 187                                     Port Elizabeth   M   26
# 188   Juno Beach / North Palm Beach, Palm Beach County   M   30
# 189                                      Fraser Island   M   27
# 190             Ehukai Beach Park, Sunset Beach, O'ahu   M   26
# 191                                  Kahe Point, O'ahu   M   26
# 192  Between Wrightsville Beach & Carolina Beach, N...   M   49
# 193                                                NaN   M   35
# 194                                                NaN   M   26
# 195  Latigo Point / Paradise Cove, west of Malibu, ...   M   24
# 196                                      Waihe'e, Maui   M   26
# 197                                           La Lucia   F   26
# 198                                             Durban   M   22
# 199                                                NaN   M   26
# 200                                         Shoalhaven   F   17
# 201                                          St. Lucia   M   26
# 202                                       Richards Bay   M   14
# 203                                     Port Shepstone   M   26
# 205                                           Platbank   M   22
# 206              Reef on seaward side of Geyser Island   M   35
# 207                                        T.O. Strand   M   21
# 208                 Fort Pierce Inlet, St Lucie County   M   17
# 209                   New Smyrna Beach, Volusia County   M   11
# 210                           Bayport, Hernando County   M   67
# 211                                          Umzimkulu   M   26
# 212                 Wabasso Beach, Indian River County   M   22
# 213                   Boynton Beach, Palm Beach County   F   77
# 214                   Off Crystal River, Citrus County   F   31
# 215                                         Cape Point   M   21
# 216                                                NaN   M   26
# 217                                                NaN   M   36
# 218                                            LaMercy   M   26
# 219                                            Tongaat   F   26
# 220                               Riomaggiore (Ligura)   M   26
# 221                                             Mpande   M   26
# 222                                        Amanzimtoti   M   26
# 223                    Hollywood Beach, Broward County   M   25
# 224           Morro Rock, Morro Bay, San Obispo County   M   17
# 225                                        Amanzimtoti   M   20
# 226                         Malibu, Los Angeles County   M   43
# 227           Daws Island, Broad River (near Beaufort)   F   33
# 228                            Keaukaha, Hilo, Hawai'i   M   26
# 229     Honoli'i Pali, Hilo Bay ('Alae Point), Hawai'i   M   26
# 230                                           Widenham   M   23
# 231                                              Mnini   M   26
# 234                 Fort Walton Beach, Okaloosa County   M   36
# 235                    Fishing camp, St. Lucia Estuary   M   26
# 236                                         Cape Vidal   M   26
# 237                    St. Petersburg, Pinellas County   M   17
# 238                                          Southport   M   26
# 239                                Sorrento Back Beach   M   26
# 240                                       Warner Beach   M   17
# 241                        Sandy Hook, Monmouth County   M   26
# 242                                            Cervara   M   37
# 243                                             Durban   M   26
# 244                                            Tongaat   M   26
# 245                                      Inhaca Island   F   20
# 247                                  Waimea Bay, O'ahu   M   26
# 248            Kingscliffe Beach, south of Tweed Heads   M   26
# 249                                           Cooktown   M   52
# 337  Aircraft went down on 6/12/1944. He survived o...   M   26
# 338  Victim was on said to be on tanker that collid...   M   26
# 339                      Villa del Mar Beach, Veracruz   M   68
# 340                                                NaN   M   26
# 341        3 miles from shore off McGregor Point, Maui   M   26
# 342                                                NaN   M   26
# 343                                     George’s River   M   18
# 344                                    Parramata River   M   26
# 347                  Cabramatta Creek, George’s River    M   40
# 348                 Lady Martin’s Beach, Sydney Harbor   M   24
# 349                                           Istanbul   M   26
# 350                                     South Cronulla   M   16
# 351                                     Port Melbourne   M   43
# 353                              Main Beach, Southport   M   17
# 354                                         Atherfield   M   26
# 355                              Santa Barbara Channel   M   23
# 356                              Santa Barbara Channel   M   53
# 357                                             Coogee   M   40
# 358                        Seaforth River, near MacKay   M    5
# 359                                             Darwin   M   26
# 360                                          Galveston   M   17
# 361                                      Kahala, O'ahu   M   26
# 362                                                NaN   M   26
# 363                                     Maroubra Beach   M   39
# 364                                       Bashee River   M   17
# 365                                           Tarrafal   F   26
# 367                                          Off shore   M   26
# 368                                                NaN   M   26
# 370                      Casa Antunez Beach, Barcelona   M   26
# 371                                          Fremantle   M   26
# 372                                          Currumbin   M   26
# 373                                     Bellinger Head   M   26
# 374                                 Botany Bay, Sydney   M   26
# 375                                            Bunbury   M   26
# 376                               20 miles from Havana   M   26
# 377                                 Botany Bay, Sydney   M   26
# 378                              Bilgola Beach, Sydney   M   26
# 379           Woodcliff Channel, Freeport, Long Island   M   30
# 380                           Sheepshead Bay, Brooklyn   F   26
# 381                                         Alexandria   M   26
# 382                                              Otaki   M   26
# 384                     St. Augustine, St Johns County   M   26
# 385                            Lavalette, Ocean County   M   26
# 386                       Spring Lake, Monmouth County   F   26
# 387                                             Durban   M   26
# 388                     Pensacola Bay, Escambia County   M   26
# 389                                             Rijeka   M   26
# 390     Off Fort Gaines, Dauphin Island, Mobile County   M   26
# 391                                Pearl Harbor, O'ahu   M   26
# 393                                     Pa'uwela, Maui   F   19
# 394                            Marathon, Monroe County   M   26
# 395                          Aux Cayes (now Les Cayes)   M   26
# 396                                                NaN   M   26
# 397                                        Karra Garra   M   26
# 398                                   Lourenco Marques   M   26
# 399                                       Moodie Beach   M   18
# 400                                    Mototapu Island   M   26
# 401                                          Geraldton   M   26
# 402                                          Port Said   M   26
# 403                                             Naples   M    8
# 404                                             Elwood   M   23
# 405                                             Elwood   M   39
# 407                                          Algoa Bay   M   26
# 408                                             Durban   M   26
# 409                                   Capo Santa Croce   M   20
# 410                                                NaN   M   26
# 411                         Woodstock Beach, Cape Town   M   26
# 412                              Makapu'u Point, O'ahu   M   26
# 413                                          East Cape   M   26
# 414                                          Escalante   M   26
# 415                                          Newcastle   F   13
# 416       St. John's River, Jacksonville, Duval County   M   26
# 417                                             Sydney   M   26
# 419                                   Vera Cruz Harbor   M   26
# 420                                      Havana Harbor   M   26
# 421                        Chimney Point, George’s Bay   M   26
# 422                                      Hampton Roads   M   26
# 423                                     Port Elizabeth   M   26
# 424                                           Honolulu   M   26
# 425                                                NaN   M   26
# 426                       Point Cook, Port Phillip Bay   M   26
# 427                           Hamakua Homakua, Hawai'i   F   26
# 428               Near the mouth of the Clarence River   M   26
# 429                                           Dunedin    M   26
# 430                   Dobroyd Head, Watson Bay, Sydney   M   26
# 431                                        Jamaica Bay   M   26
# 433                            Johnstone's Bay, Sydney   M   26
# 434                     Pensacola Bay, Escambia County   M   18
# 435                                           Acapulco   M   26
# 438                                       Near Sydney    M   26
# 439                                                NaN   M   26
# 440                                             Durban   M   26
# 441                                         Mary River   M   26
# 442                                         Newcastle    M   26
# 443                                                NaN   M   26
# 444                                              Fiume   M   26
# 445                        Levuka Point, Ovalau Island   M   26
# 446                                   Hawkesbury River   M   26
# 447                                           Demerara   M   26
# 449                                  Off De Grey river   M   26
# 450                                       Macao Harbor   M   26
# 452                                 Back Beach, Durban   M   26
# 453                                         Fuengirola   M   26
# 454                     Staten Island, Richmond County   M   26
# 455                     Staten Island, Richmond County   M   26
# 458                      Clark's Island, Sydney Harbor   M   26
# 459                                                NaN   F    1
# 460                                             Sydney   M   26
# 461                                           Cape Cod   M   26
# 463                                                NaN   M   26
# 466                                              Cadiz   M   26
# 467                                              Herøy   M   26
# 469                         Sag Harbor, Suffolk County   M   26
#
#                                                 Injury Fatal Y/N  \
# 0                       Severe injuries to lower limbs         N
# 1    Body found with shark bites. Possible drowning...         Y
# 2                                 Calf severely bitten         N
# 3                                     Left foot bitten         N
# 4                                Death by misadventure         Y
# 5                  Right forearm and left hand injured         N
# 6                             Minor cuts to left thigh         N
# 7                                          Disappeared         N
# 8             Laceration to arm caused by metal object         N
# 9                                                  NaN         N
# 10                   Severe injuries to arms and chest         N
# 11                            Lacerations to lower leg         N
# 12                          Injuries to left lower leg         N
# 13   Single laceration to right thigh inconsistent ...         N
# 14   Autopsy confirmed death by drowning, shark bit...         Y
# 15   Multiple severe injuries to arms and leg, leg ...         N
# 16       FATAL, but death was probably due to drowning         Y
# 17              Lacerations to right ankle, foot & toe         N
# 18       FATAL, but death was probably due to drowning         Y
# 19                            Lacerations to left foot         N
# 20                  Abrasions and cuts to sole of foot         N
# 21                                        Foot injured         N
# 22                 Arm injured by hook, not by a shark         N
# 23   Laceration to thigh, likely caused by surfboar...         N
# 24                    Alleged laceration to left ankle         N
# 25           Laceration & puncture wounds to left foot         N
# 26   Fatal, coroner unable to determine if the dive...         Y
# 27              No attack, shark made a threat display         N
# 28                       Minor injuries to foot & toes         N
# 29                          Cuts to right ankle & foot         N
# 30             Shark breached cage, no injury to diver         N
# 31                            No injury, board damaged         N
# 32   No injury, but sharks repeatedly hit their fin...         N
# 33                                           "Serious"         N
# 34   Fell off board when spinner shark leapt from t...         N
# 35   Minor injury to arm. Possibly caused by smalll...         N
# 36        Minor injury to wrist from Southern stingray         N
# 37                        No injury, knocked off board         N
# 38                              Lower left leg injured         N
# 39                             Left foot bitten by eel         N
# 40                            Wound to right lower leg         N
# 41    Minor injury when he attempted to touch a fish.          N
# 42                                      Injury to hand         N
# 43   2' cut to dorsum of foot, 2 puncture wounds to...         N
# 44                                  Laceration to back         N
# 45   Parallel lacerations to torso inconsistent wit...         N
# 46                            Minor lacerations to leg         N
# 47   FATAL, but shark involvement prior to death un...         Y
# 48   Injury to left thigh from unidentified species...         N
# 49                                Board snapped in two         N
# 50   During his 16-hour swim to shore, he was circl...         N
# 51                        A hoax, no shark involvement         N
# 52   Missing after a dive, shark involvement consid...         N
# 53   No injury. No attack. 12' white shark appeared...         N
# 54               Shark bites may have been post mortem         N
# 55   Injuries to wrist/hand by a mackerel, not a shark         N
# 56   Caribbean reef shark buzzed him. No injury, no...         N
# 57   Puncture wound to torso. Reported as a bite by...         N
# 58   Scrape to right forearm. Frennet says inflicte...         N
# 59            Probable drowning with post-mortem bites         N
# 60                        Shark bites were post-mortem         N
# 61   Disappeared. No evidence that he was taken by ...         N
# 62                      Never happened; it was a  hoax         N
# 63   No injury, a 3 m blue shark merely snapped at ...         N
# 64   Injury to ankle caused  by a stingray, not a s...         N
# 65                                   Laceration to toe         N
# 66                       Shark involvement unconfirmed         N
# 67             Probable drowning with post-mortem bite         N
# 68   Lacerations to 2 fingers, but shark involvemen...         N
# 69   Cause of death was drowning & preceded shark i...         Y
# 70   Laceration to foot. Injured by a stingray, not...         N
# 71          Harassed by sharks but not injured by them         N
# 72                        Bitten on right hand & wrist         N
# 73                              No injury, ski damaged         N
# 74                     Lacerations to lower right leg          N
# 75                                               FATAL         Y
# 76                              Abrasions to left hand         N
# 77   Cause of death may have been drowning; remains...         Y
# ...
# 11     Minor injury       Jul  2019
# 12          Unknown       Jun  2019
# 13     Minor injury       Jul  2018
# 14            Death       Jul  2018
# 15          Unknown       Apr  2018
# 16            Death       Oct  2017
# 17     Minor injury       Sep  2017
# 18            Death       Sep  2017
# 19     Minor injury       Aug  2017
# 20     Minor injury       Jul  2017
# 21          Unknown       Jul  2017
# 22          Unknown       Jun  2017
# 23     Minor injury       May  2017
# 24     Minor injury       Apr  2017
# 25     Minor injury       Apr  2017
# 26            Death       Apr  2017
# 27          Unknown       Jan  2017
# 28          Unknown       Jan  2017
# 29     Minor injury       Dec  2016
# 30        No injury       Oct  2016
# 31        No injury       Jun  2016
# 32        No injury       Jun  2016
# 33          Unknown       Apr  2016
# 34        No injury       Apr  2016
# 35          Unknown       Mar  2016
# 36          Unknown       Feb  2016
# 37        No injury       Feb  2016
# 38          Unknown       Nov  2015
# 39     Minor injury       Oct  2015
# 40          Unknown       Aug  2015
# 41          Unknown       Aug  2015
# 42          Unknown       Jul  2015
# 43          Unknown       Jul  2015
# 44     Minor injury       Jul  2015
# 45     Minor injury       Jul  2015
# 46     Minor injury       Jun  2015
# 47            Death       Mar  2015
# 48     Minor injury       Mar  2015
# 49          Unknown       Jan  2015
# 50          Unknown       Jan  2015
# 51          Unknown       Sep  2014
# 52          Unknown       Jul  2014
# 53        No injury       May  2014
# 54     Minor injury       Mar  2014
# 55          Unknown       Mar  2014
# 56        No injury       Mar  2014
# 57     Minor injury       Aug  2013
# 58          Unknown       Jul  2013
# 59     Minor injury       Jun  2013
# 60     Minor injury       May  2013
# 61          Unknown       Apr  2013
# 386         Unknown       Aug  1913
# 387         Unknown       May  1912
# 388           Death       Nov  1911
# 389           Death       Dec  1910
# 390         Unknown       May  1910
# 391       No injury       Mar  1910
# 393         Unknown       Apr  1909
# 394           Death       May  1908
# 395       No injury       Oct  1907
# 396       No injury       Sep  1907
# 397         Unknown       Jul  1907
# 398         Unknown       Jul  1906
# 399           Death     April  1906
# 400           Death       Feb  1906
# 401         Unknown       Dec  1905
# 402         Unknown       Aug  1905
# 403         Unknown       Jul  1905
# 404         Unknown       Feb  1905
# 405         Unknown       Jan  1905
# 407         Unknown       Apr  1902
# 408       Uncertain       Jan  1902
# 409         Unknown       Jul  1901
# 410         Unknown       Jun  1901
# 411         Unknown       Oct  1900
# 412         Unknown       Jul  1900
# 413           Death       Jun  1899
# 414           Death       May  1899
# 415         Unknown       Jan  1899
# 416         Unknown       Aug  1898
# 417           Death       Jul  1898
# 419         Unknown       Oct  1897
# 420         Unknown       Sep  1895
# 421           Death       Apr  1893
# 422           Death       Jun  1891
# 423           Death       May  1890
# 424         Unknown       Nov  1889
# 425         Unknown       Jul  1888
# 426         Unknown       Jun  1888
# 427    Minor injury       Jun  1886
# 428         Unknown       Apr  1886
# 429   Severe injury       Mar  1886
# 430         Unknown       Mar  1886
# 431         Unknown       Aug  1884
# 433         Unknown       Nov  1881
# 434           Death       Oct  1881
# 435         Unknown       May  1880
# 438         Unknown       Mar  1879
# 439         Unknown       Aug  1877
# 440    Minor injury       Jan  1877
# 441    Minor injury       Jan  1875
# 442           Death       Jun  1873
# 443       No injury       Nov  1872
# 444       No injury       Aug  1872
# 445         Unknown       Jan  1872
# 446         Unknown       Dec  1871
# 447           Death       May  1871
# 449         Unknown       Apr  1866
# 450       No injury       Apr  1864
# 452         Unknown       Feb  1863
# 453       Uncertain       Aug  1862
# 454         Unknown       Aug  1858
# 455         Unknown       Aug  1858
# 458           Death       Dec  1852
# 459           Death       Jul  1952
# 460    Minor injury       Jan  1849
# 461         Unknown       Jul  1848
# 463    Minor injury       Nov  1839
# 466       No injury       Jul  1819
# 467         Unknown       May  1818
# 469         Unknown       Sep  1805

# %%
import plotly.express as px
import plotly.io as pio
# Show in VSCode browser
pio.renderers.default = 'vscode'
# Ensure columns are clean
df.columns = df.columns.str.strip()
# Verify column exists
if 'Injury Severity' not in df.columns:
    raise KeyError("Column 'Injury Severity' not found! Found instead: " + str(df.columns.tolist()))
# Count each injury severity type
injury_counts = df['Injury Severity'].value_counts().reset_index()
injury_counts.columns = ['Injury Severity', 'Count']
# Create bar chart
fig = px.bar(
    injury_counts,
    x='Injury Severity',
    y='Count',
    title='Distribution of Shark Attack Injury Types',
    color='Injury Severity',
    text='Count',
    color_discrete_sequence=px.colors.qualitative.Vivid
)
fig.update_traces(textposition='outside')
fig.update_layout(
    xaxis_title='Injury Type',
    yaxis_title='Number of Attacks',
    template='plotly_white',
    showlegend=False
)
fig.show()

# %%
import plotly.express as px
import plotly.io as pio
import pandas as pd
# Set renderer (VS Code opens in browser, Jupyter use 'notebook')
pio.renderers.default = 'vscode'
# Ensure Year is numeric
df['YYYY'] = pd.to_numeric(df['YYYY'], errors='coerce')
# Drop rows with missing year values
df = df.dropna(subset=['YYYY'])
# Count number of shark attacks per year
attacks_per_year = df.groupby('YYYY').size().reset_index(name='Count')
# Sort by year (important for line continuity)
attacks_per_year = attacks_per_year.sort_values('YYYY')
# Create line chart
fig = px.line(
    attacks_per_year,
    x='YYYY',
    y='Count',
    title='Shark Attack Victims Over the Years',
    markers=True,
    line_shape='spline',  # smooth line
    color_discrete_sequence=px.colors.qualitative.Plotly
)
#  chart
fig.update_traces(line=dict(width=3))
fig.update_layout(
    xaxis_title='Year',
    yaxis_title='Number of Shark Attacks',
    template='plotly_white',
    hovermode='x unified'
)
fig.show()

# %%
df['YYYY'].unique()
# Out:
# array([2023, 2022, 2021, 2020, 2019, 2018, 2017, 2016, 2015, 2014, 2013,
#        2012, 2011, 2010, 2009, 2008, 2007, 2006, 2005, 2004, 2003, 2002,
#        2001, 2000, 1999, 1998, 1997, 1996, 1995, 1994, 1993, 1992, 1991,
#        1990, 1989, 1988, 1987, 1986, 1985, 1984, 1983, 1982, 1981, 1980,
#        1979, 1978, 1977, 1976, 1975, 1972, 1970, 1969, 1968, 1967, 1966,
#        1965, 1964, 1963, 1962, 1961, 1960, 1959, 1958, 1954, 1953, 1952,
#        1951, 1950, 1949, 1947, 1944, 1943, 1942, 1941, 1939, 1938, 1937,
#        1936, 1935, 1933, 1932, 1931, 1930, 1929, 1928, 1926, 1924, 1923,
#        1922, 1920, 1916, 1915, 1914, 1913, 1912, 1911, 1910, 1909, 1908,
#        1907, 1906, 1905, 1902, 1901, 1900, 1899, 1898, 1897, 1895, 1893,
#        1891, 1890, 1889, 1888, 1886, 1884, 1881, 1880, 1879, 1877, 1875,
#        1873, 1872, 1871, 1866, 1864, 1863, 1862, 1858, 1852, 1849, 1848,
#        1839, 1819, 1818, 1805])

# %%
import pandas as pd
import numpy as np
import re
# Clean the MM from ‘NaN’ and ‘None’
df = df[df["MM"].notna() & (df["MM"] != "")]
# Replace full month names with abbreviations
df["MM"] = df["MM"].replace({
    "November": "Nov",
    "April": "Apr"
})
df['MM'].unique()
# Out:
# array(['Aug', 'Jun', 'Mar', 'Feb', 'Nov', 'Oct', 'Sep', 'Jul', 'Apr',
#        'May', 'Jan', 'Dec'], dtype=object)

# %%
month_map = {
    'Jan': 1, 'January': 1,
    'Feb': 2, 'February': 2,
    'Mar': 3, 'March': 3,
    'Apr': 4, 'April': 4,
    'May': 5,
    'Jun': 6, 'June': 6,
    'Jul': 7, 'July': 7,
    'Aug': 8, 'August': 8,
    'Sep': 9, 'Sept': 9, 'September': 9,
    'Oct': 10, 'October': 10,
    'Nov': 11, 'November': 11,
    'Dec': 12, 'December': 12
}
df['Month_Num'] = df['MM'].map(month_map)
df = df.dropna(subset=['Month_Num'])
attacks_by_month = df.groupby(['Month_Num', 'MM']).size().reset_index(name='Count')
attacks_by_month = attacks_by_month.sort_values('Month_Num')
import plotly.express as px
import plotly.io as pio
pio.renderers.default = 'vscode'
fig = px.line(
    attacks_by_month,
    x='MM',
    y='Count',
    title='Shark Attacks by Month',
    markers=True,
    line_shape='spline',
    color_discrete_sequence=px.colors.qualitative.Vivid
)
fig.update_traces(line=dict(width=3))
fig.update_layout(
    xaxis_title='Month',
    yaxis_title='Number of Shark Attacks',
    template='plotly_white',
    hovermode='x unified'
)
fig.show()

# %%
# High frequency of shark attacks per month is equal or above 45
# Low frequency of shark attacks per month is under 45
# holidays around four months Jan, Apr, Jul, Aug
# Jan = Chrismas & holiday in south africa as summer
# Apr = Easter & Pack
# Jul & Aug = summer holiday for the northen hemestphere mainly USA*

# %%
pip install pandas requests scikit-learn
# Out:
# Requirement already satisfied: pandas in c:\users\sboub\anaconda3\lib\site-packages (2.2.3)
# Requirement already satisfied: requests in c:\users\sboub\anaconda3\lib\site-packages (2.32.3)
# Requirement already satisfied: scikit-learn in c:\users\sboub\anaconda3\lib\site-packages (1.6.1)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\sboub\anaconda3\lib\site-packages (from pandas) (2.3.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\sboub\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\sboub\anaconda3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\sboub\anaconda3\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\sboub\anaconda3\lib\site-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sboub\anaconda3\lib\site-packages (from requests) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\sboub\anaconda3\lib\site-packages (from requests) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sboub\anaconda3\lib\site-packages (from requests) (2025.10.5)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\sboub\anaconda3\lib\site-packages (from scikit-learn) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\sboub\anaconda3\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\sboub\anaconda3\lib\site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: six>=1.5 in c:\users\sboub\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import requests
import time
from sklearn.neighbors import BallTree

RAW_FILE = "../data/raw.csv"   # your file
OVERPASS_URL = "https://overpass-api.de/api/interpreter"
EARTH_RADIUS_KM = 6371.0088

COUNTRIES = {
    "United States": ["United States", "USA", "U.S.A.", "United States of America"],
    "Australia": ["Australia"],
    "South Africa": ["South Africa", "Republic of South Africa"]
}

def load_data(path):
    df = pd.read_csv(path, low_memory=False)
    # Normalize column names
    df = df.rename(columns={
        'lat': 'Latitude', 'latitude': 'Latitude',
        'lon': 'Longitude', 'long': 'Longitude'
    })
    df["Latitude"] = pd.to_numeric(df.get("Latitude"), errors="coerce")
    df["Longitude"] = pd.to_numeric(df.get("Longitude"), errors="coerce")
    return df

def query_hospitals(country):
    query = f"""
    [out:json][timeout:180];
    area["name"="{country}"]["boundary"="administrative"];
    (
      node["amenity"="hospital"](area);
      way["amenity"="hospital"](area);
      relation["amenity"="hospital"](area);
    );
    out center;
    """
    r = requests.post(OVERPASS_URL, data={"data": query})
    data = r.json()
    out = []
    for el in data["elements"]:
        lat = el.get("lat") or (el.get("center") or {}).get("lat")
        lon = el.get("lon") or (el.get("center") or {}).get("lon")
        if lat and lon:
            name = el.get("tags", {}).get("name") or "Unnamed Hospital"
            out.append([name, float(lat), float(lon)])
    time.sleep(1)
    return pd.DataFrame(out, columns=["name", "lat", "lon"])

def match_country(df, patterns):
    return df[df["Country"].str.contains('|'.join(patterns), case=False, na=False)]

def find_nearest(df, hospitals):
    tree = BallTree(np.radians(hospitals[["lat","lon"]]), metric="haversine")
    coords = np.radians(df[["Latitude","Longitude"]])
    dist, idx = tree.query(coords, k=1)
    df["Nearest_Hospital"] = hospitals.iloc[idx.flatten()]["name"].values
    df["Hospital_Lat"] = hospitals.iloc[idx.flatten()]["lat"].values
    df["Hospital_Lon"] = hospitals.iloc[idx.flatten()]["lon"].values
    df["Distance_km"] = dist.flatten() * EARTH_RADIUS_KM
    return df

def main():
    df = load_data(RAW_FILE)
    results = []

    for country, patterns in COUNTRIES.items():
        print(f"\n▶ Processing {country}...")
        sub = match_country(df, patterns).dropna(subset=["Latitude","Longitude"])
        if sub.empty:
            print(f"No incidents found for {country}.")
            continue

        hosp = query_hospitals(country)
        if hosp.empty:
            print(f"No hospitals found in OSM for {country}.")
            continue

        result = find_nearest(sub, hosp)
        outname = f"nearest_hospitals_{country.replace(' ','')}.csv"
        result.to_csv(outname, index=False)
        print(f"Saved: {outname}")
        results.append(result)

    if results:
        combined = pd.concat(results)
        combined.to_csv("nearest_hospitals_combined.csv", index=False)
        print("\n✅ Saved: nearest_hospitals_combined.csv")

if __name__ == "__main__":
    main()
# Out:
# ▶ Processing United States...
# No incidents found for United States.
#
# ▶ Processing Australia...
# No incidents found for Australia.
#
# ▶ Processing South Africa...
# No incidents found for South Africa.

# %%
import pandas as pd

# Load the CSV
hospital_url = 'https://docs.google.com/spreadsheets/d/1TpMOEG-ueS2SXMaecsPqOo3113cvvMMi_nL8-yX2yiw/export?format=csv'
df_us_hospitals = pd.read_csv(hospital_url)
df_us_hospitals.head(3)
# Out:
#              X            Y  FID        ID  \
# 0 -13318894.76  4346975.444    1   5793230
# 1 -13226507.27  4049625.553    2  53391362
# 2 -13156201.05  4031977.723    3  11190023
#
#                                                 NAME                  ADDRESS  \
# 0                    CENTRAL VALLEY GENERAL HOSPITAL  1025 NORTH DOUTY STREET
# 1  LOS ROBLES HOSPITAL & MEDICAL CENTER - EAST CA...           150 VIA MERIDA
# 2                  EAST LOS ANGELES DOCTORS HOSPITAL  4060 WHITTIER BOULEVARD
#
#               CITY STATE    ZIP           ZIP4      TELEPHONE  \
# 0          HANFORD    CA  93230  NOT AVAILABLE  NOT AVAILABLE
# 1  WESTLAKE VILAGE    CA  91362  NOT AVAILABLE  NOT AVAILABLE
# 2      LOS ANGELES    CA  90023  NOT AVAILABLE  NOT AVAILABLE
#
#                  TYPE  STATUS  POPULATION       COUNTY COUNTYFIPS COUNTRY  \
# 0  GENERAL ACUTE CARE  CLOSED          49        KINGS       6031     USA
# 1  GENERAL ACUTE CARE    OPEN          62      VENTURA       6111     USA
# 2  GENERAL ACUTE CARE    OPEN         127  LOS ANGELES       6037     USA
#
#     LATITUDE   LONGITUDE  NAICS_CODE                              NAICS_DESC  \
# 0  36.336159 -119.645667      622110  GENERAL MEDICAL AND SURGICAL HOSPITALS
# 1  34.154939 -118.815736      622110  GENERAL MEDICAL AND SURGICAL HOSPITALS
# 2  34.023647 -118.184165      622110  GENERAL MEDICAL AND SURGICAL HOSPITALS
#
#                                               SOURCE           SOURCEDATE  \
# 0  http://www.oshpd.ca.gov/hid/facility-listing.html  2016/02/04 00:00:00
# 1  http://www.oshpd.ca.gov/hid/facility-listing.html  2019/08/02 00:00:00
# 2  http://www.oshpd.ca.gov/hid/facility-listing.html  2019/08/02 00:00:00
#
#       VAL_METHOD             VAL_DATE                           WEBSITE  \
# 0  IMAGERY/OTHER  2014/02/10 00:00:00      http://www.hanfordhealth.com
# 1  IMAGERY/OTHER  2014/02/10 00:00:00  http://www.losrobleshospital.com
# 2  IMAGERY/OTHER  2014/02/10 00:00:00             http://www.elalax.com
#
#         STATE_ID       ALT_NAME  ST_FIPS        OWNER  TTL_STAFF  BEDS  \
# 386                         Spring Lake, Monmouth County
# 387                                               Durban
# 388                       Pensacola Bay, Escambia County
# 389                                               Rijeka
# 390       Off Fort Gaines, Dauphin Island, Mobile County
# 391                                  Pearl Harbor, O'ahu
# 393                                       Pa'uwela, Maui
# 394                              Marathon, Monroe County
# 395                            Aux Cayes (now Les Cayes)
# 396                                                  NaN
# 397                                          Karra Garra
# 398                                     Lourenco Marques
# 399                                         Moodie Beach
# 400                                      Mototapu Island
# 401                                            Geraldton
# 402                                            Port Said
# 403                                               Naples
# 404                                               Elwood
# 405                                               Elwood
# 407                                            Algoa Bay
# 408                                               Durban
# 409                                     Capo Santa Croce
# 410                                                  NaN
# 411                           Woodstock Beach, Cape Town
# 412                                Makapu'u Point, O'ahu
# 413                                            East Cape
# 414                                            Escalante
# 415                                            Newcastle
# 416         St. John's River, Jacksonville, Duval County
# 417                                               Sydney
# 419                                     Vera Cruz Harbor
# 420                                        Havana Harbor
# 421                          Chimney Point, George’s Bay
# 422                                        Hampton Roads
# 423                                       Port Elizabeth
# 424                                             Honolulu
# 425                                                  NaN
# 426                         Point Cook, Port Phillip Bay
# 427                             Hamakua Homakua, Hawai'i
# 428                 Near the mouth of the Clarence River
# 429                                             Dunedin
# 430                     Dobroyd Head, Watson Bay, Sydney
# 431                                          Jamaica Bay
# 433                              Johnstone's Bay, Sydney
# 434                       Pensacola Bay, Escambia County
# 435                                             Acapulco
# 438                                         Near Sydney
# 439                                                  NaN
# 440                                               Durban
# 441                                           Mary River
# 442                                           Newcastle
# 443                                                  NaN
# 444                                                Fiume
# 445                          Levuka Point, Ovalau Island
# 446                                     Hawkesbury River
# 447                                             Demerara
# 449                                    Off De Grey river
# 450                                         Macao Harbor
# 452                                   Back Beach, Durban
# 453                                           Fuengirola
# 454                       Staten Island, Richmond County
# 455                       Staten Island, Richmond County
# 458                        Clark's Island, Sydney Harbor
# 459                                                  NaN
# 460                                               Sydney
# 461                                             Cape Cod
# 463                                                  NaN
# 466                                                Cadiz
# 467                                                Herøy
# 469                           Sag Harbor, Suffolk County
# Name: Location, dtype: object

# %%
# !pip install geopy
# Out:
# Collecting geopy
#   Downloading geopy-2.4.1-py3-none-any.whl.metadata (6.8 kB)
# Collecting geographiclib<3,>=1.52 (from geopy)
#   Downloading geographiclib-2.1-py3-none-any.whl.metadata (1.6 kB)
# Downloading geopy-2.4.1-py3-none-any.whl (125 kB)
# Downloading geographiclib-2.1-py3-none-any.whl (40 kB)
# Installing collected packages: geographiclib, geopy
#
#    -------------------- ------------------- 1/2 [geopy]
#    -------------------- ------------------- 1/2 [geopy]
#    ---------------------------------------- 2/2 [geopy]
#
# Successfully installed geographiclib-2.1 geopy-2.4.1

# %%
import pandas as pd
from geopy.geocoders import Nominatim
from geopy.distance import geodesic

# Load hospital CSV
hospital_url = 'https://docs.google.com/spreadsheets/d/1TpMOEG-ueS2SXMaecsPqOo3113cvvMMi_nL8-yX2yiw/export?format=csv'
df_hospitals = pd.read_csv(hospital_url)

# Sample beach list
beaches = [
    "Lighthouse Beach, Port Macquarie",
    "Saunders Beach, Nassau",
    "Shark Junction",
    "Playa Del Coco"
]

# Initialize geolocator
geolocator = Nominatim(user_agent="beach_hospital_locator")

# Function to get coordinates
def get_coords(place):
    try:
        location = geolocator.geocode(place)
        if location:
            return (location.latitude, location.longitude)
    except:
        return None

# Get coordinates for beaches
beach_coords = {beach: get_coords(beach) for beach in beaches}

# Get coordinates for hospitals
df_hospitals['coords'] = df_hospitals.apply(lambda row: get_coords(f"{row['Hospital Name']}, {row['City']}, {row['State']}"), axis=1)

# Find nearest hospital for each beach
nearest_hospitals = {}

for beach, b_coord in beach_coords.items():
    if b_coord is None:
        nearest_hospitals[beach] = None
        continue
    
    min_dist = float('inf')
    nearest = None
    for idx, h_coord in df_hospitals['coords'].iteritems():
        if h_coord is None:
            continue
        dist = geodesic(b_coord, h_coord).kilometers
        if dist < min_dist:
            min_dist = dist
            nearest = df_hospitals.loc[idx, 'Hospital Name']
    nearest_hospitals[beach] = nearest

# Show results
nearest_hospitals
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\sboub\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Hospital Name'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[3419], line 33
#      30 beach_coords = {beach: get_coords(beach) for beach in beaches}
#      32 # Get coordinates for hospitals
# ---> 33 df_hospitals['coords'] = df_hospitals.apply(lambda row: get_coords(f"{row['Hospital Name']}, {row['City']}, {row['State']}"), axis=1)
#      35 # Find nearest hospital for each beach
#      36 nearest_hospitals = {}
#
# File c:\Users\sboub\anaconda3\Lib\site-packages\pandas\core\frame.py:10374, in DataFrame.apply(self, func, axis, raw, result_type, args, by_row, engine, engine_kwargs, **kwargs)
#   10360 from pandas.core.apply import frame_apply
#   10362 op = frame_apply(
#   10363     self,
#   10364     func=func,
#    (...)
#   10372     kwargs=kwargs,
#   10373 )
# > 10374 return op.apply().__finalize__(self, method="apply")
#
# File c:\Users\sboub\anaconda3\Lib\site-packages\pandas\core\apply.py:916, in FrameApply.apply(self)
#     913 elif self.raw:
#     914     return self.apply_raw(engine=self.engine, engine_kwargs=self.engine_kwargs)
# --> 916 return self.apply_standard()
#
# File c:\Users\sboub\anaconda3\Lib\site-packages\pandas\core\apply.py:1063, in FrameApply.apply_standard(self)
#    1061 def apply_standard(self):
#    1062     if self.engine == "python":
# -> 1063         results, res_index = self.apply_series_generator()
#    1064     else:
#    1065         results, res_index = self.apply_series_numba()
#
# File c:\Users\sboub\anaconda3\Lib\site-packages\pandas\core\apply.py:1081, in FrameApply.apply_series_generator(self)
#    1078 with option_context("mode.chained_assignment", None):
#    1079     for i, v in enumerate(series_gen):
#    1080         # ignore SettingWithCopy here in case the user mutates
# -> 1081         results[i] = self.func(v, *self.args, **self.kwargs)
#    1082         if isinstance(results[i], ABCSeries):
#    1083             # If we have a view on v, we need to make a copy because
#    1084             #  series_generator will swap out the underlying data
#    1085             results[i] = results[i].copy(deep=False)
#
# Cell In[3419], line 33, in <lambda>(row)
#      30 beach_coords = {beach: get_coords(beach) for beach in beaches}
#      32 # Get coordinates for hospitals
# ---> 33 df_hospitals['coords'] = df_hospitals.apply(lambda row: get_coords(f"{row['Hospital Name']}, {row['City']}, {row['State']}"), axis=1)
#      35 # Find nearest hospital for each beach
#      36 nearest_hospitals = {}
#
# File c:\Users\sboub\anaconda3\Lib\site-packages\pandas\core\series.py:1121, in Series.__getitem__(self, key)
#    1118     return self._values[key]
#    1120 elif key_is_scalar:
# -> 1121     return self._get_value(key)
#    1123 # Convert generator to list before going through hashable part
#    1124 # (We will iterate through the generator there to check for slices)
#    1125 if is_iterator(key):
#
# File c:\Users\sboub\anaconda3\Lib\site-packages\pandas\core\series.py:1237, in Series._get_value(self, label, takeable)
#    1234     return self._values[label]
#    1236 # Similar to Index.get_value, but we do not fall back to positional
# -> 1237 loc = self.index.get_loc(label)
#    1239 if is_integer(loc):
#    1240     return self._values[loc]
#
# File c:\Users\sboub\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'Hospital Name'

# %%
import pandas as pd
from geopy.geocoders import Nominatim
from geopy.distance import geodesic
import time

# Load hospital CSV
hospital_url = 'https://docs.google.com/spreadsheets/d/1TpMOEG-ueS2SXMaecsPqOo3113cvvMMi_nL8-yX2yiw/export?format=csv'
df_hospitals = pd.read_csv(hospital_url)

# Strip any extra spaces from column names
df_hospitals.columns = df_hospitals.columns.str.strip()
print("Hospital columns:", df_hospitals.columns)

# Replace these with the correct column names from your CSV
hospital_name_col = df_hospitals.columns[0]  # Usually the first column is hospital name
city_col = df_hospitals.columns[1]           # Usually the second column is city
state_col = df_hospitals.columns[2]          # Usually the third column is state

# Sample beach list (replace with your full list)
beaches = [
    "Lighthouse Beach, Port Macquarie",
    "Saunders Beach, Nassau",
    "Shark Junction",
    "Playa Del Coco"
]

# Initialize geolocator
geolocator = Nominatim(user_agent="beach_hospital_locator")

# Function to get coordinates (with retry for reliability)
def get_coords(place):
    try:
        location = geolocator.geocode(place, timeout=10)
        if location:
            return (location.latitude, location.longitude)
    except:
        time.sleep(1)
        return get_coords(place)
    return None

# Get coordinates for beaches
beach_coords = {beach: get_coords(beach) for beach in beaches}

# Get coordinates for hospitals
df_hospitals['coords'] = df_hospitals.apply(
    lambda row: get_coords(f"{row[hospital_name_col]}, {row[city_col]}, {row[state_col]}"), axis=1
)

# Find nearest hospital for each beach
nearest_hospitals = {}

for beach, b_coord in beach_coords.items():
    if b_coord is None:
        nearest_hospitals[beach] = None
        continue
    
    min_dist = float('inf')
    nearest = None
    for idx, h_coord in df_hospitals['coords'].iteritems():
        if h_coord is None:
            continue
        dist = geodesic(b_coord, h_coord).kilometers
        if dist < min_dist:
            min_dist = dist
            nearest = df_hospitals.loc[idx, hospital_name_col]
    nearest_hospitals[beach] = nearest

# Convert to DataFrame for easy export
df_results = pd.DataFrame(list(nearest_hospitals.items()), columns=['Beach', 'Nearest Hospital'])
print(df_results)
# Optionally save to CSV
df_results.to_csv("nearest_hospitals.csv", index=False)
# Out:
# Hospital columns: Index(['X', 'Y', 'FID', 'ID', 'NAME', 'ADDRESS', 'CITY', 'STATE', 'ZIP',
#        'ZIP4', 'TELEPHONE', 'TYPE', 'STATUS', 'POPULATION', 'COUNTY',
#        'COUNTYFIPS', 'COUNTRY', 'LATITUDE', 'LONGITUDE', 'NAICS_CODE',
#        'NAICS_DESC', 'SOURCE', 'SOURCEDATE', 'VAL_METHOD', 'VAL_DATE',
#        'WEBSITE', 'STATE_ID', 'ALT_NAME', 'ST_FIPS', 'OWNER', 'TTL_STAFF',
#        'BEDS', 'TRAUMA', 'HELIPAD'],
#       dtype='object')
