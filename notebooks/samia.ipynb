# %% [markdown]
# # PROJECT 02 : SHARK ATTACKS
# -----

# %% [markdown]
# ### BRIEF : data analysis of global shark attacks for a business idea
# You will initially examine the Shark Attack dataset, understanding its structure and formulating a hypothesis or several hypotheses about the data.
#  We hypothesize that shark attacks are more common in certain locations and peak during specific months.
# We define a Business Case, such as
#
# * “As a company that sells medical products, I want to identify destinations with high shark attack rates.”
# * “As a company providing supply transportation services, I want to know when and where shark attacks peak to plan the safe transport of medical supplies to hospitals.”
#
#  Throughout the project, we will use Python and the pandas library to apply at least five data cleaning techniques to handle missing values, duplicates, and formatting inconsistencies. After cleaning, we will perform basic exploratory data analysis to validate our hypotheses and extract insights.
#
# #### 📝 BUSINESS IDEA — 3 Bullet Points
#
# * Problem to Solve: Coastal hospitals and emergency response teams are not always prepared with the right medical supplies during periods of high shark-attack frequency. This business solves the problem by predicting when and where attacks are most likely, so medical supplies can be stocked in advance.
#
# * Business Concept: Use historical shark attack data to create global heatmaps and seasonal risk forecasts. Then provide pharmaceutical products (painkillers, antibiotics, blood bags, emergency kits) and transportation support to hospitals and ambulances near high-risk beaches.
#
# * Data Used to Profit: The business will analyze Country, Date/Month, Gender, Age, Fatality, and Type of Injury to identify high-risk locations, peak attack months, and most common injury types. This allows optimized supply production, targeted sales, and efficient delivery to the areas that need it most.

# %% [markdown]
# ## 🌀COLUMNS TO CLEAN :
# -----
#
# **- COUNTRY (global comparison between countries to invest in more)** @Blanca
#
#     * we just take the country column and make sure every country name is accurately named
#     * We are gonna check the column of COUNTRY and make sure every country name is correct
#     * We remove NULL COUNTRY data rows that dont have any country
#     * We need to make sure that the name of COUNTRY  is capitalized and written the same way for example :
#         United States of Amercia == USA == US
#         it has to have the same name and consistent!
#
# **- DATE ( MONTH + YEAR )** @Blanca
#
#     * split the date into day - month columns and only use month column
#     * interpret months which have shark attacks happen the most
#
# **- GENDER ( F or M )** @Cecilia
#
#     * We check unique values and make it so it is only two values F or M and deleted all rows that have other values
#     * we noticed mostly M get attacked
#     * percentages Male to Female victims
#     * We remove NULL DATE data rows that dont have a date or that the date doesnt include a month and a year
#     * We are gonna check the column of DATE and seperate it into three columns DAY + MONTH + YEAR
#     * We verify that the new YEAR column matches with the old YEAR column and keep the ones that match
#         * NEW YEAR COLUMN is the one split from the DATE column
#         * OLD YEAR COLUMN is the one already existing in the original sheet
#     * Once we finish comparing the new YEAR column vs old YEAR column and we find them not matching on some data rows. we remove the none matching ones so we keep clean data of accurate years
#     * We remove the DAY and OLD YEAR columns
#     * We are gonna keep the MONTH and matching YEAR
#
# **- AGE (victims age ranges)** @Samia
#
#     * majority of victims survive
#     * we split the age groups into three categories (minors under 18 / adults 18-40 and 40+)
#     * keep in mind complications depending on age when getting treated
#     * percentages of victims based on age ranges
#     * we split the age groups into three categories (minors under 18 / adults 18-40 and elders 40+)
#     * note that there are complications depending on age
#
# **- FATALITY ( Y or N )** @Cecilia
#     * depends on the column 'Type' of injury and if it includes death or high severity
#     * mostly survived
#     * for the pharamaceutical logistics & transportation of injured people to the hospital
#     * assumption we have a percentage of survivals highest and we use it to sell for the
#     * We check unique values and make sure it is only two values Y or N and deleted all rows that have other values
#     * assumption we have a high percentage of survivals and we use it to sell the idea to profit from selling products to hospitals
#
# **- INJURY TYPE** @Samia
#
#     * clean the type of injury by severity
#     * seperate the injury type into different severity
#     * seperate the injury type into different body parts
#     * treatment depends on type of injury and thus the supplies as well
#
# -------

# %% [markdown]
# ### IMPORT UTILS and INIT from SRC

# %%
import sys, os
sys.path.append(os.path.abspath(".."))
from src import utils
from src import init

# %% [markdown]
# -----
# ### GENERAL

# %%
import pandas as pd

# Load the CSV
url = 'https://drive.google.com/uc?export=download&id=1ZRuzHohahE54BC7hKcA289tyuL9cp7-h'
df = pd.read_csv(url)
df.head(3)
# Out:
#           Date    Year          Type    Country                   State  \
# 0  25 Aug 2023  2023.0    Unprovoked  AUSTRALIA         New South Wales
# 1  21 Aug-2023  2023.0  Questionable    BAHAMAS  New Providence   Isoad
# 2  07-Jun-2023  2023.0    Unprovoked    BAHAMAS                Freeport
#
#                             Location      Activity         Name Sex    Age  \
# 0  Lighthouse Beach, Port Macquarie        Surfing    Toby Begg   M     44
# 1             Saunders Beach, Nassau           NaN         male   M  20/30
# 2                     Shark Junction  Scuba diving  Heidi Ernst   F     73
#
#                                               Injury  Fatal Y/N     Time  \
# 0                     Severe injuries to lower limbs        NaN    10h00
# 1  Body found with shark bites. Possible drowning...        NaN  Morning
# 2                               Calf severely bitten        NaN    13h00
#
#                 Species                            Source
# 0  White shark, 3.8-4.2m  B. Myatt, & M. Michaelson, GSAF
# 1                    NaN           The Tribune, 8/21/2023
# 2  Caribbean rreef shark                J. Marchand, GSAF

# %%
# Option 1: Display the entire DataFrame (all rows and columns)
pd.set_option('display.max_rows', None)      # Show all rows
pd.set_option('display.max_columns', None)   # Show all columns

#the full table
#print(df)

# %%
df.info()
# change type of each serie
# year into int or split it from Date
# Age into int
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 561 entries, 0 to 560
# Data columns (total 15 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       561 non-null    object
#  1   Year       560 non-null    float64
#  2   Type       557 non-null    object
#  3   Country    556 non-null    object
#  4   State      508 non-null    object
#  5   Location   503 non-null    object
#  6   Activity   433 non-null    object
#  7   Name       502 non-null    object
#  8   Sex        480 non-null    object
#  9   Age        238 non-null    object
#  10  Injury     553 non-null    object
#  11  Fatal Y/N  0 non-null      float64
#  12  Time       157 non-null    object
#  13  Species    526 non-null    object
#  14  Source     556 non-null    object
# dtypes: float64(2), object(13)
# memory usage: 65.9+ KB

# %%
print("\nData Frame SHAPE", df.shape)

print("\nData Columns")
df.columns
# Out:
# Data Frame SHAPE (561, 15)
#
# Data Columns
# Index(['Date', 'Year', 'Type', 'Country', 'State', 'Location', 'Activity',
#        'Name', 'Sex', 'Age', 'Injury', 'Fatal Y/N', 'Time', 'Species ',
#        'Source'],
#       dtype='object')

# %% [markdown]
# -----
# ### 'Country' CLEANING

# %%
df.columns
# Out:
# Index(['Date', 'Year', 'Type', 'Country', 'State', 'Location', 'Activity',
#        'Name', 'Sex', 'Age', 'Injury', '
# 521                     AUSTRALIA
# 522                        AZORES
# 523                       CROATIA
# 524                          Fiji
# 525                     AUSTRALIA
# 526                        GUYANA
# 527                     AUSTRALIA
# 528                           NaN
# 529                     AUSTRALIA
# 530                         CHINA
# 531                     AUSTRALIA
# 532                  SOUTH AFRICA
# 533                   NEW ZEALAND
# 534                         SPAIN
# 535                           USA
# 536                           USA
# 537                     AUSTRALIA
# 538                           USA
# 539                     AUSTRALIA
# 540                ATLANTIC OCEAN
# 541                     AUSTRALIA
# 542                           USA
# 543                           USA
# 544                     AUSTRALIA
# 545                           USA
# 546                         SPAIN
# 547                     AUSTRALIA
# 548                       ENGLAND
# 549                       JAMAICA
# 550                         SPAIN
# 551                        NORWAY
# 552                       ANTIGUA
# 553                           USA
# 554                           USA
# 555                        FRANCE
# 556                       ICELAND
# 557                        ROATAN
# 558                        GUINEA
# 559                     AUSTRALIA
# 560                           USA
# Name: Country, dtype: object

# %%
df['Country'].nunique()
df['Country'].unique()
# Out:
# array(['AUSTRALIA', 'BAHAMAS', 'SEYCHELLES', 'ARGENTINA', 'COSTA RICA',
#        'BRAZIL', 'EGYPT', 'FRENCH POLYNESIA', 'USA', 'COLOMBIA',
#        'SOUTH AFRICA', 'SPAIN', 'COMOROS', 'MEXICO', 'CAPE VERDE',
#        'CAYMAN ISLANDS', 'ITALY', nan, 'JAMAICA', 'TRINIDAD & TOBAGO',
#        'CANADA', 'CROATIA', 'SAUDI ARABIA', 'ANTIGUA',
#        'UNITED ARAB EMIRATES (UAE)', 'GUAM', 'NEVIS', 'JAPAN',
#        'NEW ZEALAND', 'BRITISH VIRGIN ISLANDS', 'SENEGAL', 'BELIZE',
#        'Seychelles', 'LIBERIA', 'HONDURAS', 'SRI LANKA', 'INDONESIA',
#        'NEW CALEDONIA', 'MADAGASCAR', 'MALAYSIA', 'TONGA', 'BERMUDA',
#        'MONTENEGRO', 'SOMALIA', 'GREECE', 'MOZAMBIQUE',
#        'PAPUA NEW GUINEA', 'TANZANIA', 'PANAMA', 'PHILIPPINES',
#        'ATLANTIC OCEAN', 'JOHNSTON ISLAND', 'MARSHALL ISLANDS',
#        'CARIBBEAN SEA', 'TURKEY', 'CUBA', 'GUATEMALA',
#        'NORTH ATLANTIC OCEAN', 'NORTH PACIFIC OCEAN', 'PACIFIC OCEAN',
#        'INDIAN OCEAN', 'UNITED KINGDOM', 'ISRAEL', 'ITALY / CROATIA',
#        'INDIA', 'HAITI', 'ENGLAND', 'YEMEN ', 'CRETE', 'FRANCE', 'SYRIA',
#        'AZORES', 'Fiji', 'GUYANA', 'CHINA', 'NORWAY', 'ICELAND', 'ROATAN',
#        'GUINEA'], dtype=object)

# %%
import pandas as pd

# Assume df is already loaded
# COUNTRY CLEANING
df = df.dropna(subset=["Country"])
df["Country"] = df["Country"].str.strip().str.title()

country_replacements = {
    "United States Of America": "USA",
    "Usa": "USA",
    "Us": "USA",
    "U.s.": "USA",
    "United Kingdom": "UK",
    "England": "UK",
    "Uk": "UK",
    "Brasil": "Brazil",
    "México": "Mexico",
    "United Arab Emirates (Uae)": "UAE",
    "Turkey": "Türkiye"
}

df["Country"] = df["Country"].replace(country_replacements)
df = df[df["Country"] != "Italy / Croatia"]

# Show stats about the Country column
print(df["Country"].describe())

# Save 'Country' CLEANED to CSV
df.to_csv("../data/interim/1_interim_country.csv", index=False)
print("STEP 1 : 'Country' Data cleaned and CSV saved successfully!")
# Out:
# count     555
# unique     75
# top       USA
# freq      191
# Name: Country, dtype: object
# STEP 1 : 'Country' Data cleaned and CSV saved successfully!

# %%
# Load the CSV to df_country
url = "../data/interim/1_interim_country.csv"
df_country = pd.read_csv(url)
df_country['Country'].unique()
# Out:
# array(['Australia', 'Bahamas', 'Seychelles', 'Argentina', 'Costa Rica',
#        'Brazil', 'Egypt', 'French Polynesia', 'USA', 'Colombia',
#        'South Africa', 'Spain', 'Comoros', 'Mexico', 'Cape Verde',
#        'Cayman Islands', 'Italy', 'Jamaica', 'Trinidad & Tobago',
#        'Canada', 'Croatia', 'Saudi Arabia', 'Antigua', 'UAE', 'Guam',
#        'Nevis', 'Japan', 'New Zealand', 'British Virgin Islands',
#        'Senegal', 'Belize', 'Liberia', 'Honduras', 'Sri Lanka',
#        'Indonesia', 'New Caledonia', 'Madagascar', 'Malaysia', 'Tonga',
#        'Bermuda', 'Montenegro', 'Somalia', 'Greece', 'Mozambique',
#        'Papua New Guinea', 'Tanzania', 'Panama', 'Philippines',
#        'Atlantic Ocean', 'Johnston Island', 'Marshall Islands',
#        'Caribbean Sea', 'Türkiye', 'Cuba', 'Guatemala',
#        'North Atlantic Ocean', 'North Pacific Ocean', 'Pacific Ocean',
#        'Indian Ocean', 'UK', 'Israel', 'India', 'Haiti', 'Yemen', 'Crete',
#        'France', 'Syria', 'Azores', 'Fiji', 'Guyana', 'China', 'Norway',
#        'Iceland', 'Roatan', 'Guinea'], dtype=object)

# %%
# verify the changes
df['Country'].unique()
# Out:
# array(['Australia', 'Bahamas', 'Seychelles', 'Argentina', 'Costa Rica',
#        'Brazil', 'Egypt', 'French Polynesia', 'USA', 'Colombia',
#        'South Africa', 'Spain', 'Comoros', 'Mexico', 'Cape Verde',
#        'Cayman Islands', 'Italy', 'Jamaica', 'Trinidad & Tobago',
#        'Canada', 'Croatia', 'Saudi Arabia', 'Antigua', 'UAE', 'Guam',
#        'Nevis', 'Japan', 'New Zealand', 'British Virgin Islands',
#        'Senegal', 'Belize', 'Liberia', 'Honduras', 'Sri Lanka',
#        'Indonesia', 'New Caledonia', 'Madagascar', 'Malaysia', 'Tonga',
#        'Bermuda', 'Montenegro', 'Somalia', 'Greece', 'Mozambique',
#        'Papua New Guinea', 'Tanzania', 'Panama', 'Philippines',
#        'Atlantic Ocean', 'Johnston Island', 'Marshall Islands',
#        'Caribbean Sea', 'Türkiye', 'Cuba', 'Guatemala',
#        'North Atlantic Ocean', 'North Pacific Ocean', 'Pacific Ocean',
#        'Indian Ocean', 'UK', 'Israel', 'India', 'Haiti', 'Yemen', 'Crete',
#        'France', 'Syria', 'Azores', 'Fiji', 'Guyana', 'China', 'Norway',
#        'Iceland', 'Roatan', 'Guinea'], dtype=object)

# %%
top_countries = df['Country'].value_counts().head(100)
print(top_countries)
# PIE CHART FOR COUNTRIES WITH HIGHEST SHARK ATTACKS

# USA , Australia, South Africa got the highest frequency of shark attacks
# Out:
# Country
# USA                       191
# Australia                 120
# South Africa               64
# Italy                      14
# New Zealand                12
# Mexico                     11
# Spain                      10
# Brazil                      9
# Bahamas                     8
# Croatia                     8
# Japan                       6
# Greece                      5
# Mozambique                  4
# Egypt                       4
# Cuba                        4
# Philippines                 4
# French Polynesia            3
# Jamaica                     3
# Bermuda                     3
# Costa Rica                  3
# UK                          3
# Papua New Guinea            2
# Atlantic Ocean              2
# Indian Ocean                2
# Sri Lanka                   2
# Senegal                     2
# Türkiye                     2
# France                      2
# Marshall Islands            2
# Seychelles                  2
# Cape Verde                  2
# Antigua                     2
# Cayman Islands              2
# North Pacific Ocean         1
# Roatan                      1
# Iceland                     1
# Norway                      1
# Guatemala                   1
# China                       1
# North Atlantic Ocean        1
# Crete                       1
# Caribbean Sea               1
# Pacific Ocean               1
# Fiji                        1
# Azores                      1
# Israel                      1
# Syria                       1
# India                       1
# Haiti                       1
# Yemen                       1
# Guyana                      1
# Malaysia                    1
# Johnston Island             1
# British Virgin Islands      1
# Argentina                   1
# Colombia                    1
# Comoros                     1
# Trinidad & Tobago           1
# Canada                      1
# Saudi Arabia                1
# UAE                         1
# Guam                        1
# Nevis                       1
# Belize                      1
# Panama                      1
# Liberia                     1
# Honduras                    1
# Indonesia                   1
# New Caledonia               1
# Madagascar                  1
# Tonga                       1
# Montenegro                  1
# Somalia                     1
# Tanzania                    1
# Guinea                      1
# Name: count, dtype: int64

# %%
df.columns
# Out:
# Index(['Date', 'Year', 'Type', 'Country', 'State', 'Location', 'Activity',
#        'Name', 'Sex', 'Age', 'Injury', 'Fatal Y/N', 'Time', 'Species ',
#        'Source'],
#       dtype='object')

# %%
# we could try analyse which state in the USA has the most shark attacks?

# %%
df.head(5)
# Out:
#           Date    Year          Type     Country                   State  \
# 0  25 Aug 2023  2023.0    Unprovoked   Australia         New South Wales
# 1  21 Aug-2023  2023.0  Questionable     Bahamas  New Providence   Isoad
# 2  07-Jun-2023  2023.0    Unprovoked     Bahamas                Freeport
# 3  02-Mar-2023  2023.0    Unprovoked  Seychelles          Praslin Island
# 4  18-Feb-2023  2023.0  Questionable   Argentina               Patagonia
#
#                             Location      Activity          Name Sex    Age  \
# 0  Lighthouse Beach, Port Macquarie        Surfing     Toby Begg   M     44
# 1             Saunders Beach, Nassau           NaN          male   M  20/30
# 2                     Shark Junction  Scuba diving   Heidi Ernst   F     73
# 3                                NaN    Snorkeling      Arthur …   M      6
# 4                    Chubut Province           NaN  Diego Barría   M     32
#
#                                               Injury  Fatal Y/N       Time  \
# 0                     Severe injuries to lower limbs        NaN      10h00
# 1  Body found with shark bites. Possible drowning...        NaN    Morning
# 2                               Calf severely bitten        NaN      13h00
# 3                                   Left foot bitten        NaN  Afternoon
# 4                              Death by misadventure        NaN        NaN
#
#                 Species                            Source
# 0  White shark, 3.8-4.2m  B. Myatt, & M. Michaelson, GSAF
# 1                    NaN           The Tribune, 8/21/2023
# 2  Caribbean rreef shark                J. Marchand, GSAF
# 3            Lemon shark              Midlibre, 3/18/2023
# 4                    NaN              El Pais,  2/27/2023

# %%
# dropping the activity

# %% [markdown]
# -----
# ### 'Sex' CLEANING

# %%
# Load the updated CSV
url = "../data/interim/1_interim_country.csv"
df = pd.read_csv(url)
df.columns
# Out:
# Index(['Date', 'Year', 'Type', 'Country', 'State', 'Location', 'Activity',
#        'Name', 'Sex', 'Age', 'Injury', 'Fatal Y/N', 'Time', 'Species ',
#        'Source'],
#       dtype='object')

# %%
df['Sex']
# Out:
# 0        M
# 1        M
# 2        F
# 3        M
# 4        M
# 5        F
# 6        M
# 7        M
# 8        M
# 9      NaN
# 10       F
# 11     NaN
# 12       F
# 13       F
# 14     NaN
# 15       M
# 16       F
# 17       M
# 18       M
# 19       M
# 20       M
# 21       M
# 22       F
# 23       M
# 24       F
# 25     NaN
# 26       M
# 27       F
# 28       F
# 29       M
# 30       M
# 31       M
# 32       M
# 33       M
# 34       M
# 35     NaN
# 36       M
# 37       M
# 38       M
# 39       M
# 40       M
# 41     NaN
# 42       M
# 43       M
# 44       F
# 45       M
# 46       M
# 47       M
# 48       M
# 49       F
# 50       M
# 51       M
# 52       F
# 53       M
# 54       M
# 55       F
# 56       M
# 57     NaN
# 58       M
# 59     NaN
# 60       M
# 61       M
# 62       M
# 63       F
# 64       M
# 65       F
# 66       M
# 67       M
# 68       M
# 69       M
# 70       M
# 71       M
# 72       M
# 73       M
# 74       M
# 75       M
# 76       F
# 77       F
# 78     NaN
# 79       M
# 80       M
# 81       M
# 82       M
# 83     NaN
# 84       M
# 85       M
# 86       M
# 87       M
# 88       M
# 89       F
# 90       F
# 91       M
# 92       M
# 93       F
# 94       M
# 95       M
# 96       M
# 97       M
# 98       F
# 99       M
# 100      M
# 101      M
# 102      M
# 103      M
# 104      M
# 105    NaN
# 106      M
# 107      F
# 108      M
# 109      M
# 110      M
# 111      M
# 112      M
# 113      M
# 114      M
# 115      M
# 116      M
# 117      M
# 118      M
# 119      F
# 120      F
# 121    NaN
# 122      F
# 123      M
# 124      M
# 125      M
# 126      M
# 127      M
# 128      M
# 129      M
# 130      M
# 131      M
# 132    NaN
# 133      F
# 134      M
# 135      M
# 136      M
# 137      M
# 138      M
# 139      M
# 140    NaN
# 141      M
# 142      M
# 143      M
# 144    NaN
# 145      M
# 146      M
# 147      M
# 148      F
# 149      M
# 150      F
# 151    NaN
# 152      M
# 153      M
# 154      M
# 155      F
# 156      M
# 157      M
# 158      M
# 159      M
# 160      M
# 161      F
# 162      M
# 163      F
# 164      M
# 165      M
# 166    NaN
# 167      M
# 168      M
# 169      M
# 170      M
# 171      M
# 172      M
# 173      F
# 174      M
# 175      F
# 176      M
# 177      M
# 178    NaN
# 179      M
# 180      M
# 181      F
# 182      M
# 183    NaN
# 184      M
# 185      F
# 186      M
# 187      M
# 188      F
# 189      M
# 190      M
# 191      M
# 192      M
# 193      M
# 194      M
# 195      M
# 196      M
# 197      M
# 198      F
# 199      M
# 200      M
# 201      M
# 202      M
# 203      M
# 204      M
# 205    NaN
# 206      M
# 207      M
# 208      M
# 209      M
# 210      M
# 211      M
# 212      M
# 213      M
# 214      M
# 215      M
# 216      M
# 217      F
# 218      M
# 219      M
# 220      F
# 221      M
# 222      M
# 223      M
# 224      M
# 225      M
# 226    NaN
# 227      M
# 228      M
# 229      M
# 230      M
# 231      M
# 232      M
# 233      M
# 234      F
# 235      F
# 236      M
# 237      M
# 238    NaN
# 239      M
# 240      M
# 241      F
# 242      M
# 243      M
# 244      M
# 245      M
# 246      M
# 247      M
# 248      M
# 249      F
# 250      M
# 251      M
# 252      M
# 253    NaN
# 254      M
# 255      M
# 256      M
# 257      M
# 258      M
# 259    NaN
# 260      M
# 261      M
# 262      M
# 263      M
# 264    NaN
# 265      M
# 266    NaN
# 267      M
# 268    NaN
# 269      M
# 270      M
# 271      M
# 272      F
# 273    NaN
# 274      M
# 275      M
# 276      M
# 277      M
# 278      M
# 279      M
# 280    NaN
# 281    NaN
# 282      M
# 283    NaN
# 284      M
# 285      M
# 286    NaN
# 287    NaN
# 288      M
# 289      F
# 290      M
# 291      M
# 292      M
# 293      M
# 294    NaN
# 295      M
# 296      M
# 297      M
# 298      M
# 299      M
# 300      M
# 301      F
# 302    NaN
# 303      M
# 304      M
# 305      M
# 306      M
# 307      M
# 308      M
# 309    NaN
# 310    NaN
# 311      M
# 312    NaN
# 313      F
# 314      M
# 315      M
# 316      M
# 317      F
# 318    NaN
# 319      M
# 320      M
# 321      M
# 322      M
# 323      M
# 324      F
# 325    NaN
# 326      M
# 327      M
# 328      M
# 329    NaN
# 330      M
# 331    NaN
# 332      M
# 333      M
# 334    NaN
# 335      F
# 336      M
# 337      M
# 338      M
# 339      M
# 340      M
# 341      M
# 342    NaN
# 343      M
# 344      M
# 345      M
# 346    NaN
# 347      M
# 348      M
# 349    NaN
# 350      F
# 351      M
# 352      M
# 353      M
# 354      M
# 355      M
# 356      M
# 357      M
# 358    NaN
# 359      M
# 360    NaN
# 361      M
# 362      F
# 363      M
# 364      M
# 365      M
# 366    NaN
# 367      M
# 368    NaN
# 369      M
# 370      M
# 371      M
# 372    NaN
# 373      M
# 374      M
# 375      F
# 376      M
# 377      M
# 378    NaN
# 379      M
# 380      M
# 381      M
# 382      M
# 383      M
# 384      M
# 385      M
# 386      M
# 387    NaN
# 388    NaN
# 389    NaN
# 390      M
# 391      M
# 392      M
# 393      M
# 394      M
# 395      M
# 396      M
# 397      M
# 398    NaN
# 399      M
# 400      M
# 401    NaN
# 402      F
# 403      F
# 404      M
# 405      M
# 406      M
# 407    NaN
# 408      M
# 409      M
# 410      M
# 411      M
# 412      M
# 413      M
# 414      M
# 415      M
# 416    NaN
# 417      M
# 418      M
# 419      M
# 420      M
# 421      M
# 422      M
# 423    NaN
# 424      M
# 425      F
# 426      M
# 427      M
# 428      M
# 429    NaN
# 430      M
# 431      M
# 432    NaN
# 433      M
# 434      M
# 435      M
# 436      M
# 437      M
# 438      M
# 439      M
# 440      M
# 441    NaN
# 442      M
# 443      F
# 444      M
# 445      M
# 446      M
# 447      M
# 448      M
# 449      F
# 450    NaN
# 451      M
# 452      M
# 453      M
# 454      M
# 455      M
# 456      M
# 457      F
# 458    NaN
# 459    NaN
# 460      M
# 461      M
# 462      M
# 463      M
# 464      M
# 465      M
# 466      M
# 467      M
# 468      M
# 469      M
# 470    NaN
# 471      M
# 472      M
# 473      M
# 474      M
# 475      M
# 476      M
# 477      M
# 478      M
# 479      M
# 480      M
# 481      M
# 482      F
# 483      M
# 484      M
# 485      M
# 486      M
# 487      M
# 488    NaN
# 489      M
# 490    NaN
# 491      M
# 492    NaN
# 493      M
# 494    NaN
# 495      M
# 496      M
# 497    NaN
# 498      M
# 499    NaN
# 500      F
# 501      M
# 502      M
# 503      M
# 504      M
# 505      M
# 506      M
# 507      M
# 508      M
# 509      M
# 510      M
# 511      M
# 512      M
# 513      M
# 514    NaN
# 515      M
# 516      M
# 517      M
# 518      M
# 519      M
# 520      M
# 521      M
# 522      M
# 523      M
# 524      M
# 525      M
# 526      M
# 527    NaN
# 528      M
# 529      M
# 530      M
# 531      M
# 532      M
# 533      M
# 534      F
# 535      M
# 536      M
# 537      M
# 538      M
# 539      M
# 540    NaN
# 541      M
# 542    NaN
# 543    NaN
# 544      M
# 545      M
# 546    NaN
# 547      M
# 548      M
# 549      M
# 550    NaN
# 551      M
# 552      M
# 553      F
# 554      M
# Name: Sex, dtype: object

# %%
# NaN , F, M
df['Sex'].value_counts(dropna=False)
# Out:
# Sex
# M      411
# NaN     80
# F       64
# Name: count, dtype: int64

# %%
df['Sex'] = df['Sex'].replace({
    'm' : 'M', 
    'f' : 'F', 
    'Male' : 'M', 
    'Female' : 'F'})

df['Sex'] = df['Sex'].str.upper()

# %%
df.dropna (subset = ['Sex'], inplace= True)
df['Sex'].value_counts(dropna=False)
# Out:
# Sex
# M    411
# F     64
# Name: count, dtype: int64

# %%
df.columns
# Out:
# Index(['Date', 'Year', 'Type', 'Country', 'State', 'Location', 'Activity',
#        'Name', 'Sex', 'Age', 'Injury', 'Fatal Y/N', 'Time', 'Species ',
#        'Source'],
#       dtype='object')

# %%
df.shape
# Out:
# (475, 15)

# %%
df['Sex'].describe()
# Male is the highest in frequency with shark attacks
# Out:
# count     475
# unique      2
# top         M
# freq      411
# Name: Sex, dtype: object

# %%
# Save 'Sex' CLEANED to CSV
df.to_csv("../data/interim/2_interim_sex.csv", index=False)
print("STEP 2 : 'Sex' Data cleaned successfully!")
# Out:
# STEP 2 : 'Sex' Data cleaned successfully!

# %%
 df.head()
# Out:
#           Date    Year          Type     Country                   State  \
# 0  25 Aug 2023  2023.0    Unprovoked   Australia         New South Wales
# 1  21 Aug-2023  2023.0  Questionable     Bahamas  New Providence   Isoad
# 2  07-Jun-2023  2023.0    Unprovoked     Bahamas                Freeport
# 3  02-Mar-2023  2023.0    Unprovoked  Seychelles          Praslin Island
# 4  18-Feb-2023  2023.0  Questionable   Argentina               Patagonia
#
#                             Location      Activity          Name Sex    Age  \
# 0  Lighthouse Beach, Port Macquarie        Surfing     Toby Begg   M     44
# 1             Saunders Beach, Nassau           NaN          male   M  20/30
# 2                     Shark Junction  Scuba diving   Heidi Ernst   F     73
# 3                                NaN    Snorkeling      Arthur …   M      6
# 4                    Chubut Province           NaN  Diego Barría   M     32
#
#                                               Injury  Fatal Y/N       Time  \
# 0                     Severe injuries to lower limbs        NaN      10h00
# 1  Body found with shark bites. Possible drowning...        NaN    Morning
# 2                               Calf severely bitten        NaN      13h00
# 3                                   Left foot bitten        NaN  Afternoon
# 4                              Death by misadventure        NaN        NaN
#
#                 Species                            Source
# 0  White shark, 3.8-4.2m  B. Myatt, & M. Michaelson, GSAF
# 1                    NaN           The Tribune, 8/21/2023
# 2  Caribbean rreef shark                J. Marchand, GSAF
# 3            Lemon shark              Midlibre, 3/18/2023
# 4                    NaN              El Pais,  2/27/2023

# %% [markdown]
# -----
# ### 'Age' CLEANING

# %%
# Load the updated CSV
url = "../data/interim/2_interim_sex.csv"
df = pd.read_csv(url)
df.columns
# Out:
# Index(['Date', 'Year', 'Type', 'Country', 'State', 'Location', 'Activity',
#        'Name', 'Sex', 'Age', 'Injury', 'Fatal Y/N', 'Time', 'Species ',
#        'Source'],
#       dtype='object')

# %%
df['Age'].info()
#238 non-null object
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 475 entries, 0 to 474
# Series name: Age
# Non-Null Count  Dtype
# --------------  -----
# 233 non-null    object
# dtypes: object(1)
# memory usage: 3.8+ KB

# %%
df['Age'].unique()
# Out:
# array(['44', '20/30', '73', '6', '32', '50', '11', '26', nan, '35', '62',
#        '34', '31', '33', '25', '10', '8', '18', '68', '20', '19', '27',
#        '60', 'Teen', '65', '9', '40', '39', '43', '23', '38', '63', '47',
#        '48', '42', '24', '12', '16', '14', '7', '49', '17', '52', '53',
#        '45', '36', '54', '51', '22', '28', '56', '8 or 10', '75',
#        '23 & 20', '37', '29', '21', '15', '30', '16 to 18', '67', '77',
#        'mid-20s', 'Ca. 33', '? & 19', '46', '37, 67, 35, 27,  ? & 27',
#        '21, 34,24 & 35', '34 & 19', '13', '5', '1'], dtype=object)

# %%
df['Age'].nunique()
# Out:
# 71

# %%
import pandas as pd
import numpy as np
import re

# DATA .csv
df = pd.read_csv(url)
# def Function : clean_age(value=age)
def clean_age(value):
    if pd.isna(value):
        return np.nan
    
    value = str(value).strip().lower()

    # Remove useless text
    value = value.replace("years", "").replace("year", "").replace("ca.", "").replace("about", "").strip()

    # Words meaning no age
    if value in ["n/a", "na", "none", "?", "", "unknown"]:
        return np.nan

    # Teen keyword (approx.)
    if "teen" in value:
        return 15

    # mid-20s → 25
    if "mid" in value and "20" in value:
        return 25

    # Extract numbers
    nums = re.findall(r"\d+", value)

    # Single number
    if len(nums) == 1:
        return int(nums[0])
    
    # Multiple numbers -> average them (20/30, 23 & 20, 16 to 18)
    if len(nums) >= 2:
        nums = [int(n) for n in nums]
        return sum(nums) / len(nums)

    return np.nan

# Apply cleaner
df['Age_clean'] = df['Age'].apply(clean_age)

# Convert to numeric
df['Age_clean'] = pd.to_numeric(df['Age_clean'], errors='coerce')

# Fill missing with median
median_age = df['Age_clean'].median()
df['Age_clean'].fillna(median_age, inplace=True)

# Convert to integer (no floats)
df['Age_clean'] = df['Age_clean'].round().astype(int)


# Show result
print(df[['Age', 'Age_clean']].head(10))
print("\nMedian age used:", int(median_age))

# Copy Age_clean into Age
df['Age'] = df['Age_clean']

# Drop Age_clean column
df = df.drop(columns=['Age_clean'])
# Out:
#      Age  Age_clean
# 0     44         44
# 1  20/30         25
# 2     73         73
# 3      6          6
# 4     32         32
# 5     50         50
# 6     11         11
# 7     26         26
# 8    NaN         26
# 9    NaN         26
#
# Median age used: 26
# C:\Users\sboub\AppData\Local\Temp\ipykernel_13544\3124323.py:51: FutureWarning:
#
# A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.

# %%
# Check result
print("\nFrequency of each",df["Age"].value_counts())
# Out:
# Frequency of each Age
# 26    247
# 17     15
# 20      9
# 43      8
# 22      7
# 24      7
# 21      7
# 32      7
# 25      7
# 19      7
# 18      7
# 11      6
# 23      6
# 31      6
# 27      6
# 9       5
# 40      5
# 36      5
# 10      5
# 28      5
# 35      5
# 14      5
# 39      4
# 49      4
# 44      4
# 45      4
# 52      4
# 12      4
# 53      3
# 37      3
# 7       3
# 29      3
# 30      3
# 47      3
# 42      3
# 15      3
# 50      3
# 33      3
# 34      3
# 68      2
# 8       2
# 13      2
# 51      2
# 63      2
# 16      2
# 38      2
# 62      2
# 48      2
# 6       2
# 65      1
# 67      1
# 5       1
# 46      1
# 77      1
# 75      1
# 73      1
# 56      1
# 54      1
# 60      1
# 1       1
# Name: count, dtype: int64

# %%
df['Age'].describe().round().astype(int)
# Out:
# count    475
# mean      28
# std       11
# min        1
# 25%       26
# 50%       26
# 75%       26
# max       77
# Name: Age, dtype: int64

# %%
percentiles = df['Age'].describe(percentiles=[0.25, 0.5, 0.75])

print("Age Percentile Statistics:")
print(f"Min:   {int(percentiles['min'])}")
print(f"25%:   {int(percentiles['25%'])}")
print(f"50% (Median): {int(percentiles['50%'])}")
print(f"75%:   {int(percentiles['75%'])}")
print(f"Max:   {int(percentiles['max'])}")

# the majority were people up to 26 years old
# Out:
# Age Percentile Statistics:
# Min:   1
# 25%:   26
# 50% (Median): 26
# 75%:   26
# Max:   77

# %%
# Save 'Age' CLEANED to CSV
df.to_csv("../data/interim/3_interim_age.csv", index=False)
print("STEP 3 : 'Age' Data cleaned successfully!")
# Out:
# STEP 3 : 'Age' Data cleaned successfully!

# %%
df.head(5)
# Out:
#           Date    Year          Type     Country                   State  \
# 0  25 Aug 2023  2023.0    Unprovoked   Australia         New South Wales
# 1  21 Aug-2023  2023.0  Questionable     Bahamas  New Providence   Isoad
# 2  07-Jun-2023  2023.0    Unprovoked     Bahamas                Freeport
# 3  02-Mar-2023  2023.0    Unprovoked  Seychelles          Praslin Island
# 4  18-Feb-2023  2023.0  Questionable   Argentina               Patagonia
#
#                             Location      Activity          Name Sex  Age  \
# 0  Lighthouse Beach, Port Macquarie        Surfing     Toby Begg   M   44
# 1             Saunders Beach, Nassau           NaN          male   M   25
# 2                     Shark Junction  Scuba diving   Heidi Ernst   F   73
# 3                                NaN    Snorkeling      Arthur …   M    6
# 4                    Chubut Province           NaN  Diego Barría   M   32
#
#                                               Injury  Fatal Y/N       Time  \
# 0                     Severe injuries to lower limbs        NaN      10h00
# 1  Body found with shark bites. Possible drowning...        NaN    Morning
# 2                               Calf severely bitten        NaN      13h00
# 3                                   Left foot bitten        NaN  Afternoon
# 4                              Death by misadventure        NaN        NaN
#
#                 Species                            Source
# 0  White shark, 3.8-4.2m  B. Myatt, & M. Michaelson, GSAF
# 1                    NaN           The Tribune, 8/21/2023
# 2  Caribbean rreef shark                J. Marchand, GSAF
# 3            Lemon shark              Midlibre, 3/18/2023
# 4                    NaN              El Pais,  2/27/2023

# %% [markdown]
# -----
# ## 'Type' Injury CLEANING

# %%
# Load the updated CSV
url = "../data/interim/3_interim_age.csv"
df = pd.read_csv(url)
df.columns
# Out:
# Index(['Date', 'Year', 'Type', 'Country', 'State', 'Location', 'Activity',
#        'Name', 'Sex', 'Age', 'Injury', 'Fatal Y/N', 'Time', 'Species ',
#        'Source'],
#       dtype='object')

# %%
import pandas as pd

# Load only the relevant columns
df = pd.read_csv("data/hospital_supplies_shark_attacks.csv", usecols=["Type", "Injury Severity"])

# --- Clean column names ---
df.columns = df.columns.str.strip().str.lower().str.replace(" ", "_")

# --- Clean 'type' column ---
df["type"] = (
    df["type"]
    .astype(str)
    .str.strip()
    .str.title()
    .replace({
        "Provoked": "Provoked",
        "Unprovoked": "Unprovoked",
        "Invalid": "Invalid",
        "Boat": "Boat",
        "Sea Disaster": "Sea Disaster",
        "Questionable": "Questionable",
        "Unknown": "Unknown"
    })
)

# Replace any blank or weird values with "Unknown"
df.loc[df["type"].isin(["", "Nan", "None", "Na", "0"]), "type"] = "Unknown"

# --- Clean 'injury_severity' column ---
df["injury_severity"] = (
    df["injury_severity"]
    .astype(str)
    .str.strip()
    .str.lower()
    .replace({
        "death": "Death",
        "fatal": "Death",
        "severe": "Severe Injury",
        "severe injury": "Severe Injury",
        "minor": "Minor Injury",
        "minor injury": "Minor Injury",
        "no injury": "No Injury",
        "unknown": "Unknown",
        "uncertain": "Unknown",
        "unconfirmed": "Unknown",
        "": "Unknown",
        "none": "Unknown"
    })
)

# Capitalize consistently
df["injury_severity"] = df["injury_severity"].str.title()

# --- Drop duplicates and NaNs ---
df.drop_duplicates(inplace=True)
df.dropna(subset=["type", "injury_severity"], inplace=True)

# --- Save cleaned data ---
df.to_csv("data/4.5_interim_type_and_severity_injury.csv", index=False)

print("✅ Cleaned file saved as '4.5_interim_type_and_severity_injury.csv'")
print("Unique 'Type' values:", df['type'].unique())
print("Unique 'Injury Severity' values:", df['injury_severity'].unique())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[399], line 4
#       1 import pandas as pd
#       3 # Load only the relevant columns
# ----> 4 df = pd.read_csv("data/hospital_supplies_shark_attacks.csv", usecols=["Type", "Injury Severity"])
#       6 # --- Clean column names ---
#       7 df.columns = df.columns.str.strip().str.lower().str.replace(" ", "_")
#
# File c:\Users\sboub\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\sboub\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File c:\Users\sboub\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File c:\Users\sboub\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File c:\Users\sboub\anaconda3\Lib\site-packages\pandas\io\common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/hospital_supplies_shark_attacks.csv'

# %%
df['Fatal Y/N'].unique()
# EMPTY
# Out:
# array([nan])

# %%
import pandas as pd
import numpy as np

def classify_injury(injury, fatal):
    if pd.isna(injury):
        injury = ""
    injury = injury.lower()
    fatal = str(fatal).strip().upper()

    # HOAX / FALSE
    if "hoax" in injury or "false" in injury:
        return "Hoax / False report"

    # NOT A SHARK
    if any(x in injury for x in ["not a shark", "stingray", "barracuda", "propeller", "fish"]):
        return "Not a shark"

    # NO INJURY
    if "no injury" in injury or "no injuries" in injury:
        return "No injury"

    # PROVOKED
    if "provoked" in injury:
        return "Provoked incident"

    # MISSING
    if any(x in injury for x in ["missing", "disappeared", "body not recovered"]):
        return "Missing / Unknown"

    # FATAL CASES
    if fatal == "Y":
        # drowned then bitten after death
        if "post-mortem" in injury or ("drown" in injury and "post" in injury):
            return "Fatal | Drowned, shark scavenged"
        if "unconfirmed" in injury or "probable" in injury:
            return "Fatal | Unconfirmed shark involvement"
        return "Fatal | Shark confirmed"

    # NON-FATAL CASES
    if fatal == "N":
        if any(x in injury for x in ["bitten", "lacerat", "puncture", "wound", "abrasion"]):
            return "Non-fatal | Confirmed shark bite"
        # Text but no bite
        return "Non-fatal | Other"

    # Unknown
    return "Other/Unknown"

# Apply to dataframe
df["Type"] = df.apply(lambda row: classify_injury(row["Injury"], row["Fatal Y/N"]), axis=1)


# Check RESULTS--------------------------------------------------------------------------------------------------------------

# Count number of records in each injury type
counts = df["Type"].value_counts()

# Calculate percentages
percentages = (counts / len(df)) * 100

# Create summary DataFrame
summary = pd.DataFrame({
    "Cases": counts,
    "Percentage": percentages.round(2)
})


# Save TYPE of INJURY CLEANED file
df.to_csv("../data/interim/4_interim_type_injury.csv", index=False)

# Print Injury type
print("Injury Type:")
for category in counts.index:
    print(f"{category}: {counts[category]} cases  ({percentages[category]:.2f}%)")
# Out:
# Injury Type:
# Other/Unknown: 338 cases  (71.16%)
# No injury: 74 cases  (15.58%)
# Missing / Unknown: 34 cases  (7.16%)
# Not a shark: 22 cases  (4.63%)
# Provoked incident: 4 cases  (0.84%)
# Hoax / False report: 3 cases  (0.63%)

# %%
# Save 'Type' CLEANED file
# Save cleaned and updated DataFrame to a new CSV
# we save the data after changes
df.to_csv("../data/interim/4_interim_type_injury.csv", index=False)
print("STEP 4 : 'Type' Data cleaned successfully!")
# Out:
# STEP 4 : 'Type' Data cleaned successfully!

# %%
df.head(5)
# Out:
#           Date    Year           Type     Country                   State  \
# 0  25 Aug 2023  2023.0  Other/Unknown   Australia         New South Wales
# 1  21 Aug-2023  2023.0  Other/Unknown     Bahamas  New Providence   Isoad
# 2  07-Jun-2023  2023.0  Other/Unknown     Bahamas                Freeport
# 3  02-Mar-2023  2023.0  Other/Unknown  Seychelles          Praslin Island
# 4  18-Feb-2023  2023.0  Other/Unknown   Argentina               Patagonia
#
#                             Location      Activity          Name Sex  Age  \
# 0  Lighthouse Beach, Port Macquarie        Surfing     Toby Begg   M   44
# 1             Saunders Beach, Nassau           NaN          male   M   25
# 2                     Shark Junction  Scuba diving   Heidi Ernst   F   73
# 3                                NaN    Snorkeling      Arthur …   M    6
# 4                    Chubut Province           NaN  Diego Barría   M   32
#
#                                               Injury  Fatal Y/N       Time  \
# 0                     Severe injuries to lower limbs        NaN      10h00
# 1  Body found with shark bites. Possible drowning...        NaN    Morning
# 2                               Calf severely bitten        NaN      13h00
# 3                                   Left foot bitten        NaN  Afternoon
# 4                              Death by misadventure        NaN        NaN
#
#                 Species                            Source
# 0  White shark, 3.8-4.2m  B. Myatt, & M. Michaelson, GSAF
# 1                    NaN           The Tribune, 8/21/2023
# 2  Caribbean rreef shark                J. Marchand, GSAF
# 3            Lemon shark              Midlibre, 3/18/2023
# 4                    NaN              El Pais,  2/27/2023

# %% [markdown]
# -----
# ## INJURY SEVERITY

# %%
# Load the updated CSV
url = "../data/interim/4_interim_type_injury.csv"
df = pd.read_csv(url)
df.columns
# Out:
# Index(['Date', 'Year', 'Type', 'Country', 'State', 'Location', 'Activity',
#        'Name', 'Sex', 'Age', 'Injury', 'Fatal Y/N', 'Time', 'Species ',
#        'Source'],
#       dtype='object')

# %%
df['Type'].describe().round()
# Out:
# count               475
# unique                6
# top       Other/Unknown
# freq                338
# Name: Type, dtype: object

# %%
import re

# Function to classify injury severity
def classify_severity(val):
    if pd.isna(val):
        val = ""
    val = val.lower()
    
    if re.search(r'fatal|death|died|deceased', val):
        return "Death"
    if re.search(r'amputation|severed|severely bitten', val):
        return "Severe injury"
    if re.search(r'bitten|bite|laceration|cuts|fracture', val):
        return "Minor injury"
    if re.search(r'no injury|not injured|unharmed', val):
        return "No injury"
    if re.search(r'possible drowning|unknown', val):
        return "Uncertain"
    
    return "Unknown"

# Apply to create Injury Severity column
df["Injury Severity"] = df["Injury"].apply(classify_severity)

# %%
# Save 'Injury Severity' CLEANED to CSV
df.to_csv("../data/interim/5_interim_injury_severity.csv", index=False)
print("STEP 5 : 'Injury Severity' Data cleaned successfully!")
# Out:
# STEP 5 : 'Injury Severity' Data cleaned successfully!

# %%
print(df['Type'].unique())
# Out:
# ['Other/Unknown' 'Missing / Unknown' 'No injury' 'Not a shark'
#  'Hoax / False report' 'Provoked incident']

# %% [markdown]
# -----
# ## FATALITY

# %% [markdown]
# Fatality depends on injury severity because it used to be all NaN

# %%
# Load the updated CSV
url = "../data/interim/5_interim_injury_severity.csv"
df = pd.read_csv(url)
df.columns
# Out:
# Index(['Date', 'Year', 'Type', 'Country', 'State', 'Location', 'Activity',
#        'Name', 'Sex', 'Age', 'Injury', 'Fatal Y/N', 'Time', 'Species ',
#        'Source', 'Injury Severity'],
#       dtype='object')

# %%
# Now derive Fatal Y/N based on Injury Severity
def derive_fatal(severity):
    if severity == "Death":
        return "Y"
    elif severity in ["Severe injury", "Injury", "No injury", "Uncertain", "Other/Unknown"]:
        return "N"
    return "N"

df["Fatal Y/N"] = df["Injury Severity"].apply(derive_fatal)


# Save INJURY SEVERITY CLEANED file
df.to_csv("../data/interim/5_interim_injury_severity.csv", index=False)



# Check the first rows
print(df[["Injury", "Injury Severity", "Fatal Y/N"]].head(10))
# Out:
#                                               Injury Injury Severity Fatal Y/N
# 0                     Severe injuries to lower limbs         Unknown         N
# 1  Body found with shark bites. Possible drowning...           Death         Y
# 2                               Calf severely bitten   Severe injury         N
# 3                                   Left foot bitten    Minor injury         N
# 4                              Death by misadventure           Death         Y
# 5                Right forearm and left hand injured         Unknown         N
# 6                           Minor cuts to left thigh    Minor injury         N
# 7                                        Disappeared         Unknown         N
# 8           Laceration to arm caused by metal object    Minor injury         N
# 9                                                NaN         Unknown         N

# %%
# Save INJURY SEVERITY CLEANED file
df.to_csv("../data/interim/6_interim.fatality.csv", index=False)

df['Fatal Y/N'].describe()
# majority survive shark attacks !
# Out:
# count     475
# unique      2
# top         N
# freq      378
# Name: Fatal Y/N, dtype: object

# %%
df.head(5)
# Out:
#           Date    Year           Type     Country                   State  \
# 0  25 Aug 2023  2023.0  Other/Unknown   Australia         New South Wales
# 1  21 Aug-2023  2023.0  Other/Unknown     Bahamas  New Providence   Isoad
# 2  07-Jun-2023  2023.0  Other/Unknown     Bahamas                Freeport
# 3  02-Mar-2023  2023.0  Other/Unknown  Seychelles          Praslin Island
# 4  18-Feb-2023  2023.0  Other/Unknown   Argentina               Patagonia
#
#                             Location      Activity          Name Sex  Age  \
# 0  Lighthouse Beach, Port Macquarie        Surfing     Toby Begg   M   44
# 1             Saunders Beach, Nassau           NaN          male   M   25
# 2                     Shark Junction  Scuba diving   Heidi Ernst   F   73
# 3                                NaN    Snorkeling      Arthur …   M    6
# 4                    Chubut Province           NaN  Diego Barría   M   32
#
#                                               Injury Fatal Y/N       Time  \
# 0                     Severe injuries to lower limbs         N      10h00
# 1  Body found with shark bites. Possible drowning...         Y    Morning
# 2                               Calf severely bitten         N      13h00
# 3                                   Left foot bitten         N  Afternoon
# 4                              Death by misadventure         Y        NaN
#
#                 Species                            Source Injury Severity
# 0  White shark, 3.8-4.2m  B. Myatt, & M. Michaelson, GSAF         Unknown
# 1                    NaN           The Tribune, 8/21/2023           Death
# 2  Caribbean rreef shark                J. Marchand, GSAF   Severe injury
# 3            Lemon shark              Midlibre, 3/18/2023    Minor injury
# 4                    NaN              El Pais,  2/27/2023           Death

# %% [markdown]
# ----------
# ## 'Date' CLEANING & seperate DD-MM-YYYY columns

# %%
# Load the updated CSV
url = "../data/interim/6_interim.fatality.csv"
df = pd.read_csv(url)
df.columns
# Out:
# Index(['Date', 'Year', 'Type', 'Country', 'State', 'Location', 'Activity',
#        'Name', 'Sex', 'Age', 'Injury', 'Fatal Y/N', 'Time', 'Species ',
#        'Source', 'Injury Severity'],
#       dtype='object')

# %%
import pandas as pd
import re

# DataFrame with the 'Date' column
df = pd.read_csv(url)

# Function to parse dates-------------------------------------------------------------------------------------------------------------------
def parse_date(date_str):
    date_str = str(date_str).strip()
    
    # Remove 'Reported ' prefix
    date_str = re.sub(r'^Reported\s+', '', date_str, flags=re.IGNORECASE)
    
    # Patterns to match
    patterns = [
        r'(?P<DD>\d{1,2})[- ](?P<MM>[A-Za-z]+)[- ](?P<YYYY>\d{4})',  # DD MMM YYYY
        r'(?P<MM>[A-Za-z]+)[- ](?P<YYYY>\d{4})',                      # MMM-YYYY
        r'(?P<YYYY>\d{4})',                                           # YYYY only
    ]
    
    for pat in patterns:
        match = re.match(pat, date_str)
        if match:
            return match.groupdict()
    
    return {'DD': None, 'MM': None, 'YYYY': None}
#--------------------------------------------------------------------------------------------------------------------------------------------
# Call Function to the column
parsed_dates = df['Date'].apply(parse_date).apply(pd.Series)

# Merge back to original DataFrame
df = pd.concat([df, parsed_dates], axis=1)

# drop the column 'Date' and add the new columns DD MM YYYY
df = df.drop(columns=['Date'])

#
df = df[df["MM"] != "Early"]
df = df[df["MM"] != "Circa"]
df = df[df["MM"] != "Late"]
df = df[df["MM"] != "Before"]

df.head()
# Out:
#      Year           Type     Country                   State  \
# 0  2023.0  Other/Unknown   Australia         New South Wales
# 1  2023.0  Other/Unknown     Bahamas  New Providence   Isoad
# 2  2023.0  Other/Unknown     Bahamas                Freeport
# 3  2023.0  Other/Unknown  Seychelles          Praslin Island
# 4  2023.0  Other/Unknown   Argentina               Patagonia
#
#                             Location      Activity          Name Sex  Age  \
# 0  Lighthouse Beach, Port Macquarie        Surfing     Toby Begg   M   44
# 1             Saunders Beach, Nassau           NaN          male   M   25
# 2                     Shark Junction  Scuba diving   Heidi Ernst   F   73
# 3                                NaN    Snorkeling      Arthur …   M    6
# 4                    Chubut Province           NaN  Diego Barría   M   32
#
#                                               Injury Fatal Y/N       Time  \
# 0                     Severe injuries to lower limbs         N      10h00
# 1  Body found with shark bites. Possible drowning...         Y    Morning
# 2                               Calf severely bitten         N      13h00
# 3                                   Left foot bitten         N  Afternoon
# 4                              Death by misadventure         Y        NaN
#
#                 Species                            Source Injury Severity  DD  \
# 0  White shark, 3.8-4.2m  B. Myatt, & M. Michaelson, GSAF         Unknown  25
# 1                    NaN           The Tribune, 8/21/2023           Death  21
# 2  Caribbean rreef shark                J. Marchand, GSAF   Severe injury  07
# 3            Lemon shark              Midlibre, 3/18/2023    Minor injury  02
# 4                    NaN              El Pais,  2/27/2023           Death  18
#
#     MM  YYYY
# 0  Aug  2023
# 1  Aug  2023
# 2  Jun  2023
# 3  Mar  2023
# 4  Feb  2023

# %%
import pandas as pd
import numpy as np
import re
# Clean the MM from 'NaN' and 'None'
df = df[df["MM"].notna() & (df["MM"] != "")]

# Replace full month names with abbreviations
df["MM"] = df["MM"].replace({
    "November": "Nov",
    "April": "Apr"
})

df['MM'].unique()
# Out:
# array(['Aug', 'Jun', 'Mar', 'Feb', 'Nov', 'Oct', 'Sep', 'Jul', 'Apr',
#        'May', 'Jan', 'Dec'], dtype=object)

# %%
import pandas as pd
import numpy as np
import re

# DATA .csv
df = pd.read_csv(url)
# Function to parse dates-------------------------------------------------------------------------------------------------------------------
def parse_date(date_str):
    date_str = str(date_str).strip()
    
    # Remove 'Reported ' prefix
    date_str = re.sub(r'^Reported\s+', '', date_str, flags=re.IGNORECASE)
    
    # Patterns to match
    patterns = [
        r'(?P<DD>\d{1,2})[- ](?P<MM>[A-Za-z]+)[- ](?P<YYYY>\d{4})',  # DD MMM YYYY
        r'(?P<MM>[A-Za-z]+)[- ](?P<YYYY>\d{4})',                      # MMM-YYYY
        r'(?P<YYYY>\d{4})',                                           # YYYY only
    ]
    
    for pat in patterns:
        match = re.match(pat, date_str)
        if match:
            return match.groupdict()
    
    return {'DD': None, 'MM': None, 'YYYY': None}
#--------------------------------------------------------------------------------------------------------------------------------------------
# Call Function to the column
parsed_dates = df['Date'].apply(parse_date).apply(pd.Series)

# Merge back to original DataFrame
df = pd.concat([df, parsed_dates], axis=1)

# drop the column 'Date' and add the new columns DD MM YYYY
df = df.drop(columns=['Date'])

#
df = df[df["MM"] != "Early"]
df = df[df["MM"] != "Circa"]
df = df[df["MM"] != "Late"]
df = df[df["MM"] != "Before"]

# %%
# Mapping month names to integers
month_map = {
    'Jan': 1, 'January': 1,
    'Feb': 2, 'February': 2,
    'Mar': 3, 'March': 3,
    'Apr': 4, 'April': 4,
    'May': 5,
    'Jun': 6, 'June': 6,
    'Jul': 7, 'July': 7,
    'Aug': 8, 'August': 8,
    'Sep': 9, 'Sept': 9, 'September': 9,
    'Oct': 10, 'October': 10,
    'Nov': 11, 'November': 11,
    'Dec': 12, 'December': 12
}

# Map MM column to integers; non-months become NaN
df['MM_clean'] = df['MM'].map(month_map)

# Drop non-month values
df_months_only = df.dropna(subset=['MM_clean']).copy()

# Convert to int
df_months_only['MM_clean'] = df_months_only['MM_clean'].astype(int)

# Compute percentages
mm_percent = df_months_only['MM_clean'].value_counts(normalize=True) * 100


# Compute counts from the cleaned DataFrame
mm_counts = df_months_only['MM_clean'].value_counts()

# Display results
print("Counts of months (MM_clean):")
print(mm_counts.sort_index())  # months in chronological order

mm_percent = df_months_only['MM_clean'].value_counts(normalize=True) * 100

# Round to 2 decimal places and add % sign
mm_percent_formatted = mm_percent.sort_index().map(lambda x: f"{x:.2f}%")

# Display
print("\nPercentage of each month (MM_clean):")
print(mm_percent_formatted)
# Out:
# Counts of months (MM_clean):
# MM_clean
# 1     46
# 2     23
# 3     29
# 4     45
# 5     24
# 6     38
# 7     51
# 8     62
# 9     30
# 10    27
# 11    28
# 12    29
# Name: count, dtype: int64
#
# Percentage of each month (MM_clean):
# MM_clean
# 1     10.65%
# 2      5.32%
# 3      6.71%
# 4     10.42%
# 5      5.56%
# 6      8.80%
# 7     11.81%
# 8     14.35%
# 9      6.94%
# 10     6.25%
# 11     6.48%
# 12     6.71%
# Name: proportion, dtype: object

# %%
# frequency of shark attack in every month
df['MM'].value_counts()
# Out:
# MM
# Aug         62
# Jul         51
# Jan         46
# Apr         44
# Jun         38
# Sep         30
# Mar         29
# Dec         29
# Nov         27
# Oct         27
# May         24
# Feb         23
# November     1
# April        1
# Name: count, dtype: int64

# %%
# Calculate percentage of shark attacks per month
percentages = df['MM'].value_counts(normalize=True) * 100

# Sort from high to low
percentages_sorted = percentages.sort_values(ascending=False)

# Format as 00.00%
percentages_formatted = percentages_sorted.map("{:.2f}%".format)

print(percentages_formatted)
# Out:
# MM
# Aug         14.35%
# Jul         11.81%
# Jan         10.65%
# Apr         10.19%
# Jun          8.80%
# Sep          6.94%
# Mar          6.71%
# Dec          6.71%
# Nov          6.25%
# Oct          6.25%
# May          5.56%
# Feb          5.32%
# November     0.23%
# April        0.23%
# Name: proportion, dtype: object

# %%
# Drop MM_clean column
df = df.drop(columns=['MM_clean'])

# Drop Year column
df = df.drop(columns=['Year'])

# %%
# Save 'Date' CLEANED to CSV
df.to_csv("../data/interim/7_interim_date.csv", index=False)
print("STEP 7 : 'Date' cleaned successfully!")
# Out:
# STEP 7 : 'Date' cleaned successfully!

# %%
# Save DATE CLEANED file
# check for changes
df.head()
# Out:
#             Type     Country                   State  \
# 0  Other/Unknown   Australia         New South Wales
# 1  Other/Unknown     Bahamas  New Providence   Isoad
# 2  Other/Unknown     Bahamas                Freeport
# 3  Other/Unknown  Seychelles          Praslin Island
# 4  Other/Unknown   Argentina               Patagonia
#
#                             Location      Activity          Name Sex  Age  \
# 0  Lighthouse Beach, Port Macquarie        Surfing     Toby Begg   M   44
# 1             Saunders Beach, Nassau           NaN          male   M   25
# 2                     Shark Junction  Scuba diving   Heidi Ernst   F   73
# 3                                NaN    Snorkeling      Arthur …   M    6
# 4                    Chubut Province           NaN  Diego Barría   M   32
#
#                                               Injury Fatal Y/N       Time  \
# 0                     Severe injuries to lower limbs         N      10h00
# 1  Body found with shark bites. Possible drowning...         Y    Morning
# 2                               Calf severely bitten         N      13h00
# 3                                   Left foot bitten         N  Afternoon
# 4                              Death by misadventure         Y        NaN
#
#                 Species                            Source Injury Severity  DD  \
# 0  White shark, 3.8-4.2m  B. Myatt, & M. Michaelson, GSAF         Unknown  25
# 1                    NaN           The Tribune, 8/21/2023           Death  21
# 2  Caribbean rreef shark                J. Marchand, GSAF   Severe injury  07
# 3            Lemon shark              Midlibre, 3/18/2023    Minor injury  02
# 4                    NaN              El Pais,  2/27/2023           Death  18
#
#     MM  YYYY
# 0  Aug  2023
# 1  Aug  2023
# 2  Jun  2023
# 3  Mar  2023
# 4  Feb  2023

# %% [markdown]
# ----
# # FINAL CHANGES

# %%
df.head(5)
# Out:
#             Type     Country                   State  \
# 0  Other/Unknown   Australia         New South Wales
# 1  Other/Unknown     Bahamas  New Providence   Isoad
# 2  Other/Unknown     Bahamas                Freeport
# 3  Other/Unknown  Seychelles          Praslin Island
# 4  Other/Unknown   Argentina               Patagonia
#
#                             Location      Activity          Name Sex  Age  \
# 0  Lighthouse Beach, Port Macquarie        Surfing     Toby Begg   M   44
# 1             Saunders Beach, Nassau           NaN          male   M   25
# 2                     Shark Junction  Scuba diving   Heidi Ernst   F   73
# 3                                NaN    Snorkeling      Arthur …   M    6
# 4                    Chubut Province           NaN  Diego Barría   M   32
#
#                                               Injury Fatal Y/N       Time  \
# 0                     Severe injuries to lower limbs         N      10h00
# 1  Body found with shark bites. Possible drowning...         Y    Morning
# 2                               Calf severely bitten         N      13h00
# 3                                   Left foot bitten         N  Afternoon
# 4                              Death by misadventure         Y        NaN
#
#                 Species                            Source Injury Severity  DD  \
# 0  White shark, 3.8-4.2m  B. Myatt, & M. Michaelson, GSAF         Unknown  25
# 1                    NaN           The Tribune, 8/21/2023           Death  21
# 2  Caribbean rreef shark                J. Marchand, GSAF   Severe injury  07
# 3            Lemon shark              Midlibre, 3/18/2023    Minor injury  02
# 4                    NaN              El Pais,  2/27/2023           Death  18
#
#     MM  YYYY
# 0  Aug  2023
# 1  Aug  2023
# 2  Jun  2023
# 3  Mar  2023
# 4  Feb  2023

# %%
# Drop columns we don't need:
df = df.drop(columns=['Activity'])
df = df.drop(columns=['Type'])
df = df.drop(columns=['Species '])
df = df.drop(columns=['Source'])
df = df.drop(columns=['Time'])
df = df.drop(columns=['Name'])
df = df.drop(columns=['State'])
df = df.drop(columns=['Location'])
df = df.drop(columns=['DD'])
df = df[df['MM'].notna() & (df['MM'] != "")]
df.head()
# Out:
#       Country Sex  Age                                             Injury  \
# 0   Australia   M   44                     Severe injuries to lower limbs
# 1     Bahamas   M   25  Body found with shark bites. Possible drowning...
# 2     Bahamas   F   73                               Calf severely bitten
# 3  Seychelles   M    6                                   Left foot bitten
# 4   Argentina   M   32                              Death by misadventure
#
#   Fatal Y/N Injury Severity   MM  YYYY
# 0         N         Unknown  Aug  2023
# 1         Y           Death  Aug  2023
# 2         N   Severe injury  Jun  2023
# 3         N    Minor injury  Mar  2023
# 4         Y           Death  Feb  2023

# %%
# Save INTERIM DATAFRAM CLEANED to CSV
df.to_csv("../data/interim/8_interim_clean.csv", index=False)
print("STEP 8 : All Data cleaned successfully!")
df.head()
# Out:
# STEP 8 : All Data cleaned successfully!
#       Country Sex  Age                                             Injury  \
# 0   Australia   M   44                     Severe injuries to lower limbs
# 1     Bahamas   M   25  Body found with shark bites. Possible drowning...
# 2     Bahamas   F   73                               Calf severely bitten
# 3  Seychelles   M    6                                   Left foot bitten
# 4   Argentina   M   32                              Death by misadventure
#
#   Fatal Y/N Injury Severity   MM  YYYY
# 0         N         Unknown  Aug  2023
# 1         Y           Death  Aug  2023
# 2         N   Severe injury  Jun  2023
# 3         N    Minor injury  Mar  2023
# 4         Y           Death  Feb  2023

# %% [markdown]
# ----
# # CHARTS & INSIGHTS

# %%
df.columns
# Out:
# Index(['Country', 'Sex', 'Age', 'Injury', 'Fatal Y/N', 'Injury Severity', 'MM',
#        'YYYY'],
#       dtype='object')

# %%
import plotly.io as pio
import plotly.express as px

# Use VS Code renderer for inline display
pio.renderers.default = 'vscode'  # or 'iframe'

# Prepare data
top_5 = df['Country'].value_counts().nlargest(5).reset_index()
top_5.columns = ['Country', 'Count']

# Create pie chart
fig = px.pie(
    top_5,
    names='Country',
    values='Count',
    title='Countries with High frequncy of shark attacks',
    color_discrete_sequence=px.colors.qualitative.Pastel
)

fig.show()

# %%
import pandas as pd
import plotly.express as px
import plotly.io as pio

# Ensure inline display in VS Code
pio.renderers.default = 'vscode'  # or 'iframe'

# Check column names for typos/spaces
print(df.columns)  # Optional: just to see actual column names

# Use the correct column names for Age and Sex
age_col = [col for col in df.columns if 'age' in col.lower()][0]  # picks the first column containing 'age'
sex_col = [col for col in df.columns if 'sex' in col.lower()][0]   # picks the first column containing 'sex'

# Ensure 'Age' is numeric
df[age_col] = pd.to_numeric(df[age_col], errors='coerce')

# Drop rows where Age is NaN
df = df.dropna(subset=[age_col])

# Group by Sex and calculate average Age
sex_age = df.groupby(sex_col)[age_col].mean().reset_index()

# Create the bar chart
fig = px.bar(
    sex_age,
    x=sex_col,
    y=age_col,
    color=sex_col,
    title='Average Age by Sex',
    text=sex_age[age_col].round(1),
    color_discrete_sequence=px.colors.qualitative.Pastel
)

# Customize layout
fig.update_traces(textposition='outside')
fig.update_layout(
    xaxis_title='Sex',
    yaxis_title='Average Age',
    template='plotly_white'
)

fig.show()
# Out:
# Index(['Country', 'Sex', 'Age', 'Injury', 'Fatal Y/N', 'Injury Severity', 'MM',
#        'YYYY'],
#       dtype='object')

# %%
print(df.columns)
df.head(560)


# Clean Location data
# add extra data
## nearest_hospital_to_beach_location
## most_needed_product_for_injury_severity
# Out:
# Index(['Country', 'Sex', 'Age', 'Injury', 'Fatal Y/N', 'Injury Severity', 'MM',
#        'YYYY'],
#       dtype='object')
#                     Country Sex  Age  \
# 0                 Australia   M   44
# 1                   Bahamas   M   25
# 2                   Bahamas   F   73
# 3                Seychelles   M    6
# 4                 Argentina   M   32
# 5                Costa Rica   F   50
# 6                    Brazil   M   11
# 7                 Australia   M   26
# 8                     Egypt   M   26
# 9                 Australia   F   26
# 10         French Polynesia   F   35
# 11                Australia   F   26
# 12                  Bahamas   M   50
# 13                      USA   F   26
# 14                 Colombia   M   62
# 15                   Brazil   M   34
# 16             South Africa   M   31
# 17                      USA   M   33
# 18             South Africa   M   25
# 19                    Spain   F   11
# 20                      USA   M   10
# 21                      USA   F    8
# 22                      USA   M   26
# 23                      USA   F   18
# 24                      USA   F   26
# 25                      USA   M   26
# 26             South Africa   M   68
# 27                Australia   M   35
# 28                Australia   M   20
# 29                      USA   M   19
# 30                   Mexico   M   26
# 31                      USA   M   27
# 32                Australia   M   26
# 33               Cape Verde   M   60
# 34                      USA   M   26
# 35                      USA   M   15
# 36           Cayman Islands   M   65
# 37                Australia   M   26
# 38                      USA   F    9
# 39                      USA   M   32
# 40                      USA   M   26
# 41                    Spain   M   10
# 42                Australia   M   40
# 43                      USA   F   35
# 44                      USA   M   39
# 45         French Polynesia   M   26
# 46                      USA   F   26
# 47                    Italy   M   43
# 48                   Brazil   M   23
# 49                Australia   F   26
# 50                      USA   M   38
# 51                      USA   M   26
# 52                  Bahamas   M   63
# 53                      USA   M   26
# 54                Australia   M   38
# 55                Australia   F   10
# 56           Cayman Islands   M   26
# 57                      USA   F   47
# 58                    Spain   M   48
# 59                  Jamaica   M   20
# 60                      USA   M   42
# 61                Australia   M   24
# 62                Australia   M   47
# 63                Australia   M   62
# 64                Australia   M   20
# 65                      USA   M   26
# 66                      USA   M   12
# 67        Trinidad & Tobago   M   24
# 68                   Canada   F   23
# 69                Australia   F   42
# 70                      USA   M   16
# 71             Saudi Arabia   M   42
# 72                  Antigua   M   26
# 73             South Africa   M   26
# 74                      USA   M   27
# 75                Australia   M   48
# 76                      USA   M   12
# 77                   Brazil   M   14
# 78                      UAE   M   43
# 79                    Egypt   F   26
# 80                Australia   F    7
# 81                Australia   M   26
# 82                  Bahamas   M   43
# 83                      USA   F   26
# 84                     Guam   M   31
# 85             South Africa   M   26
# 86                      USA   M   49
# 87                    Nevis   M   26
# 88                    Spain   F   11
# 89                      USA   M   26
# 90                      USA   M   14
# 91                      USA   M   49
# 92             South Africa   M   24
# 93                   Brazil   M   17
# 94                   Brazil   M   17
# 95                      USA   M   27
# 96                      USA   F   20
# 97                      USA   M    7
# 98                      USA   M   52
# 99                      USA   M   53
# 100            South Africa   M   26
# 101                  Mexico   M   32
# 102               Australia   M   19
# 104             New Zealand   M   26
# 105  British Virgin Islands   M   53
# 106               Australia   M   34
# 107                  Mexico   M   26
# 108                     USA   F   26
# 109                     USA   F   43
# 110                     USA   F    9
# 111               Australia   M   45
# 112              Costa Rica   M   36
# 113               Australia   M   20
# 114                     USA   M   54
# 116            South Africa   M   36
# 117               Australia   M   44
# 118                  Brazil   M   17
# 119                  Belize   M   34
# 120                   Spain   F    7
# 121                     USA   M   26
# 122            South Africa   M   17
# 123                     USA   M   45
# 124                 Bahamas   M   26
# 125                     USA   M   26
# 126                     USA   M   17
# 127              Seychelles   M   26
# 128                     USA   M   25
# 129                 Liberia   M   26
# 130                     USA   M   49
# 131                     USA   M   17
# 132                     USA   M   52
# 133                Honduras   F   26
# 134            South Africa   M   51
# 135               Sri Lanka   F   11
# 136                     USA   M   26
# 137               Australia   M   26
# 138                     USA   M    9
# 139                     USA   F   22
# 140               Australia   M   31
# 141             New Zealand   M   26
# 142             New Zealand   M   26
# 143                     USA   M   28
# 144                     USA   M   56
# 145                     USA   F    9
# 146                     USA   M   31
# 147                     USA   F   22
# 148            South Africa   M   14
# 149               Australia   M   11
# 150               Australia   M   52
# 151           New Caledonia   M   44
# 152               Australia   M   26
# 153               Australia   M   75
# 154              Madagascar   M   26
# 155                  Brazil   M   12
# 156                Malaysia   F   26
# 157               Australia   M   47
# 158                     USA   F   27
# 159                     USA   M   26
# 160                     USA   M   22
# 161             New Zealand   M   27
# 162                     USA   M   26
# 163               Australia   F   37
# 165               Australia   M   31
# 166                     USA   F   29
# 167               Australia   M   21
# 168                  Mexico   M   28
# 169                     USA   F   28
# 170                     USA   M   26
# 171                     USA   M    9
# 172                     USA   M   15
# 173                   Tonga   M   26
# 174                     USA   M   26
# 175                     USA   M   12
# 178               Australia   M   44
# 179                     USA   F   25
# 180               Australia   M   32
# 181                     USA   M   26
# 182                     USA   M   26
# 183                     USA   M   26
# 184                     USA   M   45
# 185               Australia   M   19
# 186                 Bahamas   M   32
# 187            South Africa   M   26
# 188                     USA   M   30
# 189               Australia   M   27
# 190                     USA   M   26
# 191                     USA   M   26
# 192                     USA   M   49
# 193                 Bermuda   M   35
# 194                   Japan   M   26
# 195                     USA   M   24
# 196                     USA   M   26
# 197            South Africa   F   26
# 198            South Africa   M   22
# 199               Australia   M   26
# 200               Australia   F   17
# 201            South Africa   M   26
# 202            South Africa   M   14
# 203            South Africa   M   26
# 205            South Africa   M   22
# 206            South Africa   M   35
# 207            South Africa   M   21
# 208                     USA   M   17
# 209                     USA   M   11
# 210                     USA   M   67
# 211            South Africa   M   26
# 212                     USA   M   22
# 213                     USA   F   77
# 214                     USA   F   31
# 215            South Africa   M   21
# 216                 Somalia   M   26
# 217                  Greece   M   36
# 218            South Africa   M   26
# 219            South Africa   F   26
# 220                   Italy   M   26
# 221            South Africa   M   26
# 222            South Africa   M   26
# 223                     USA   M   25
# 224                     USA   M   17
# 225            South Africa   M   20
# 226                     USA   M   43
# 227                     USA   F   33
# 228                     USA   M   26
# 229                     USA   M   26
# 230            South Africa   M   23
# 231            South Africa   M   26
# 234                     USA   M   36
# 235            South Africa   M   26
# 236            South Africa   M   26
# 237                     USA   M   17
# 238               Australia   M   26
# 239               Australia   M   26
# 240            South Africa   M   17
# 241                     USA   M   26
# 242                   Italy   M   37
# 243            South Africa   M   26
# 244            South Africa   M   26
# 245              Mozambique   F   20
# 247                     USA   M   26
# 248               Australia   M   26
# 249               Australia   M   52
# 250            South Africa   M   26
# 251            South Africa   M   30
# 252                  Mexico   M   43
# 253                     USA   M   63
# 254                     USA   M   28
# 255        Papua New Guinea   M   32
# 256            South Africa   F   26
# 257                     USA   M   26
# 258                   Italy   M   21
# 259               Australia   M   19
# 260                     USA   M   18
# 261               Australia   M   26
# 263            South Africa   M   26
# 265                     USA   M   46
# 266                     USA   M   24
# 268             Philippines   M   26
# 269                     USA   M    6
# 270                     USA   M   26
# 271                     USA   M   19
# 272                     USA   M   26
# 273                     USA   M   21
# 274                     USA   M   18
# 275                     USA   F   29
# 276            South Africa   M   40
# 277               Australia   M   23
# 278             New Zealand   M   26
# 279          Atlantic Ocean   F   26
# 280                     USA   M   26
# 281                     USA   M   26
# 282                     USA   M   26
# 283               Australia   M   25
# 284               Australia   M   26
# 285                     USA   F   43
# 286                     USA   M   26
# 287            South Africa   M   40
# 288               Australia   M   25
# 289                     USA   M   45
# 290                     USA   M   10
# 291                     USA   M   26
# 292                     USA   F   51
# 293               Australia   M   24
# 294                     USA   M   26
# 295         Johnston Island   M   37
# 296        Marshall Islands   M   26
# 297        Marshall Islands   M   26
# 298                     USA   M   26
# 299                     USA   M   39
# 300                 Bermuda   M   28
# 301                     USA   M   36
# 303               Australia   M   26
# 304                 Bermuda   F   29
# 305                     USA   M   26
# 306               Australia   M   26
# 307                   Japan   M   14
# 308             Philippines   M   10
# 309                     USA   M   21
# 310                     USA   M   26
# 312               Australia   M   22
# 313            South Africa   M   26
# 314               Australia   F   26
# 315            South Africa   M   26
# 316               Australia   M   21
# 317                   Japan   M   50
# 320                   Japan   M   13
# 321                   Italy   M   26
# 322                     USA   M   26
# 323                  Mexico   M   19
# 324               Guatemala   F   26
# 325            South Africa   M   18
# 327               Australia   M   26
# 328                     USA   M   26
# 329               Australia   M   26
# 330                     USA   M   26
# 332               Australia   M   26
# 333                   Italy   M   17
# 334               Australia   M   32
# 335                  Greece   M   26
# 336               Australia   M   26
# 337     North Pacific Ocean   M   26
# 338                     USA   M   26
# 339                  Mexico   M   68
# 340           Pacific Ocean   M   26
# 341                     USA   M   26
# 342                  Brazil   M   26
# 343               Australia   M   18
# 344               Australia   M   26
# 347               Australia   M   40
# 348               Australia   M   24
# 349                 Türkiye   M   26
# 350               Australia   M   16
# 351               Australia   M   43
# 353               Australia   M   17
# 354                      UK   M   26
# 355                     USA   M   23
# 356                     USA   M   53
# 357               Australia   M   40
# 358               Australia   M    5
# 359               Australia   M   26
# 360                     USA   M   17
# 361                     USA   M   26
# 362                     USA   M   26
# 363               Australia   M   39
# 364            South Africa   M   17
# 365              Cape Verde   F   26
# 367                     USA   M   26
# 368                   India   M   26
# 370                   Spain   M   26
# 371               Australia   M   26
# 372               Australia   M   26
# 373               Australia   M   26
# 374               Australia   M   26
# 375               Australia   M   26
# 376                    Cuba   M   26
# 377               Australia   M   26
# 378               Australia   M   26
# 379                     USA   M   30
# 380                     USA   F   26
# 381                   Egypt   M   26
# 382             New Zealand   M   26
# 384                     USA   M   26
# 385                     USA   M   26
# 386                     USA   F   26
# 387            South Africa   M   26
# 388                     USA   M   26
# 389                 Croatia   M   26
# 390                     USA   M   26
# 391                     USA   M   26
# 393                     USA   F   19
# 394                     USA   M   26
# 395                   Haiti   M   26
# 396                      UK   M   26
# 397               Australia   M   26
# 398              Mozambique   M   26
# 399               Australia   M   18
# 400             New Zealand   M   26
# 401               Australia   M   26
# 402                   Egypt   M   26
# 403                   Italy   M    8
# 404               Australia   M   23
# 405               Australia   M   39
# 407            South Africa   M   26
# 408            South Africa   M   26
# 409                   Italy   M   20
# 410                   Yemen   M   26
# 411            South Africa   M   26
# 412                     USA   M   26
# 413             New Zealand   M   26
# 414             Philippines   M   26
# 415               Australia   F   13
# 416                     USA   M   26
# 417               Australia   M   26
# 419                  Mexico   M   26
# 420                    Cuba   M   26
# 421               Australia   M   26
# 422                     USA   M   26
# 423            South Africa   M   26
# 424                     USA   M   26
# 425                 Jamaica   M   26
# 426               Australia   M   26
# 427                     USA   F   26
# 428             New Zealand   M   26
# 429             New Zealand   M   26
# 430               Australia   M   26
# 431                     USA   M   26
# 433               Australia   M   26
# 434                     USA   M   18
# 435                  Mexico   M   26
# 438               Australia   M   26
# 439            Indian Ocean   M   26
# 440            South Africa   M   26
# 441               Australia   M   26
# 442               Australia   M   26
# 443                  Azores   M   26
# 444                 Croatia   M   26
# 445                    Fiji   M   26
# 446               Australia   M   26
# 447                  Guyana   M   26
# 449               Australia   M   26
# 450                   China   M   26
# 452            South Africa   M   26
# 453                   Spain   M   26
# 454                     USA   M   26
# 455                     USA   M   26
# 458               Australia   M   26
# 459          Atlantic Ocean   F    1
# 460               Australia   M   26
# 461                     USA   M   26
# 463               Australia   M   26
# 466                   Spain   M   26
# 467                  Norway   M   26
# 469                     USA   M   26
#
#                                                 Injury Fatal Y/N  \
# 0                       Severe injuries to lower limbs         N
# 1    Body found with shark bites. Possible drowning...         Y
# 2                                 Calf severely bitten         N
# 3                                     Left foot bitten         N
# 4                                Death by misadventure         Y
# 5                  Right forearm and left hand injured         N
# 6                             Minor cuts to left thigh         N
# 7                                          Disappeared         N
# 8             Laceration to arm caused by metal object         N
# 9                                                  NaN         N
# 10                   Severe injuries to arms and chest         N
# 11                            Lacerations to lower leg         N
# 12                          Injuries to left lower leg         N
# 13   Single laceration to right thigh inconsistent ...         N
# 14   Autopsy confirmed death by drowning, shark bit...         Y
# 15   Multiple severe injuries to arms and leg, leg ...         N
# 16       FATAL, but death was probably due to drowning         Y
# 17              Lacerations to right ankle, foot & toe         N
# 18       FATAL, but death was probably due to drowning         Y
# 19                            Lacerations to left foot         N
# 20                  Abrasions and cuts to sole of foot         N
# 21                                        Foot injured         N
# 22                 Arm injured by hook, not by a shark         N
# 23   Laceration to thigh, likely caused by surfboar...         N
# 24                    Alleged laceration to left ankle         N
# 25           Laceration & puncture wounds to left foot         N
# 26   Fatal, coroner unable to determine if the dive...         Y
# 27              No attack, shark made a threat display         N
# 28                       Minor injuries to foot & toes         N
# 29                          Cuts to right ankle & foot         N
# 30             Shark breached cage, no injury to diver         N
# 31                            No injury, board damaged         N
# 32   No injury, but sharks repeatedly hit their fin...         N
# 33                                           "Serious"         N
# 34   Fell off board when spinner shark leapt from t...         N
# 35   Minor injury to arm. Possibly caused by smalll...         N
# 36        Minor injury to wrist from Southern stingray         N
# 37                        No injury, knocked off board         N
# 38                              Lower left leg injured         N
# 39                             Left foot bitten by eel         N
# 40                            Wound to right lower leg         N
# 41    Minor injury when he attempted to touch a fish.          N
# 42                                      Injury to hand         N
# 43   2' cut to dorsum of foot, 2 puncture wounds to...         N
# 44                                  Laceration to back         N
# 45   Parallel lacerations to torso inconsistent wit...         N
# 46                            Minor lacerations to leg         N
# 47   FATAL, but shark involvement prior to death un...         Y
# 48   Injury to left thigh from unidentified species...         N
# 49                                Board snapped in two         N
# 50   During his 16-hour swim to shore, he was circl...         N
# 51                        A hoax, no shark involvement         N
# 52   Missing after a dive, shark involvement consid...         N
# 53   No injury. No attack. 12' white shark appeared...         N
# 54               Shark bites may have been post mortem         N
# 55   Injuries to wrist/hand by a mackerel, not a shark         N
# 56   Caribbean reef shark buzzed him. No injury, no...         N
# 57   Puncture wound to torso. Reported as a bite by...         N
# 58   Scrape to right forearm. Frennet says inflicte...         N
# 59            Probable drowning with post-mortem bites         N
# 60                        Shark bites were post-mortem         N
# 61   Disappeared. No evidence that he was taken by ...         N
# 62                      Never happened; it was a  hoax         N
# 63   No injury, a 3 m blue shark merely snapped at ...         N
# 64   Injury to ankle caused  by a stingray, not a s...         N
# 65                                   Laceration to toe         N
# 66                       Shark involvement unconfirmed         N
# 67             Probable drowning with post-mortem bite         N
# 68   Lacerations to 2 fingers, but shark involvemen...         N
# 69   Cause of death was drowning & preceded shark i...         Y
# 70   Laceration to foot. Injured by a stingray, not...         N
# 71          Harassed by sharks but not injured by them         N
# 72                        Bitten on right hand & wrist         N
# 73                              No injury, ski damaged         N
# 74                     Lacerations to lower right leg          N
# 75                                               FATAL         Y
# 76                              Abrasions to left hand         N
# 77   Cause of death may have been drowning; remains...         Y
# 78   Erroneously reported on several internet sites...         N
# 79   Apparent drowning, and subsequent scavenging b...         N
# 80                            Lacerations to both legs         N
# 81                 Death may have been due to drowning         Y
# 82   His partial remains were recovered from a 12' ...         Y
# 83   Minor abrasions to legs when she was lifted on...         N
# 84                        Shark bites were post-mortem         N
# 85   Minor lacerations to left leg. nitially report...         N
# 86                       Puncture wounds to right foot         N
# 87   Death was due to drowning. Two days later his ...         Y
# 88                             Laceration to left foot         N
# 89                             Puncture wounds to foot         N
# 90                 2-inch laceration to upper left arm         N
# 91                                             Missing         N
# 92                                  Body not recovered         N
# 93            Probable drowning with post-mortem bites         N
# 94                    Drowned, body scavenged by shark         N
# 95                  Death was probably due to drowning         Y
# 96                                         Calf bitten         N
# 97                                      Minor injuries         N
# 98   Bruises, abrasions and some spinal and nerve d...         N
# 99            Probable drowning with post-mortem bites         N
# 100  As he pushd the shark away from his camera, hi...         N
# 101           Probable drowning with post-mortem bites         N
# 102                           2 puncture wounds to leg         N
# 104                 Stingray envenomation, not a shark         N
# 105                       Shark bites were post-mortem         N
# 106                        Lacerations to left forearm         N
# 107  White shark breached cage. No injury to occupants         N
# 108       Shark involvement prior to death unconfirmed         Y
# 109         Foot injured. Shark involvment uncomfirmed         N
# 110  Superficial injuries to upper leg may have bee...         N
# 111       Shark involvement prior to death unconfirmed         Y
# 112  Death due to drowning. Shark bite may have bee...         Y
# 113       Shark involvement prior to death unconfirmed         Y
# 114                                          No injury         N
# 116    No injury; 4m white shark made a threat display         N
# 117  Killed by a stingray, not a shark - a tragedy ...         N
# 118              Shark bites may have been post mortem         N
# 119     Shark involvement prior to death not confirmed         Y
# 120                       Hand & wrist severely bitten         N
# 121                            Shark bites post mortem         N
# 122  FATAL, but shark involvement prior to death un...         Y
# 123  Forensic examination suggested diver drowned &...         N
# 124  No injury, divers felt threatened by 10' pregn...         N
# 125                 Lacerations to dorsum of left foot         N
# 126  Laceration to knee, possibly by a  small black...         N
# 127  FATAL, shark involvement prior to death is unc...         Y
# 128      Straight 2.5" laceration on top of left ankle         N
# 129  Presumed to have drowned until his body washed...         N
# 130  No injury, 2.1m [7'] tiger shark approached sw...         N
# 131  Dorsum of foot/ankle  injured by surfboard ske...         N
# 132                                      Foot injured          N
# 133  Laceration on siide of calf, small laceration ...         N
# 134        Bites by 2.5 m tiger shark were post mortem         N
# 135                                          No injury         N
# 136                              Minor scratch on calf         N
# 137  No injury, shark made threat displays & diver ...         N
# 138                  Single puncture wound on the foot         N
# 139  Disappeared, surfboard washed ashore, marks on...         N
# 140  Disappeared while diving, may have suffered sh...         N
# 141                        No injury, swim fin damaged         N
# 142  No injury, no attack, shark took fish from bac...         N
# 143                                     Knee lacerated         N
# 144                             Left forearm lacerated         N
# 145                     Puncture wounds on inner thigh         N
# 146                               Left ankle lacerated         N
# 147                                     Foot lacerated         N
# 148  Probable scavenging. The boy disappeared while...         N
# 149                                     Foot lacerated         N
# 150  Drowned, his remains were found in a 3m [10'],...         N
# 151                 PRESUMED FATAL, body not recovered         Y
# 152  No injury, fell off ski after possibly collidi...         N
# 153  Remains recovered from gut of a  3.7 m [12'] t...         N
# 154      Fatal or drowned & remains scavenged by shark         Y
# 155                         Lacerations below the knee         N
# 156  Bones recovered by fishermen in 300-kg [662-lb...         N
# 157     Missing, thought to have been taken by a shark         N
# 158                                          No injury         N
# 159                                          Non-fatal         Y
# 160             Shark involvement probably post-mortem         N
# 161    Reported as shark attack but probable drowning          N
# 162  Presumed taken by a shark,  but forensic evide...         N
# 163  Cut foot, but injury caused by fishing line, n...         N
# 165     Missing, thought to have been taken by a shark         N
# 166    Ankle bitten, but shark involvement unconfirmed         N
# 167  5 m white shark obsrved feeding on remains 6 d...         N
# 168                                              FATAL         Y
# 169                             Minor injuries to foot         N
# 170                                       Minor injury         N
# 171                            Laceration to lower leg         N
# 172  Death resulted fom drowning; tiger shark bites...         Y
# 173  Finger broken when 1.8 m [6'] hooked grey reef...         N
# 174              Torso bitten by 4 m [13'] white shark         N
# 175  Dorsum of right hand bitten, a probable bluefi...         N
# 178                      Shark scavenged on his corpse         N
# 179  Not a shark attack; possibly murder. Body reco...         N
# 180                                         No injury          N
# 181  Body recovered next morning. Injuries appeared...         N
# 182                                         No details         N
# 183  Death due to drowning. His body, tied to float...         Y
# 184  Disappeared. His ripped dive jacket was recovered         N
# 185  No injury, shark allegedly took his surfboard ...         N
# 186  Initally reported as a shark attack, forensic ...         Y
# 187                                           Survived         N
# 188  Disappeared, body recovered with large bite on...         N
# 189            Swept out to sea, feared taken by shark         N
# 190  Lower porton of body recovered 3 days later. N...         N
# 191  Disappeared 15 minutes into shallow dive. Deca...         N
# 192                                              FATAL         Y
# 193                                              FATAL         Y
# 194             Doubtful incident, needs investigation         N
# 195  Reported by media as shark attack but forensic...         Y
# 196  Human remains, believed to be those of Mr. Goo...         N
# 197  Arm washed ashore. scratch marks on the humeru...         Y
# 198                                Minor injury to leg         N
# 199  His remains were recovered from a shark caught...         N
# 200  Remains recovered from 4 m, 420-kg, caught 13-...         N
# 201                     Possible drowning / scavenging         N
# 202                                Abrasion to forearm         N
# 203  Slipped off rocks & was treading water when he...         N
# 205  No injury, no attack, 1.8 m copper shark made ...         N
# 206  No injury, shark made threat display & impaled...         N
# 207                     Probable drowning / scavenging         N
# 208                                 Found to be a hoax         N
# 209                                  3" wound on thigh         N
# 210  Body not recovered. 3 days later some of his e...         N
# 211                     Probable drowning / scavenging         N
# 212  Disappeared, 1 mile from where Sandra Fletcher...         Y
# 213                              10" laceration on leg         N
# 214  Death was due to drowning; body scavenged by a...         Y
# 215  FATAL, but shark involvement prior to death co...         Y
# 216   Forced at gunpoint to jump overboard. Presume...         Y
# 217  Coroner determined the man was killed by a boa...         N
# 218  Two feet found in 1.74 m, 115-kg Zambesi shark...         N
# 219                   Probable drowning and scavenging         N
# 220  No injury, 3 m shark "harassed" him at depth o...         N
# 221                                           Survived         N
# 222                                              FATAL         Y
# 223  Remains recovered from 2.7 m tiger shark, but ...         Y
# 224                            No Injury, board bitten         N
# 225                         No injury, swim fin bitten         N
# 226                           Laceration to left thigh         N
# 227           Human remains recovered from tiger shark         N
# 228  Disappeared while fishing from shore. Leg foun...         N
# 229  Probable drowning, 1.2 m [4'] shark hindered r...         N
# 230  Probable drowning & scavenging by 1.5 m tiger ...         N
# 231                    Probable  drowning & scavenging         N
# 234  FATAL, but shark involvement prior to death wa...         Y
# 235  FATAL or scavenging by 3 m tiger shark (may ha...         Y
# 236  Human head recovered from 3 m [10'] tiger shar...         N
# 237                         Lacerations to hip and leg         N
# 238                 Missing, believed taken by a shark         N
# 239   Shark involvement prior to death was unconfirmed         Y
# 240                                 Laceration to foot         N
# 241                          "Tooth marks" in left leg         N
# 242  The press reported this as an attack by a whit...         N
# 243                     Probable drowning / scavenging         N
# 244    Probable drowning / scavenging by a white shark         N
# 245                                       Feet injured         N
# 247  Swept out to sea,  5.5 m [18'] shark seen in t...         N
# 248                                          No injury         N
# 249                                         No details         N
# 250                                          No injury         N
# 251                                          No injury         N
# 252                                          No injury         N
# 253                              Foot severely injured         N
# 254                                          No injury         N
# 255                                          No injury         N
# 256  Bones and brightly colored bangles recovered  ...         N
# 257  Remains found in a 3.4 m (11') tiger shark. Pr...         N
# 258  Diver shot the shark, then it injured his arm ...         N
# 259  Disappeared, no trace of men or equipment, sha...         N
# 260                             Incident not confirmed         N
# 261   The 2.9 m [9.5'] shark never made contact wit...         N
# 263  No attack, no injury to occupant: a 400-lb gre...         N
# 265  No injury. A 1.1 m [3.5'] blacktip shark shark...         N
# 266  White shark, 3.7 m [12']  made threat display....         N
# 268          One man was lost, but he may have drowned         N
# 269  Parallel lacerations on right calf. Thought to...         N
# 270  No injury, chased by 4.6 m [15'] oceanic white...         N
# 271  Drowned & his body was not recovered. Sharks s...         Y
# 272  All 16 onboard perished, recovery efforts hamp...         N
# 273  Puncture marks on chest may have been post mor...         N
# 274  3 m to 3.7 m [10' to 12']  great hammerhead sh...         N
# 275  Disappeared, probable drowning but sharks in a...         N
# 276  Skeletonized, except for head & feet. Possibly...         N
# 277  Body not recovered  / May have drowned prior t...         N
# 278                                          No injury         N
# 279  One woman reported to have suffered fish bites...         Y
# 280                     3 lacerations below right knee         N
# 281  May have drowned prior to shark involvement, p...         N
# 282  Two shark-bitten lifejackets were recovered le...         N
# 283  9' shark in area when he disappeared, body not...         N
# 284  Skeletonized, except for head & feet. Possible...         N
# 285  Drowned due to CO2 poisoning - Post Mortem sca...         N
# 286                                              FATAL         Y
# 287  Possible drowning / post mortem scavenging by ...         N
# 288  Remains recovered from 10' shark, but shark in...         Y
# 289  Skeletonized, but shark involvement may have o...         Y
# 290                                    Abdomen abraded         N
# 291                     Considered a doubtful incident         N
# 292  FATAL, probable drowning & post mortem scavenging         Y
# 293  Swept off rocks & presumed to have drowned, sh...         N
# 294  Apparently went missing while diving. Helicopt...         N
# 295               No injury, shark made threat display         N
# 296             No injury, shark made a threat display         N
# 297             No injury, shark made a threat display         N
# 298  Partial human remains spotted by helicopter, s...         N
# 299  Legs & arms bitten, coroner unable to determin...         Y
# 300                    No injury, 5 sharks bumped raft         N
# 301                             Left forearm lacerated         N
# 303  No injury, shark made threat display, one dive...         N
# 304                 Murdered, body scavenged by sharks         N
# 305                                          No injury         N
# 306                                          No injury         N
# 307                              Survived (no injury?)         N
# 308  Navy personnel reported that his body was "mut...         Y
# 309                                          No injury         N
# 310  No injury, no attack, the 10' shark merely cir...         N
# 312                                    Thigh lacerated         N
# 313                      No injury, shark leapt at him         N
# 314           Injuries caused by coral, not the  shark         N
# 315                      Injuries not caused by sharks         N
# 316  Disappeared while diving, speargun recovered, ...         N
# 317                  Torso recovered from 206-lb shark         N
# 320           Body found in gut of 2000-lb white shark         N
# 321  No injury to occupants. Shark tore nets & traw...         N
# 322               Body recovered, mutilated by shark/s         N
# 323                                          No injury         N
# 324  It is probable that all onboard (2 men & 2 wom...         Y
# 325  Possibly drowned, remains recovered days later...         N
# 327  Body found after a week in the water apparentl...         N
# 328                       Human remains found in shark         N
# 329  Szot's right hand found in a 4.5' [14.5'] tige...         N
# 330  His remains were recovered from a “huge shark”...         N
# 332                    Fatal or drowning or scavenging         Y
# 333                                          No injury         N
# 334                      No injury, chased by 3 sharks         N
# 335                     Shark involvement  unconfirmed         N
# 336                     Probable drowning & scavenging         N
# 337  When picked up by the USS Boyd DD 44 on 6/23/1...         N
# 338  Hand, forearm, leg and pelvis recovered from 4...         N
# 339           No injury, a shark made a threat display         N
# 340                                           Survived         N
# 341  On 29-Apr-1943 his remains (right forearm & sw...         N
# 342  Remains  recovered from 440-lb shark, but caus...         Y
# 343  Cause of death was drowning, shark bites were ...         Y
# 344       Shark involvement prior to death unconfirmed         Y
# 347                               Abrasion above knee          N
# 348             Superficial lacerations on feet & toes         N
# 349                               No injury, no attack         N
# 350  His body was recovered 2 days later but shark ...         Y
# 351  Shark involvement prior to death was not confi...         Y
# 353      Disappeared & his torn clothing washed ashore         N
# 354  The hooked shark didn't cut his finger, he was...         N
# 355  Although listed as an uprovoked fatal attack b...         Y
# 356  Although listed as  an uprovoked fatal attack ...         Y
# 357  Captive tiger shark regurgitated his arm in th...         N
# 358  No injury; onlookers saw 10' shark heading for...         N
# 359               No injury, "shark chased him ashore"         N
# 360  Body recovered  from 9' shark but death due to...         Y
# 361  Swept out to sea by strong currents, his remai...         N
# 362  "Mysteriously disappeared" His body was found ...         N
# 363                Death may have been due to drowning         Y
# 364  Remains of drowning victim recovered from 250-...         N
# 365             Body of woman recovered from 15' shark         N
# 367     Thumb & coat sleeve recovered from shark's gut         N
# 368                                         No details         N
# 370                                          No injury         N
# 371                                          Abrasions         N
# 372                     Probable drowning & scavenging         N
# 373                                              FATAL         Y
# 374  He failed to return, his body was recovered 11...         N
# 375                Death may have been due to drowning         Y
# 376  Although this incident is listed elsewhere as ...         N
# 377  FATAL, but shark involvement prior to death un...         Y
# 378  Disappeared whiile swimming alone, body parts ...         Y
# 379  Thought to have been taken by a shark. Body wa...         N
# 380                              No attack,  no injury         N
# 381                    Shark involvement not confirmed         N
# 382                Death may have been due to drowning         Y
# 384  His remains were recovered from a shark 3 year...         N
# 385              Man's leg recovered from 800-lb shark         N
# 386                   Female foot recovered from shark         N
# 387                                                NaN         N
# 388  Cause of death undetermined. 3.6 m [11'9"] sha...         Y
# 389                                             FATAL?         Y
# 390          Presumed drowned & bodies taken by sharks         N
# 391                                          No injury         N
# 393   Search party saw a large shark devour what ap...         N
# 394  FATAL, but shark involvement prior to death wa...         Y
# 395                               No attack, no injury         N
# 396   "Struck across loins" but no injury. Accordin...         N
# 397     Disappeared, but shark involvement unconfirmed         N
# 398  Sanna may have drowned; his hand  (identified ...         N
# 399               Cause of death may have been downing         Y
# 400  Shark involvement prior to death was not deter...         Y
# 401  "Bad wound in the leg" - 7-ft shark caught in ...         N
# 402                   Probable drowning & scavenging.          N
# 403  Body recovered from shark, probable drowning a...         N
# 404              Thought to have been taken by a shark         N
# 405  Reported to have been killed by a shark but 2 ...         N
# 407                     Probable drowning & scavenging         N
# 408  Possible drowning & scavenging. Remains were r...         N
# 409     Disappeared, but shark involvement unconfirmed         N
# 410                                                NaN         N
# 411                     Probable drowning & scavenging         N
# 412  Believed drowned. Uhlbrecht’s foot, and the pe...         N
# 413                                              FATAL         Y
# 414                                              FATAL         Y
# 415                   Drowning may mav preceded attack         N
# 416                                "Cut up very badly"         N
# 417  Reported fatal, but this is a questionable inc...         Y
# 419                                     Minor injuries         N
# 420                     Probable drowning & scavenging         N
# 421                           Fatal, probable drowning         Y
# 422     Fatal, but death may have been due to drowning         Y
# 423  Forensic evidence indicated death resulted fro...         Y
# 424  Speculated that he was taken by a shark but mo...         N
# 425  Human remains recovered from a 10' to 12' shar...         N
# 426                     Probable drowning & scavenging         N
# 427  The body of one woman had been bitten by a sha...         N
# 428                     Probable drowning & scavenging         N
# 429  Left leg severed. Probably confusion with GSAF...         N
# 430  His body was found in a tiger shark; next day ...         N
# 431  Unclear if he sustained any injury from the 7'...         N
# 433      Shark involvement suspected but not confirmed         N
# 434                                              FATAL         Y
# 435  Human remains recovered from a 15' shark, prob...         N
# 438                    Partial  remains found in shark         N
# 439           Partial human remains found in 13' shark         N
# 440  Although his body was bitten by a shark/s, bru...         N
# 441                                    Forehead bitten         N
# 442                                              FATAL         Y
# 443  No injury, but according to Fosdyk, captain & ...         N
# 444                                          No injury         N
# 445                                  Probable drowning         N
# 446             Human remains recovered from 11' shark         N
# 447                                              FATAL         Y
# 449  Thought to have been taken by a shark. Body wa...         N
# 450                                          No injury         N
# 452  3.2 m [10.5'] shark caught 9 days later contai...         N
# 453                   Possible drowning and scavenging         N
# 454  Thought to have been taken by a shark/s. Bodie...         N
# 455  Thought to have been taken by a shark/s. Body ...         N
# 458  Shark involvement prior to death was not confi...         Y
# 459                   Death preceded shark involvement         Y
# 407         Unknown       Apr  1902
# 408       Uncertain       Jan  1902
# 409         Unknown       Jul  1901
# 410         Unknown       Jun  1901
# 411         Unknown       Oct  1900
# 412         Unknown       Jul  1900
# 413           Death       Jun  1899
# 414           Death       May  1899
# 415         Unknown       Jan  1899
# 416         Unknown       Aug  1898
# 417           Death       Jul  1898
# 419         Unknown       Oct  1897
# 420         Unknown       Sep  1895
# 421           Death       Apr  1893
# 422           Death       Jun  1891
# 423           Death       May  1890
# 424         Unknown       Nov  1889
# 425         Unknown       Jul  1888
# 426         Unknown       Jun  1888
# 427    Minor injury       Jun  1886
# 428         Unknown       Apr  1886
# 429   Severe injury       Mar  1886
# 430         Unknown       Mar  1886
# 431         Unknown       Aug  1884
# 433         Unknown       Nov  1881
# 434           Death       Oct  1881
# 435         Unknown       May  1880
# 438         Unknown       Mar  1879
# 439         Unknown       Aug  1877
# 440    Minor injury       Jan  1877
# 441    Minor injury       Jan  1875
# 442           Death       Jun  1873
# 443       No injury       Nov  1872
# 444       No injury       Aug  1872
# 445         Unknown       Jan  1872
# 446         Unknown       Dec  1871
# 447           Death       May  1871
# 449         Unknown       Apr  1866
# 450       No injury       Apr  1864
# 452         Unknown       Feb  1863
# 453       Uncertain       Aug  1862
# 454         Unknown       Aug  1858
# 455         Unknown       Aug  1858
# 458           Death       Dec  1852
# 459           Death       Jul  1952
# 460    Minor injury       Jan  1849
# 461         Unknown       Jul  1848
# 463    Minor injury       Nov  1839
# 466       No injury       Jul  1819
# 467         Unknown       May  1818
# 469         Unknown       Sep  1805

# %%
import plotly.express as px
import plotly.io as pio
# Show in VSCode browser
pio.renderers.default = 'vscode'
# Ensure columns are clean
df.columns = df.columns.str.strip()
# Verify column exists
if 'Injury Severity' not in df.columns:
    raise KeyError("Column 'Injury Severity' not found! Found instead: " + str(df.columns.tolist()))
# Count each injury severity type
injury_counts = df['Injury Severity'].value_counts().reset_index()
injury_counts.columns = ['Injury Severity', 'Count']
# Create bar chart
fig = px.bar(
    injury_counts,
    x='Injury Severity',
    y='Count',
    title='Distribution of Shark Attack Injury Types',
    color='Injury Severity',
    text='Count',
    color_discrete_sequence=px.colors.qualitative.Vivid
)
fig.update_traces(textposition='outside')
fig.update_layout(
    xaxis_title='Injury Type',
    yaxis_title='Number of Attacks',
    template='plotly_white',
    showlegend=False
)
fig.show()

# %%
import plotly.express as px
import plotly.io as pio
import pandas as pd
# Set renderer (VS Code opens in browser, Jupyter use 'notebook')
pio.renderers.default = 'vscode'
# Ensure Year is numeric
df['YYYY'] = pd.to_numeric(df['YYYY'], errors='coerce')
# Drop rows with missing year values
df = df.dropna(subset=['YYYY'])
# Count number of shark attacks per year
attacks_per_year = df.groupby('YYYY').size().reset_index(name='Count')
# Sort by year (important for line continuity)
attacks_per_year = attacks_per_year.sort_values('YYYY')
# Create line chart
fig = px.line(
    attacks_per_year,
    x='YYYY',
    y='Count',
    title='Shark Attack Victims Over the Years',
    markers=True,
    line_shape='spline',  # smooth line
    color_discrete_sequence=px.colors.qualitative.Plotly
)
#  chart
fig.update_traces(line=dict(width=3))
fig.update_layout(
    xaxis_title='Year',
    yaxis_title='Number of Shark Attacks',
    template='plotly_white',
    hovermode='x unified'
)
fig.show()

# %%
df['YYYY'].unique()
# Out:
# array([2023, 2022, 2021, 2020, 2019, 2018, 2017, 2016, 2015, 2014, 2013,
#        2012, 2011, 2010, 2009, 2008, 2007, 2006, 2005, 2004, 2003, 2002,
#        2001, 2000, 1999, 1998, 1997, 1996, 1995, 1994, 1993, 1992, 1991,
#        1990, 1989, 1988, 1987, 1986, 1985, 1984, 1983, 1982, 1981, 1980,
#        1979, 1978, 1977, 1976, 1975, 1972, 1970, 1969, 1968, 1967, 1966,
#        1965, 1964, 1963, 1962, 1961, 1960, 1959, 1958, 1954, 1953, 1952,
#        1951, 1950, 1949, 1947, 1944, 1943, 1942, 1941, 1939, 1938, 1937,
#        1936, 1935, 1933, 1932, 1931, 1930, 1929, 1928, 1926, 1924, 1923,
#        1922, 1920, 1916, 1915, 1914, 1913, 1912, 1911, 1910, 1909, 1908,
#        1907, 1906, 1905, 1902, 1901, 1900, 1899, 1898, 1897, 1895, 1893,
#        1891, 1890, 1889, 1888, 1886, 1884, 1881, 1880, 1879, 1877, 1875,
#        1873, 1872, 1871, 1866, 1864, 1863, 1862, 1858, 1852, 1849, 1848,
#        1839, 1819, 1818, 1805])

# %%
import pandas as pd
import numpy as np
import re
# Clean the MM from ‘NaN’ and ‘None’
df = df[df["MM"].notna() & (df["MM"] != "")]
# Replace full month names with abbreviations
df["MM"] = df["MM"].replace({
    "November": "Nov",
    "April": "Apr"
})
df['MM'].unique()
# Out:
# array(['Aug', 'Jun', 'Mar', 'Feb', 'Nov', 'Oct', 'Sep', 'Jul', 'Apr',
#        'May', 'Jan', 'Dec'], dtype=object)

# %%
month_map = {
    'Jan': 1, 'January': 1,
    'Feb': 2, 'February': 2,
    'Mar': 3, 'March': 3,
    'Apr': 4, 'April': 4,
    'May': 5,
    'Jun': 6, 'June': 6,
    'Jul': 7, 'July': 7,
    'Aug': 8, 'August': 8,
    'Sep': 9, 'Sept': 9, 'September': 9,
    'Oct': 10, 'October': 10,
    'Nov': 11, 'November': 11,
    'Dec': 12, 'December': 12
}
df['Month_Num'] = df['MM'].map(month_map)
df = df.dropna(subset=['Month_Num'])
attacks_by_month = df.groupby(['Month_Num', 'MM']).size().reset_index(name='Count')
attacks_by_month = attacks_by_month.sort_values('Month_Num')
import plotly.express as px
import plotly.io as pio
pio.renderers.default = 'vscode'
fig = px.line(
    attacks_by_month,
    x='MM',
    y='Count',
    title='Shark Attacks by Month',
    markers=True,
    line_shape='spline',
    color_discrete_sequence=px.colors.qualitative.Vivid
)
fig.update_traces(line=dict(width=3))
fig.update_layout(
    xaxis_title='Month',
    yaxis_title='Number of Shark Attacks',
    template='plotly_white',
    hovermode='x unified'
)
fig.show()

# %%
# High frequency of shark attacks per month is equal or above 45
# Low frequency of shark attacks per month is under 45
# holidays around four months Jan, Apr, Jul, Aug
# Jan = Chrismas & holiday in south africa as summer
# Apr = Easter & Pack
# Jul & Aug = summer holiday for the northen hemestphere mainly USA*
